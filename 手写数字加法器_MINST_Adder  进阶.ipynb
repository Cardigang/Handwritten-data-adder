# %% [markdown]
# # 迁移学习——手写数字加法机
# 实现了一个手写数字加法机，它可以通过识别输入的两个手写体图像文件，从而计算两个数字的和，并给出输出。展示了三种不同
# 的迁移学习方式，并对它们进行了系统化的比较：
#
# 1、没有迁移学习，网络完全从头学习如何识别数字，如何计算加法；
#
# 2、将已训练好的手写数字识别器网络迁移过来，作为预训练权重；
#
# 3、将已训练好的手写数字识别器网络迁移过来，并作为不可修改的权重。

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np
import copy

# %matplotlib inline

# %% [markdown]
# ## 一、加载数据
#
# 首先一个问题是如何加载成对的图像数据？我们采用的解决方案是采用了两套采样器和加载器，
# 这样每一组采样器＋加载器都独立地从原始的数据集中抽样数据，这就让我们可以获得大量不重复
# 的手写数字图像对，从而可以训练我们的神经网络。

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np
import copy

# %matplotlib inline
# 设置图像读取器的超参数
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64  #批处理的尺寸大小

# 如果系统中存在着GPU，我们将用GPU来完成张量的计算
use_cuda = torch.cuda.is_available() #定义一个布尔型变量，标志当前的GPU是否可用

# 如果当前GPU可用，则将优先在GPU上进行张量计算
dtype = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
itype = torch.cuda.LongTensor if use_cuda else torch.LongTensor

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中
# MNIST数据是属于torchvision包自带的数据，所以可以直接调用。
# 在调用自己的数据的时候，我们可以用torchvision.datasets.ImageFolder或者torch.utils.data.TensorDataset来加载
train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

# 加载测试数据集
test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())


# 定义两个采样器，每一个采样器都随机地从原始的数据集中抽样数据。抽样数据采用permutation
# 生成任意一个下标重排，从而利用下标来提取dataset中的数据
sample_size = len(train_dataset)
sampler1 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))
sampler2 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.choice(range(len(train_dataset)), sample_size))

# 定义两个加载器，分别封装了前两个采样器，实现采样。
train_loader1 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler1
                                           )
train_loader2 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           sampler = sampler2
                                           )

# 对于校验数据和测试数据，我们进行类似的处理。
val_size = 5000
val_indices1 = range(val_size)
val_indices2 = np.random.permutation(range(val_size))
test_indices1 = range(val_size, len(test_dataset))
test_indices2 = np.random.permutation(test_indices1)
val_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(val_indices1)
val_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(val_indices2)

test_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(test_indices1)
test_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(test_indices2)

val_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler1
                                        )
val_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler2
                                        )
test_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler1
                                         )
test_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler2
                                         )

# 为了比较不同数据量对迁移学习的影响，我们设定了一个加载数据的比例fraction
# 即我们只加载原训练数据集的1/fraction来训练网络
fraction = 1

# %% [markdown]
# ## 二、加载网络
#
# 为了实现迁移学习，我们需要从硬盘上加载已经训练好的手写数字识别器卷积神经网络，加载网络需要经过两个步骤：
#
# 1、定义网络模块（nn.Module）的框架，即新定义类ConvNet，实现其forwar函数；
#
# 2、从硬盘文件加载网络
#
# 3、通过绘制其卷积核，验证加载到的网络和导出的网络一致

# %% [markdown]
# ### 1. 定义网络架构

# %%
# 定义待迁移的网络框架，所有的神经网络模块包括：Conv2d、MaxPool2d，Linear等模块都不需要重新定义，会自动加载
# 但是网络的forward功能没有办法自动实现，需要重写。
# 一般的，加载网络只加载网络的属性，不加载方法
depth = [4, 8]
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        # 将立体的Tensor全部转换成一维的Tensor。两次pooling操作，所以图像维度减少了1/4
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1])
        x = F.relu(self.fc1(x)) #全链接，激活函数
        x = F.dropout(x, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        x = self.fc2(x) #全链接，激活函数
        x = F.log_softmax(x, dim =1) #log_softmax可以理解为概率对数值
        return x

# %% [markdown]
# ### 2. 从硬盘文件加载网络
#
# 网络加载命令如下：

# %%
original_net = torch.load('minst_conv_checkpoint') #读取硬盘上的minst_conv_checkpoint文件

# %%
original_net #将网络打印出来观看（只能看到其神经模块和架构）
# Out:
# ConvNet(
#   (conv1): Conv2d(1, 4, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(4, 8, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=392, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ### 3. 检测加载的正确性
#
# 通过测试它在测试数据集上的分类准确度，以及绘制其卷积核，并与导出的程序（minist_convnet.ipynb）中的分类准确度、卷积核等是否相同判断

# %%
def rightness(predictions, labels):
    """计算预测错误率的函数，其中predictions是模型给出的一组预测结果，batch_size行10列的矩阵，labels是数据之中的正确答案"""
    pred = torch.max(predictions.data, 1)[1] # 对于任意一行（一个样本）的输出值的第1个维度，求最大，得到每一行的最大元素的下标
    rights = pred.eq(labels.data.view_as(pred)).sum() #将下标与labels中包含的类别进行比较，并累计得到比较正确的数量
    return rights, len(labels) #返回正确的数量和这一次一共比较了多少元素

#在测试集上分批运行，并计算总的正确率
original_net.eval() #标志模型当前为运行阶段
test_loss = 0
correct = 0
vals = []

#对测试数据集进行循环
for data, target in test_loader1:
#     data, target = data.clone().detach().requires_grad_(False), target.clone().detach()
    with torch.no_grad():
        data = data.clone().detach()
    target = target.clone().detach()
    
    output = original_net(data) #将特征数据喂入网络，得到分类的输出
    val = rightness(output, target) #获得正确样本数以及总样本数
    vals.append(val) #记录结果

#计算准确率
rights = (sum([tup[0] for tup in vals]), sum([tup[1] for tup in vals]))
right_rate = 1.0 * rights[0].numpy() / rights[1]
right_rate
# Out:
# 0.9898

# %%
train_set
# Out:
# 标签是： 4

# %%
#提取第一层卷积层的卷积核
plt.figure(figsize = (10, 7))
for i in range(4):
    plt.subplot(1,4,i + 1)
    plt.imshow(original_net.conv1.weight.data.numpy()[i,0,...])

# %%
# 绘制第二层的卷积核
plt.figure(figsize = (15, 10))
for i in range(4):
    for j in range(8):
        plt.subplot(4, 8, i * 8 + j + 1)
        plt.imshow(original_net.conv2.weight.data.numpy()[j, i,...])

# %% [markdown]
# ## 三、数字加法机的实现
#
# 数字加法机：输入两张图像，输出这两个手写数字的加法。网络的架构如下：
#
# 两个并行的卷积模块：两个卷积层、两个Pooling层；一个全链接模块：最多四层全链接层。

# %%
depth = [4, 8]
class Transfer(nn.Module):
    def __init__(self):
        super(Transfer, self).__init__()
        # 两个并行的卷积通道，第一个通道：
        self.net1_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net_pool = nn.MaxPool2d(2, 2) #2*2 池化
        self.net1_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 第二个通道，注意pooling操作不需要重复定义
        self.net2_conv1 = nn.Conv2d(1, 4, 5, padding = 2) #一个输入通道，4个输出通道（4个卷积核），窗口为5，填充2
        self.net2_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) #输入通道4，输出通道8（8个卷积核），窗口5，填充2
        
        # 全链接层
        self.fc1 = nn.Linear(2 * image_size // 4 * image_size // 4 * depth[1] , 1024) #输入为处理后的特征图压平，输出1024个单元
        self.fc2 = nn.Linear(1024, 2 * num_classes) #输入1024个单元，输出20个单元
        self.fc3 = nn.Linear(2 * num_classes, num_classes) #输入20个单元，输出10个单元
        self.fc4 = nn.Linear(num_classes, 1) #输入10个单元，输出为1

    def forward(self, x, y, training = True):
        # 网络的前馈过程。输入两张手写图像x和y，输出一个数字表示两个数字的和
        # x,y都是batch_size*image_size*image_size形状的三阶张量
        # 输出为batch_size长的列向量
        
        # 首先，第一张图像进入第一个通道
        x = F.relu(self.net1_conv1(x)) #第一层卷积
        x = self.net_pool(x)   # 第一层池化
        x = F.relu(self.net1_conv2(x))  # 第二层卷积
        x = self.net_pool(x) # 第二层池化
        x = x.view(-1, image_size // 4 * image_size // 4 * depth[1]) # 将特征图张量压平
        
        
        y = F.relu(self.net2_conv1(y)) #第一层卷积
        y = self.net_pool(y) # 第一层池化
        y = F.relu(self.net2_conv2(y)) #第二层卷积
        y = self.net_pool(y) #第二层池化
        y = y.view(-1, image_size // 4 * image_size // 4 * depth[1])# 将特征图张量压平
        
        # 将两个卷积过来的铺平向量拼接在一起，形成一个大向量
        z = torch.cat((x, y), 1) #cat函数为拼接向量操作，1表示拼接的维度为第1个维度（0维度对应了batch）
        z = self.fc1(z) #第一层全链接
        z = F.relu(z)  #对于深层网络来说，激活函数用relu效果会比较好
        z = F.dropout(z, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        z = self.fc2(z) #第二层全链接
        z = F.relu(z)
        z = self.fc3(z) #第三层全链接
        z = F.relu(z)
        z = self.fc4(z) # 第四层全链接
        return z
    def set_filter_values(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为预训练式
        # 输入参数net为从硬盘加载的网络作为迁移源
        
        # 逐个儿为网络的两个卷积模块的权重和偏置进行赋值
        # 注意在赋值的时候需要用deepcopy而不能直接等于，或者copy。
        # 这是因为这种拷贝是将张量中的数值全部拷贝到了目标中，而不是拷贝地址
        # 如果不用deepcopy，由于我们将同一组参数（net.conv1.weight.data,bias）
        #  赋予了两组参数（net1_conv1.weight.data，net2_conv1.weight.data）
        # 所以它们会共享源net.conv1.weight.data中的地址，这样对于net1_conv1.weight.data
        # 的训练也自然会被用到了net2_conv1.weight.data中，但其实我们希望它们是两个不同的参数。
        self.net1_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net1_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net1_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net1_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        self.net2_conv1.weight.data = copy.deepcopy(net.conv1.weight.data)
        self.net2_conv1.bias.data = copy.deepcopy(net.conv1.bias.data)
        self.net2_conv2.weight.data = copy.deepcopy(net.conv2.weight.data)
        self.net2_conv2.bias.data = copy.deepcopy(net.conv2.bias.data)
        
        # 将变量加载到GPU上        
        self.net1_conv1 = self.net1_conv1.cuda() if use_cuda else self.net1_conv1
        self.net1_conv2 = self.net1_conv2.cuda() if use_cuda else self.net1_conv2
        
        self.net2_conv1 = self.net2_conv1.cuda() if use_cuda else self.net2_conv1
        self.net2_conv2 = self.net2_conv2.cuda() if use_cuda else self.net2_conv2
    def set_filter_values_nograd(self, net):
        # 本函数为迁移网络所用，即将迁移过来的网络的权重值拷贝到本网络中
        # 本函数对应的迁移为固定权重式
        # 调用set_filter_values为全部卷积核进行赋值
        self.set_filter_values(net)
        
        # 为了让我们的网络不被训练调整权值，我们需要设定每一个变量的requires_grad为False
        # 即不需要计算梯度值
        self.net1_conv1.weight.requires_grad = False
        self.net1_conv1.bias.requires_grad = False
        self.net1_conv2.weight.requires_grad = False
        self.net1_conv2.bias.requires_grad = False
        
        
        self.net2_conv1.weight.requires_grad = False
        self.net2_conv1.bias.requires_grad = False
        self.net2_conv2.weight.requires_grad = False
        self.net2_conv2.bias.requires_grad = False
def rightness(y, target):
    # 计算分类准确度的函数，y为模型预测的标签，target为数据的标签
    # 输入的y为一个矩阵，行对应了batch中的不同数据记录，列对应了不同的分类选择，数值对应了概率
    # 函数输出分别为预测与数据标签相等的个数，本次判断的所有数据个数
    out = torch.round(y.squeeze()).type(itype)
    out = out.eq(target).sum()
    out1 = y.size()[0]
    return(out, out1)

# %% [markdown]
# ## 四、数据迁移实验

# %% [markdown]
# ### 1. 无迁移实验
#
# 在本试验中，我们不迁移网络，直接训练整个网络

# %%
# 生成网络实例
net = Transfer()

# 如果存在GPU，则将网络加载到GPU中
if use_cuda:
    net = net.cuda()
    
# 定义损失函数，我们用最小均方误差来定义损失
criterion = nn.MSELoss()

# 定义优化器
optimizer = optim.SGD(net.parameters(), lr = 0.01, momentum = 0.95)
results = {}

# %%
# 开始训练网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    
    # 我们可以用zip命令来同时从两个数据加载器中加载数据，enumerate则给这个迭代附加上了计数
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        # 为了比较数据量大小对迁移学习的影响，我们只加载了部分数据，当数据加载个数idx大于
        # 全数据集的1/fraction的时候则不再加载后面的数据
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        optimizer.zero_grad()
        net.train()
        outputs = net(x1.clone().detach(), x2.clone().detach())
        labels = y1 + y2
        loss = criterion(outputs, labels.type(torch.float))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            # 在校验数据上计算计算准确率
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach(), x2.clone().detach())
                labels = y1 + y2
                
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])

# 在测试数据集上测试准确度
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach(), x2.clone().detach())
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
results['notransfer'] = [records, right_ratio]
# Out:
# D:\Deep_Learning\Anaconda\lib\site-packages\torch\nn\modules\loss.py:520: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# D:\Deep_Learning\Anaconda\lib\site-packages\torch\nn\modules\loss.py:520: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# 第0周期，第(0/938)个撮，训练误差：87.84595489501953, 校验误差：92.41, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：70.1146469116211, 校验误差：17.68, 准确率：0.09
# 第0周期，第(200/938)个撮，训练误差：44.064273834228516, 校验误差：17.06, 准确率：0.10
# 第0周期，第(300/938)个撮，训练误差：35.20755386352539, 校验误差：16.77, 准确率：0.10
# 第0周期，第(400/938)个撮，训练误差：30.62398910522461, 校验误差：17.00, 准确率：0.10
# 第0周期，第(500/938)个撮，训练误差：27.883127212524414, 校验误差：16.17, 准确率：0.10
# 第0周期，第(600/938)个撮，训练误差：26.048295974731445, 校验误差：16.66, 准确率：0.11
# 第0周期，第(700/938)个撮，训练误差：24.76921844482422, 校验误差：16.69, 准确率：0.11
# 第0周期，第(800/938)个撮，训练误差：23.792083740234375, 校验误差：16.83, 准确率：0.10
# 第0周期，第(900/938)个撮，训练误差：23.063093185424805, 校验误差：17.20, 准确率：0.09
# D:\Deep_Learning\Anaconda\lib\site-packages\torch\nn\modules\loss.py:520: UserWarning: Using a target size (torch.Size([32])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# 第1周期，第(0/938)个撮，训练误差：18.84446907043457, 校验误差：16.78, 准确率：0.10
# 第1周期，第(100/938)个撮，训练误差：17.014619827270508, 校验误差：16.83, 准确率：0.11
# 第1周期，第(200/938)个撮，训练误差：16.99190902709961, 校验误差：16.32, 准确率：0.10
# 第1周期，第(300/938)个撮，训练误差：16.903121948242188, 校验误差：16.56, 准确率：0.10
# 第1周期，第(400/938)个撮，训练误差：16.95234489440918, 校验误差：16.67, 准确率：0.10
# 第1周期，第(500/938)个撮，训练误差：16.897077560424805, 校验误差：16.99, 准确率：0.10
# 第1周期，第(600/938)个撮，训练误差：16.98577880859375, 校验误差：17.32, 准确率：0.10
# 第1周期，第(700/938)个撮，训练误差：16.924264907836914, 校验误差：16.63, 准确率：0.10
# 第1周期，第(800/938)个撮，训练误差：16.99102020263672, 校验误差：16.90, 准确率：0.10
# 第1周期，第(900/938)个撮，训练误差：17.01726531982422, 校验误差：16.51, 准确率：0.10
# 第2周期，第(0/938)个撮，训练误差：20.27923583984375, 校验误差：16.46, 准确率：0.10
# 第2周期，第(100/938)个撮，训练误差：16.967622756958008, 校验误差：16.84, 准确率：0.10
# 第2周期，第(200/938)个撮，训练误差：16.773311614990234, 校验误差：17.24, 准确率：0.10
# 第2周期，第(300/938)个撮，训练误差：16.724550247192383, 校验误差：16.79, 准确率：0.10
# 第2周期，第(400/938)个撮，训练误差：16.83370590209961, 校验误差：16.98, 准确率：0.10
# 第2周期，第(500/938)个撮，训练误差：16.860837936401367, 校验误差：16.85, 准确率：0.09
# 第2周期，第(600/938)个撮，训练误差：16.866235733032227, 校验误差：16.86, 准确率：0.11
# 第2周期，第(700/938)个撮，训练误差：16.800783157348633, 校验误差：16.42, 准确率：0.10
# 第2周期，第(800/938)个撮，训练误差：16.819196701049805, 校验误差：16.70, 准确率：0.10
# 第2周期，第(900/938)个撮，训练误差：16.823619842529297, 校验误差：16.59, 准确率：0.10
# 第3周期，第(0/938)个撮，训练误差：14.34821891784668, 校验误差：16.97, 准确率：0.09
# 第3周期，第(100/938)个撮，训练误差：16.745946884155273, 校验误差：16.46, 准确率：0.10
# 第3周期，第(200/938)个撮，训练误差：16.764265060424805, 校验误差：16.66, 准确率：0.10
# 第3周期，第(300/938)个撮，训练误差：16.8148136138916, 校验误差：16.48, 准确率：0.10
# 第3周期，第(400/938)个撮，训练误差：16.780086517333984, 校验误差：16.92, 准确率：0.10
# 第3周期，第(500/938)个撮，训练误差：16.77861785888672, 校验误差：16.82, 准确率：0.10
# 第3周期，第(600/938)个撮，训练误差：16.80321502685547, 校验误差：16.93, 准确率：0.10
# 第3周期，第(700/938)个撮，训练误差：16.791778564453125, 校验误差：16.76, 准确率：0.10
# 第3周期，第(800/938)个撮，训练误差：16.793331146240234, 校验误差：16.42, 准确率：0.10
# 第3周期，第(900/938)个撮，训练误差：16.7952823638916, 校验误差：16.45, 准确率：0.09
# 第4周期，第(0/938)个撮，训练误差：11.983936309814453, 校验误差：16.83, 准确率：0.11
# 第4周期，第(100/938)个撮，训练误差：17.201425552368164, 校验误差：16.82, 准确率：0.10
# 第4周期，第(200/938)个撮，训练误差：16.872285842895508, 校验误差：16.50, 准确率：0.10
# 第4周期，第(300/938)个撮，训练误差：16.793365478515625, 校验误差：16.90, 准确率：0.10
# 第4周期，第(400/938)个撮，训练误差：16.811573028564453, 校验误差：17.00, 准确率：0.10
# 第4周期，第(500/938)个撮，训练误差：16.758737564086914, 校验误差：16.59, 准确率：0.09
# 第4周期，第(600/938)个撮，训练误差：16.70997428894043, 校验误差：16.57, 准确率：0.10
# 第4周期，第(700/938)个撮，训练误差：16.70476531982422, 校验误差：16.67, 准确率：0.09
# 第4周期，第(800/938)个撮，训练误差：16.723865509033203, 校验误差：16.66, 准确率：0.09
# 第4周期，第(900/938)个撮，训练误差：16.75849723815918, 校验误差：16.72, 准确率：0.10
# 第5周期，第(0/938)个撮，训练误差：21.88271141052246, 校验误差：17.02, 准确率：0.10
# 第5周期，第(100/938)个撮，训练误差：16.47893524169922, 校验误差：16.92, 准确率：0.10
# 第5周期，第(200/938)个撮，训练误差：16.707687377929688, 校验误差：16.40, 准确率：0.10
# 第5周期，第(300/938)个撮，训练误差：16.75541114807129, 校验误差：16.83, 准确率：0.09
# 第5周期，第(400/938)个撮，训练误差：16.8164005279541, 校验误差：16.93, 准确率：0.09
# 第5周期，第(500/938)个撮，训练误差：16.77248191833496, 校验误差：16.84, 准确率：0.10
# 第5周期，第(600/938)个撮，训练误差：16.79592514038086, 校验误差：17.04, 准确率：0.09
# 第5周期，第(700/938)个撮，训练误差：16.846254348754883, 校验误差：16.84, 准确率：0.10
# 第5周期，第(800/938)个撮，训练误差：16.837921142578125, 校验误差：16.93, 准确率：0.10
# 第5周期，第(900/938)个撮，训练误差：16.826393127441406, 校验误差：16.79, 准确率：0.09
# 第6周期，第(0/938)个撮，训练误差：16.20557403564453, 校验误差：16.90, 准确率：0.10
# 第6周期，第(100/938)个撮，训练误差：16.649818420410156, 校验误差：17.03, 准确率：0.09
# 第6周期，第(200/938)个撮，训练误差：16.770448684692383, 校验误差：16.98, 准确率：0.10
# 第6周期，第(300/938)个撮，训练误差：16.829486846923828, 校验误差：16.84, 准确率：0.11
# 第6周期，第(400/938)个撮，训练误差：16.826976776123047, 校验误差：17.06, 准确率：0.10
# 第6周期，第(500/938)个撮，训练误差：16.829917907714844, 校验误差：16.59, 准确率：0.09
# 第6周期，第(600/938)个撮，训练误差：16.86546516418457, 校验误差：16.49, 准确率：0.11
# 第6周期，第(700/938)个撮，训练误差：16.852123260498047, 校验误差：16.70, 准确率：0.10
# 第6周期，第(800/938)个撮，训练误差：16.809223175048828, 校验误差：17.09, 准确率：0.10
# 第6周期，第(900/938)个撮，训练误差：16.782955169677734, 校验误差：16.91, 准确率：0.10
# 第7周期，第(0/938)个撮，训练误差：18.49015998840332, 校验误差：16.35, 准确率：0.10
# 第7周期，第(100/938)个撮，训练误差：16.70881462097168, 校验误差：16.73, 准确率：0.10
# 第7周期，第(200/938)个撮，训练误差：16.737958908081055, 校验误差：16.60, 准确率：0.09
# 第7周期，第(300/938)个撮，训练误差：16.905263900756836, 校验误差：17.05, 准确率：0.10
# 第7周期，第(400/938)个撮，训练误差：16.89039421081543, 校验误差：16.51, 准确率：0.09
# 第7周期，第(500/938)个撮，训练误差：16.857141494750977, 校验误差：16.68, 准确率：0.10
# 第7周期，第(600/938)个撮，训练误差：16.80223274230957, 校验误差：16.73, 准确率：0.10
# 第7周期，第(700/938)个撮，训练误差：16.801118850708008, 校验误差：16.52, 准确率：0.11
# 第7周期，第(800/938)个撮，训练误差：16.764314651489258, 校验误差：17.33, 准确率：0.10
# 第7周期，第(900/938)个撮，训练误差：16.728322982788086, 校验误差：16.73, 准确率：0.09
# 第8周期，第(0/938)个撮，训练误差：14.03485107421875, 校验误差：17.48, 准确率：0.09
# 第8周期，第(100/938)个撮，训练误差：16.664966583251953, 校验误差：16.64, 准确率：0.11
# 第8周期，第(200/938)个撮，训练误差：16.647289276123047, 校验误差：16.44, 准确率：0.11
# 第8周期，第(300/938)个撮，训练误差：16.620180130004883, 校验误差：16.63, 准确率：0.11
# 第8周期，第(400/938)个撮，训练误差：16.642913818359375, 校验误差：16.51, 准确率：0.10
# 第8周期，第(500/938)个撮，训练误差：16.770139694213867, 校验误差：16.59, 准确率：0.10
# 第8周期，第(600/938)个撮，训练误差：16.754539489746094, 校验误差：16.91, 准确率：0.10
# 第8周期，第(700/938)个撮，训练误差：16.757556915283203, 校验误差：16.63, 准确率：0.11
# 第8周期，第(800/938)个撮，训练误差：16.75531768798828, 校验误差：16.82, 准确率：0.09
# 第8周期，第(900/938)个撮，训练误差：16.731212615966797, 校验误差：17.03, 准确率：0.10
# 第9周期，第(0/938)个撮，训练误差：16.187957763671875, 校验误差：16.67, 准确率：0.10
# 第9周期，第(100/938)个撮，训练误差：17.04924201965332, 校验误差：16.79, 准确率：0.10
# 第9周期，第(200/938)个撮，训练误差：16.825292587280273, 校验误差：17.00, 准确率：0.11
# 第9周期，第(300/938)个撮，训练误差：16.74836540222168, 校验误差：16.99, 准确率：0.10
# 第9周期，第(400/938)个撮，训练误差：16.79315948486328, 校验误差：16.70, 准确率：0.10
# 第9周期，第(500/938)个撮，训练误差：16.837345123291016, 校验误差：16.81, 准确率：0.10
# 第9周期，第(600/938)个撮，训练误差：16.826980590820312, 校验误差：16.90, 准确率：0.10
# 第9周期，第(700/938)个撮，训练误差：16.883586883544922, 校验误差：16.41, 准确率：0.10
# 第9周期，第(800/938)个撮，训练误差：16.900667190551758, 校验误差：16.81, 准确率：0.10
# 第9周期，第(900/938)个撮，训练误差：16.871503829956055, 校验误差：16.81, 准确率：0.11
# 第10周期，第(0/938)个撮，训练误差：16.905345916748047, 校验误差：16.79, 准确率：0.10
# 第10周期，第(100/938)个撮，训练误差：16.69514274597168, 校验误差：16.95, 准确率：0.11
# 第10周期，第(200/938)个撮，训练误差：16.618038177490234, 校验误差：17.18, 准确率：0.10
# 第10周期，第(300/938)个撮，训练误差：16.720903396606445, 校验误差：16.56, 准确率：0.10
# 第10周期，第(400/938)个撮，训练误差：16.692745208740234, 校验误差：16.92, 准确率：0.09
# 第10周期，第(500/938)个撮，训练误差：16.665679931640625, 校验误差：16.27, 准确率：0.10
# 第10周期，第(600/938)个撮，训练误差：16.652965545654297, 校验误差：17.07, 准确率：0.10
# 第10周期，第(700/938)个撮，训练误差：16.672618865966797, 校验误差：16.86, 准确率：0.10
# 第10周期，第(800/938)个撮，训练误差：16.70997428894043, 校验误差：16.49, 准确率：0.09
# 第10周期，第(900/938)个撮，训练误差：16.743616104125977, 校验误差：16.51, 准确率：0.10
# 第11周期，第(0/938)个撮，训练误差：13.340835571289062, 校验误差：16.88, 准确率：0.11
# 第11周期，第(100/938)个撮，训练误差：16.83856201171875, 校验误差：17.13, 准确率：0.10
# 第11周期，第(200/938)个撮，训练误差：16.780799865722656, 校验误差：16.79, 准确率：0.10
# 第11周期，第(300/938)个撮，训练误差：16.7989559173584, 校验误差：16.51, 准确率：0.10
# 第11周期，第(400/938)个撮，训练误差：16.697404861450195, 校验误差：16.75, 准确率：0.10
# 第11周期，第(500/938)个撮，训练误差：16.737125396728516, 校验误差：16.74, 准确率：0.10
# 第11周期，第(600/938)个撮，训练误差：16.82181739807129, 校验误差：16.31, 准确率：0.11
# 第11周期，第(700/938)个撮，训练误差：16.812400817871094, 校验误差：16.76, 准确率：0.10
# 第11周期，第(800/938)个撮，训练误差：16.700010299682617, 校验误差：16.76, 准确率：0.11
# 第11周期，第(900/938)个撮，训练误差：16.687965393066406, 校验误差：16.62, 准确率：0.11
# 第12周期，第(0/938)个撮，训练误差：18.653593063354492, 校验误差：16.76, 准确率：0.09
# 第12周期，第(100/938)个撮，训练误差：16.91644287109375, 校验误差：17.00, 准确率：0.10
# 第12周期，第(200/938)个撮，训练误差：17.040334701538086, 校验误差：16.86, 准确率：0.11
# 第12周期，第(300/938)个撮，训练误差：17.022953033447266, 校验误差：17.23, 准确率：0.10
# 第12周期，第(400/938)个撮，训练误差：17.025236129760742, 校验误差：16.89, 准确率：0.09
# 第12周期，第(500/938)个撮，训练误差：17.00595474243164, 校验误差：16.70, 准确率：0.10
# 第12周期，第(600/938)个撮，训练误差：16.96979331970215, 校验误差：16.78, 准确率：0.09
# 第12周期，第(700/938)个撮，训练误差：16.959348678588867, 校验误差：16.93, 准确率：0.10
# 第12周期，第(800/938)个撮，训练误差：16.93412971496582, 校验误差：16.72, 准确率：0.10
# 第12周期，第(900/938)个撮，训练误差：16.89661407470703, 校验误差：16.96, 准确率：0.10
# 第13周期，第(0/938)个撮，训练误差：15.375617980957031, 校验误差：16.39, 准确率：0.11
# 第13周期，第(100/938)个撮，训练误差：17.058565139770508, 校验误差：16.78, 准确率：0.11
# 第13周期，第(200/938)个撮，训练误差：16.78949737548828, 校验误差：16.96, 准确率：0.10
# 第13周期，第(300/938)个撮，训练误差：16.722124099731445, 校验误差：16.71, 准确率：0.09
# 第13周期，第(400/938)个撮，训练误差：16.742782592773438, 校验误差：16.93, 准确率：0.10
# 第13周期，第(500/938)个撮，训练误差：16.752830505371094, 校验误差：16.82, 准确率：0.10
# 第13周期，第(600/938)个撮，训练误差：16.772436141967773, 校验误差：16.63, 准确率：0.10
# 第13周期，第(700/938)个撮，训练误差：16.789705276489258, 校验误差：17.01, 准确率：0.09
# 第13周期，第(800/938)个撮，训练误差：16.782169342041016, 校验误差：16.68, 准确率：0.10
# 第13周期，第(900/938)个撮，训练误差：16.782184600830078, 校验误差：16.83, 准确率：0.10
# 第14周期，第(0/938)个撮，训练误差：14.171976089477539, 校验误差：16.70, 准确率：0.11
# 第14周期，第(100/938)个撮，训练误差：16.923988342285156, 校验误差：16.96, 准确率：0.09
# 第14周期，第(200/938)个撮，训练误差：16.700136184692383, 校验误差：16.30, 准确率：0.11
# 第14周期，第(300/938)个撮，训练误差：16.768924713134766, 校验误差：16.72, 准确率：0.11
# 第14周期，第(400/938)个撮，训练误差：16.710742950439453, 校验误差：17.04, 准确率：0.10
# 第14周期，第(500/938)个撮，训练误差：16.766536712646484, 校验误差：16.80, 准确率：0.09
# 第14周期，第(600/938)个撮，训练误差：16.796411514282227, 校验误差：16.33, 准确率：0.10
# 第14周期，第(700/938)个撮，训练误差：16.81728172302246, 校验误差：16.39, 准确率：0.10
# 第14周期，第(800/938)个撮，训练误差：16.785736083984375, 校验误差：16.81, 准确率：0.10
# 第14周期，第(900/938)个撮，训练误差：16.83320426940918, 校验误差：16.85, 准确率：0.10
# 第15周期，第(0/938)个撮，训练误差：21.388412475585938, 校验误差：16.43, 准确率：0.10
# 第15周期，第(100/938)个撮，训练误差：16.676240921020508, 校验误差：17.21, 准确率：0.10
# 第15周期，第(200/938)个撮，训练误差：16.2769718170166, 校验误差：17.14, 准确率：0.09
# 第15周期，第(300/938)个撮，训练误差：16.353073120117188, 校验误差：16.28, 准确率：0.10
# 第15周期，第(400/938)个撮，训练误差：16.505966186523438, 校验误差：17.24, 准确率：0.10
# 第15周期，第(500/938)个撮，训练误差：16.593660354614258, 校验误差：16.76, 准确率：0.10
# 第15周期，第(600/938)个撮，训练误差：16.59553337097168, 校验误差：16.56, 准确率：0.10
# 第15周期，第(700/938)个撮，训练误差：16.560569763183594, 校验误差：16.68, 准确率：0.09
# 第15周期，第(800/938)个撮，训练误差：16.659284591674805, 校验误差：16.66, 准确率：0.10
# 第15周期，第(900/938)个撮，训练误差：16.724214553833008, 校验误差：16.76, 准确率：0.10
# 第16周期，第(0/938)个撮，训练误差：16.06584358215332, 校验误差：17.32, 准确率：0.10
# 第16周期，第(100/938)个撮，训练误差：16.623188018798828, 校验误差：16.69, 准确率：0.10
# 第16周期，第(200/938)个撮，训练误差：16.646682739257812, 校验误差：16.24, 准确率：0.11
# 第16周期，第(300/938)个撮，训练误差：16.665861129760742, 校验误差：17.02, 准确率：0.09
# 第16周期，第(400/938)个撮，训练误差：16.683141708374023, 校验误差：16.64, 准确率：0.10
# 第16周期，第(500/938)个撮，训练误差：16.608875274658203, 校验误差：16.66, 准确率：0.10
# 第16周期，第(600/938)个撮，训练误差：16.664474487304688, 校验误差：16.27, 准确率：0.10
# 第16周期，第(700/938)个撮，训练误差：16.635194778442383, 校验误差：17.01, 准确率：0.10
# 第16周期，第(800/938)个撮，训练误差：16.681739807128906, 校验误差：16.65, 准确率：0.10
# 第16周期，第(900/938)个撮，训练误差：16.722272872924805, 校验误差：16.64, 准确率：0.10
# 第17周期，第(0/938)个撮，训练误差：18.6785831451416, 校验误差：16.58, 准确率：0.10
# 第17周期，第(100/938)个撮，训练误差：17.07782554626465, 校验误差：16.51, 准确率：0.11
# 第17周期，第(200/938)个撮，训练误差：17.06220054626465, 校验误差：16.71, 准确率：0.10
# 第17周期，第(300/938)个撮，训练误差：16.874479293823242, 校验误差：16.77, 准确率：0.11
# 第17周期，第(400/938)个撮，训练误差：16.787208557128906, 校验误差：16.85, 准确率：0.10
# 第17周期，第(500/938)个撮，训练误差：16.753297805786133, 校验误差：16.80, 准确率：0.09
# 第17周期，第(600/938)个撮，训练误差：16.71117401123047, 校验误差：16.85, 准确率：0.10
# 第17周期，第(700/938)个撮，训练误差：16.78028678894043, 校验误差：16.42, 准确率：0.10
# 第17周期，第(800/938)个撮，训练误差：16.746047973632812, 校验误差：16.80, 准确率：0.10
# 第17周期，第(900/938)个撮，训练误差：16.727073669433594, 校验误差：16.39, 准确率：0.10
# 第18周期，第(0/938)个撮，训练误差：17.252338409423828, 校验误差：16.62, 准确率：0.10
# 第18周期，第(100/938)个撮，训练误差：16.33680534362793, 校验误差：16.94, 准确率：0.10
# 第18周期，第(200/938)个撮，训练误差：16.584890365600586, 校验误差：16.56, 准确率：0.10
# 第18周期，第(300/938)个撮，训练误差：16.715513229370117, 校验误差：16.90, 准确率：0.09
# 第18周期，第(400/938)个撮，训练误差：16.7482852935791, 校验误差：17.03, 准确率：0.09
# 第18周期，第(500/938)个撮，训练误差：16.812522888183594, 校验误差：16.89, 准确率：0.10
# 第18周期，第(600/938)个撮，训练误差：16.778615951538086, 校验误差：16.52, 准确率：0.10
# 第18周期，第(700/938)个撮，训练误差：16.80388641357422, 校验误差：16.80, 准确率：0.10
# 第18周期，第(800/938)个撮，训练误差：16.80829620361328, 校验误差：16.39, 准确率：0.10
# 第18周期，第(900/938)个撮，训练误差：16.830869674682617, 校验误差：16.75, 准确率：0.09
# 第19周期，第(0/938)个撮，训练误差：21.889272689819336, 校验误差：16.70, 准确率：0.10
# 第19周期，第(100/938)个撮，训练误差：16.868194580078125, 校验误差：16.98, 准确率：0.10
# 第19周期，第(200/938)个撮，训练误差：16.955547332763672, 校验误差：16.55, 准确率：0.10
# 第19周期，第(300/938)个撮，训练误差：16.915142059326172, 校验误差：16.76, 准确率：0.10
# 第19周期，第(400/938)个撮，训练误差：16.853342056274414, 校验误差：16.76, 准确率：0.10
# 第19周期，第(500/938)个撮，训练误差：16.842382431030273, 校验误差：16.62, 准确率：0.10
# 第19周期，第(600/938)个撮，训练误差：16.834394454956055, 校验误差：16.87, 准确率：0.10
# 第19周期，第(700/938)个撮，训练误差：16.852975845336914, 校验误差：16.40, 准确率：0.10
# 第19周期，第(800/938)个撮，训练误差：16.78317642211914, 校验误差：16.53, 准确率：0.10
# 第19周期，第(900/938)个撮，训练误差：16.760108947753906, 校验误差：16.53, 准确率：0.10

# %%
# 绘制实验结果，打印测试集上的准确度
plt.plot([i[0] for i in records])
plt.plot([i[1] for i in records])
plt.plot([100 * (1 - i[2]) for i in records])
right_ratio
# Out:
# 0.0952

# %% [markdown]
# ### 2. 迁移网络，预训练
#
# 在本试验中，我们将手写数字识别的卷积神经网络权重迁移过来，作为新的加法机网络的预训练值（也就是初始值）

# %%
net = Transfer()

# 为新网络赋予权重数值，注意我们只将卷积部分的网络进行迁移，而没有迁移全链接层
net.set_filter_values(original_net)

if use_cuda:
    net = net.cuda()

criterion = nn.MSELoss()

# 将需要训练的参数加载到优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad: #我们只将可以调整权重的变量加到了集合new_parameters
        new_parameters.append(para)
        
# 将new_parameters加载到了优化器中
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 开始训练网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
        labels = y1 + y2
        loss = criterion(outputs,labels.type(torch.float))
        loss.backward()
        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                labels = y1 + y2
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_pretrained'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：91.74, 校验误差：89.91, 准确率：0.02
# 第0周期，第(100/938)个撮，训练误差：24.97, 校验误差：18.30, 准确率：0.10
# 第0周期，第(200/938)个撮，训练误差：21.21, 校验误差：18.31, 准确率：0.09
# 第0周期，第(300/938)个撮，训练误差：20.12, 校验误差：17.56, 准确率：0.09
# 第0周期，第(400/938)个撮，训练误差：19.54, 校验误差：18.09, 准确率：0.10
# 第0周期，第(500/938)个撮，训练误差：19.18, 校验误差：16.96, 准确率：0.09
# 第0周期，第(600/938)个撮，训练误差：18.96, 校验误差：17.33, 准确率：0.09
# 第0周期，第(700/938)个撮，训练误差：18.75, 校验误差：17.41, 准确率：0.10
# 第0周期，第(800/938)个撮，训练误差：18.59, 校验误差：17.72, 准确率：0.09
# 第0周期，第(900/938)个撮，训练误差：18.51, 校验误差：17.39, 准确率：0.10
# 第1周期，第(0/938)个撮，训练误差：15.59, 校验误差：18.71, 准确率：0.08
# 第1周期，第(100/938)个撮，训练误差：17.16, 校验误差：16.82, 准确率：0.10
# 第1周期，第(200/938)个撮，训练误差：17.21, 校验误差：18.01, 准确率：0.09
# 第1周期，第(300/938)个撮，训练误差：17.30, 校验误差：17.91, 准确率：0.09
# 第1周期，第(400/938)个撮，训练误差：17.29, 校验误差：17.47, 准确率：0.09
# 第1周期，第(500/938)个撮，训练误差：17.22, 校验误差：17.44, 准确率：0.09
# 第1周期，第(600/938)个撮，训练误差：17.29, 校验误差：17.38, 准确率：0.10
# 第1周期，第(700/938)个撮，训练误差：17.34, 校验误差：16.90, 准确率：0.09
# 第1周期，第(800/938)个撮，训练误差：17.40, 校验误差：16.89, 准确率：0.10
# 第1周期，第(900/938)个撮，训练误差：17.44, 校验误差：16.99, 准确率：0.10
# 第2周期，第(0/938)个撮，训练误差：23.03, 校验误差：18.13, 准确率：0.08
# 第2周期，第(100/938)个撮，训练误差：17.56, 校验误差：16.93, 准确率：0.10
# 第2周期，第(200/938)个撮，训练误差：17.62, 校验误差：17.65, 准确率：0.10
# 第2周期，第(300/938)个撮，训练误差：17.49, 校验误差：17.03, 准确率：0.10
# 第2周期，第(400/938)个撮，训练误差：17.49, 校验误差：16.73, 准确率：0.10
# 第2周期，第(500/938)个撮，训练误差：17.54, 校验误差：17.44, 准确率：0.10
# 第2周期，第(600/938)个撮，训练误差：17.48, 校验误差：17.30, 准确率：0.09
# 第2周期，第(700/938)个撮，训练误差：17.48, 校验误差：16.54, 准确率：0.10
# 第2周期，第(800/938)个撮，训练误差：17.45, 校验误差：17.28, 准确率：0.09
# 第2周期，第(900/938)个撮，训练误差：17.45, 校验误差：17.16, 准确率：0.10
# 第3周期，第(0/938)个撮，训练误差：16.58, 校验误差：17.68, 准确率：0.09
# 第3周期，第(100/938)个撮，训练误差：16.96, 校验误差：17.49, 准确率：0.09
# 第3周期，第(200/938)个撮，训练误差：17.16, 校验误差：17.39, 准确率：0.09
# 第3周期，第(300/938)个撮，训练误差：17.27, 校验误差：16.56, 准确率：0.10
# 第3周期，第(400/938)个撮，训练误差：17.19, 校验误差：16.89, 准确率：0.10
# 第3周期，第(500/938)个撮，训练误差：17.16, 校验误差：16.56, 准确率：0.10
# 第3周期，第(600/938)个撮，训练误差：17.24, 校验误差：17.88, 准确率：0.08
# 第3周期，第(700/938)个撮，训练误差：17.22, 校验误差：17.59, 准确率：0.10
# 第3周期，第(800/938)个撮，训练误差：17.24, 校验误差：16.94, 准确率：0.10
# 第3周期，第(900/938)个撮，训练误差：17.29, 校验误差：17.07, 准确率：0.10
# 第4周期，第(0/938)个撮，训练误差：17.23, 校验误差：16.86, 准确率：0.10
# 第4周期，第(100/938)个撮，训练误差：17.39, 校验误差：17.31, 准确率：0.09
# 第4周期，第(200/938)个撮，训练误差：16.96, 校验误差：17.38, 准确率：0.09
# 第4周期，第(300/938)个撮，训练误差：16.97, 校验误差：16.57, 准确率：0.11
# 第4周期，第(400/938)个撮，训练误差：17.00, 校验误差：16.81, 准确率：0.09
# 第4周期，第(500/938)个撮，训练误差：17.11, 校验误差：17.17, 准确率：0.10
# 第4周期，第(600/938)个撮，训练误差：17.12, 校验误差：16.73, 准确率：0.10
# 第4周期，第(700/938)个撮，训练误差：17.17, 校验误差：17.48, 准确率：0.09
# 第4周期，第(800/938)个撮，训练误差：17.16, 校验误差：17.45, 准确率：0.09
# 第4周期，第(900/938)个撮，训练误差：17.20, 校验误差：17.80, 准确率：0.09
# 第5周期，第(0/938)个撮，训练误差：17.33, 校验误差：16.75, 准确率：0.09
# 第5周期，第(100/938)个撮，训练误差：17.87, 校验误差：17.16, 准确率：0.10
# 第5周期，第(200/938)个撮，训练误差：17.54, 校验误差：17.27, 准确率：0.10
# 第5周期，第(300/938)个撮，训练误差：17.29, 校验误差：17.52, 准确率：0.09
# 第5周期，第(400/938)个撮，训练误差：17.28, 校验误差：17.22, 准确率：0.10
# 第5周期，第(500/938)个撮，训练误差：17.38, 校验误差：16.86, 准确率：0.10
# 第5周期，第(600/938)个撮，训练误差：17.29, 校验误差：16.76, 准确率：0.10
# 第5周期，第(700/938)个撮，训练误差：17.31, 校验误差：17.45, 准确率：0.09
# 第5周期，第(800/938)个撮，训练误差：17.30, 校验误差：16.77, 准确率：0.10
# 第5周期，第(900/938)个撮，训练误差：17.28, 校验误差：17.60, 准确率：0.09
# 第6周期，第(0/938)个撮，训练误差：20.44, 校验误差：16.92, 准确率：0.10
# 第6周期，第(100/938)个撮，训练误差：17.19, 校验误差：17.48, 准确率：0.09
# 第6周期，第(200/938)个撮，训练误差：17.37, 校验误差：16.53, 准确率：0.10
# 第6周期，第(300/938)个撮，训练误差：17.46, 校验误差：18.15, 准确率：0.09
# 第6周期，第(400/938)个撮，训练误差：17.43, 校验误差：17.24, 准确率：0.10
# 第6周期，第(500/938)个撮，训练误差：17.30, 校验误差：17.06, 准确率：0.09
# 第6周期，第(600/938)个撮，训练误差：17.27, 校验误差：16.75, 准确率：0.10
# 第6周期，第(700/938)个撮，训练误差：17.26, 校验误差：16.79, 准确率：0.10
# 第6周期，第(800/938)个撮，训练误差：17.22, 校验误差：17.23, 准确率：0.10
# 第6周期，第(900/938)个撮，训练误差：17.19, 校验误差：17.31, 准确率：0.10
# 第7周期，第(0/938)个撮，训练误差：14.47, 校验误差：16.81, 准确率：0.10
# 第7周期，第(100/938)个撮，训练误差：17.16, 校验误差：17.31, 准确率：0.10
# 第7周期，第(200/938)个撮，训练误差：17.12, 校验误差：16.66, 准确率：0.10
# 第7周期，第(300/938)个撮，训练误差：17.08, 校验误差：16.92, 准确率：0.10
# 第7周期，第(400/938)个撮，训练误差：17.11, 校验误差：16.85, 准确率：0.09
# 第7周期，第(500/938)个撮，训练误差：17.13, 校验误差：16.81, 准确率：0.10
# 第7周期，第(600/938)个撮，训练误差：17.13, 校验误差：17.20, 准确率：0.09
# 第7周期，第(700/938)个撮，训练误差：17.11, 校验误差：17.49, 准确率：0.09
# 第7周期，第(800/938)个撮，训练误差：17.09, 校验误差：18.22, 准确率：0.09
# 第7周期，第(900/938)个撮，训练误差：17.09, 校验误差：16.84, 准确率：0.10
# 第8周期，第(0/938)个撮，训练误差：15.69, 校验误差：16.73, 准确率：0.09
# 第8周期，第(100/938)个撮，训练误差：17.19, 校验误差：17.75, 准确率：0.09
# 第8周期，第(200/938)个撮，训练误差：17.10, 校验误差：16.97, 准确率：0.10
# 第8周期，第(300/938)个撮，训练误差：16.89, 校验误差：17.11, 准确率：0.10
# 第8周期，第(400/938)个撮，训练误差：16.96, 校验误差：17.10, 准确率：0.10
# 第8周期，第(500/938)个撮，训练误差：16.93, 校验误差：16.66, 准确率：0.09
# 第8周期，第(600/938)个撮，训练误差：16.89, 校验误差：17.53, 准确率：0.09
# 第8周期，第(700/938)个撮，训练误差：16.94, 校验误差：17.65, 准确率：0.08
# 第8周期，第(800/938)个撮，训练误差：16.97, 校验误差：17.27, 准确率：0.09
# 第8周期，第(900/938)个撮，训练误差：17.02, 校验误差：16.79, 准确率：0.10
# 第9周期，第(0/938)个撮，训练误差：20.10, 校验误差：16.87, 准确率：0.10
# 第9周期，第(100/938)个撮，训练误差：17.43, 校验误差：17.05, 准确率：0.09
# 第9周期，第(200/938)个撮，训练误差：16.91, 校验误差：17.33, 准确率：0.10
# 第9周期，第(300/938)个撮，训练误差：16.93, 校验误差：17.01, 准确率：0.10
# 第9周期，第(400/938)个撮，训练误差：17.00, 校验误差：17.26, 准确率：0.10
# 第9周期，第(500/938)个撮，训练误差：16.99, 校验误差：17.02, 准确率：0.11
# 第9周期，第(600/938)个撮，训练误差：17.03, 校验误差：16.84, 准确率：0.10
# 第9周期，第(700/938)个撮，训练误差：17.05, 校验误差：17.06, 准确率：0.09
# 第9周期，第(800/938)个撮，训练误差：17.08, 校验误差：17.70, 准确率：0.09
# 第9周期，第(900/938)个撮，训练误差：17.10, 校验误差：17.45, 准确率：0.10
# 第10周期，第(0/938)个撮，训练误差：18.05, 校验误差：17.73, 准确率：0.09
# 第10周期，第(100/938)个撮，训练误差：16.96, 校验误差：17.39, 准确率：0.09
# 第10周期，第(200/938)个撮，训练误差：17.01, 校验误差：17.17, 准确率：0.09
# 第10周期，第(300/938)个撮，训练误差：17.05, 校验误差：16.81, 准确率：0.10
# 第10周期，第(400/938)个撮，训练误差：16.91, 校验误差：16.56, 准确率：0.10
# 第10周期，第(500/938)个撮，训练误差：16.99, 校验误差：16.86, 准确率：0.09
# 第10周期，第(600/938)个撮，训练误差：16.98, 校验误差：17.03, 准确率：0.10
# 第10周期，第(700/938)个撮，训练误差：17.04, 校验误差：16.92, 准确率：0.09
# 第10周期，第(800/938)个撮，训练误差：17.01, 校验误差：16.81, 准确率：0.10
# 第10周期，第(900/938)个撮，训练误差：16.98, 校验误差：16.93, 准确率：0.10
# 第11周期，第(0/938)个撮，训练误差：16.25, 校验误差：16.79, 准确率：0.09
# 第11周期，第(100/938)个撮，训练误差：17.06, 校验误差：17.16, 准确率：0.10
# 第11周期，第(200/938)个撮，训练误差：16.90, 校验误差：17.15, 准确率：0.09
# 第11周期，第(300/938)个撮，训练误差：17.00, 校验误差：16.78, 准确率：0.09
# 第11周期，第(400/938)个撮，训练误差：17.02, 校验误差：17.32, 准确率：0.09
# 第11周期，第(500/938)个撮，训练误差：16.96, 校验误差：16.74, 准确率：0.11
# 第11周期，第(600/938)个撮，训练误差：17.02, 校验误差：16.66, 准确率：0.08
# 第11周期，第(700/938)个撮，训练误差：17.05, 校验误差：16.78, 准确率：0.10
# 第11周期，第(800/938)个撮，训练误差：17.00, 校验误差：17.03, 准确率：0.09
# 第11周期，第(900/938)个撮，训练误差：17.06, 校验误差：16.64, 准确率：0.10
# 第12周期，第(0/938)个撮，训练误差：18.93, 校验误差：16.76, 准确率：0.10
# 第12周期，第(100/938)个撮，训练误差：16.59, 校验误差：17.68, 准确率：0.09
# 第12周期，第(200/938)个撮，训练误差：16.84, 校验误差：17.25, 准确率：0.09
# 第12周期，第(300/938)个撮，训练误差：16.86, 校验误差：16.74, 准确率：0.11
# 第12周期，第(400/938)个撮，训练误差：16.84, 校验误差：16.74, 准确率：0.09
# 第12周期，第(500/938)个撮，训练误差：16.85, 校验误差：16.91, 准确率：0.10
# 第12周期，第(600/938)个撮，训练误差：16.85, 校验误差：17.38, 准确率：0.09
# 第12周期，第(700/938)个撮，训练误差：16.90, 校验误差：16.80, 准确率：0.09
# 第12周期，第(800/938)个撮，训练误差：16.93, 校验误差：17.22, 准确率：0.09
# 第12周期，第(900/938)个撮，训练误差：16.93, 校验误差：16.75, 准确率：0.10
# 第13周期，第(0/938)个撮，训练误差：16.94, 校验误差：16.86, 准确率：0.11
# 第13周期，第(100/938)个撮，训练误差：16.46, 校验误差：17.08, 准确率：0.10
# 第13周期，第(200/938)个撮，训练误差：16.74, 校验误差：16.63, 准确率：0.10
# 第13周期，第(300/938)个撮，训练误差：16.91, 校验误差：17.18, 准确率：0.10
# 第13周期，第(400/938)个撮，训练误差：16.80, 校验误差：16.65, 准确率：0.10
# 第13周期，第(500/938)个撮，训练误差：16.74, 校验误差：16.68, 准确率：0.10
# 第13周期，第(600/938)个撮，训练误差：16.75, 校验误差：16.82, 准确率：0.10
# 第13周期，第(700/938)个撮，训练误差：16.80, 校验误差：16.80, 准确率：0.09
# 第13周期，第(800/938)个撮，训练误差：16.86, 校验误差：16.86, 准确率：0.09
# 第13周期，第(900/938)个撮，训练误差：16.90, 校验误差：16.53, 准确率：0.10
# 第14周期，第(0/938)个撮，训练误差：18.67, 校验误差：16.72, 准确率：0.10
# 第14周期，第(100/938)个撮，训练误差：16.89, 校验误差：16.55, 准确率：0.10
# 第14周期，第(200/938)个撮，训练误差：16.78, 校验误差：16.53, 准确率：0.09
# 第14周期，第(300/938)个撮，训练误差：16.91, 校验误差：17.29, 准确率：0.10
# 第14周期，第(400/938)个撮，训练误差：16.93, 校验误差：16.77, 准确率：0.10
# 第14周期，第(500/938)个撮，训练误差：16.93, 校验误差：16.60, 准确率：0.10
# 第14周期，第(600/938)个撮，训练误差：16.95, 校验误差：16.59, 准确率：0.10
# 第14周期，第(700/938)个撮，训练误差：17.01, 校验误差：16.65, 准确率：0.10
# 第14周期，第(800/938)个撮，训练误差：16.99, 校验误差：16.42, 准确率：0.10
# 第14周期，第(900/938)个撮，训练误差：17.00, 校验误差：16.28, 准确率：0.10
# 第15周期，第(0/938)个撮，训练误差：20.13, 校验误差：16.87, 准确率：0.10
# 第15周期，第(100/938)个撮，训练误差：17.10, 校验误差：16.71, 准确率：0.10
# 第15周期，第(200/938)个撮，训练误差：16.91, 校验误差：16.71, 准确率：0.10
# 第15周期，第(300/938)个撮，训练误差：17.02, 校验误差：16.75, 准确率：0.10
# 第15周期，第(400/938)个撮，训练误差：16.97, 校验误差：16.99, 准确率：0.09
# 第15周期，第(500/938)个撮，训练误差：16.97, 校验误差：16.96, 准确率：0.10
# 第15周期，第(600/938)个撮，训练误差：16.98, 校验误差：17.20, 准确率：0.10
# 第15周期，第(700/938)个撮，训练误差：16.95, 校验误差：16.99, 准确率：0.09
# 第15周期，第(800/938)个撮，训练误差：16.93, 校验误差：17.33, 准确率：0.10
# 第15周期，第(900/938)个撮，训练误差：16.93, 校验误差：16.97, 准确率：0.11
# 第16周期，第(0/938)个撮，训练误差：17.25, 校验误差：17.11, 准确率：0.09
# 第16周期，第(100/938)个撮，训练误差：16.72, 校验误差：17.03, 准确率：0.09
# 第16周期，第(200/938)个撮，训练误差：16.87, 校验误差：16.80, 准确率：0.10
# 第16周期，第(300/938)个撮，训练误差：16.96, 校验误差：16.68, 准确率：0.10
# 第16周期，第(400/938)个撮，训练误差：16.87, 校验误差：16.78, 准确率：0.09
# 第16周期，第(500/938)个撮，训练误差：16.92, 校验误差：17.03, 准确率：0.10
# 第16周期，第(600/938)个撮，训练误差：16.96, 校验误差：16.24, 准确率：0.10
# 第16周期，第(700/938)个撮，训练误差：16.96, 校验误差：16.86, 准确率：0.09
# 第16周期，第(800/938)个撮，训练误差：16.99, 校验误差：16.71, 准确率：0.09
# 第16周期，第(900/938)个撮，训练误差：16.97, 校验误差：16.72, 准确率：0.10
# 第17周期，第(0/938)个撮，训练误差：12.33, 校验误差：16.95, 准确率：0.10
# 第17周期，第(100/938)个撮，训练误差：16.89, 校验误差：16.71, 准确率：0.10
# 第17周期，第(200/938)个撮，训练误差：16.90, 校验误差：17.20, 准确率：0.10
# 第17周期，第(300/938)个撮，训练误差：16.79, 校验误差：16.85, 准确率：0.11
# 第17周期，第(400/938)个撮，训练误差：16.75, 校验误差：16.84, 准确率：0.10
# 第17周期，第(500/938)个撮，训练误差：16.75, 校验误差：16.53, 准确率：0.10
# 第17周期，第(600/938)个撮，训练误差：16.66, 校验误差：16.62, 准确率：0.09
# 第17周期，第(700/938)个撮，训练误差：16.69, 校验误差：17.06, 准确率：0.10
# 第17周期，第(800/938)个撮，训练误差：16.72, 校验误差：16.80, 准确率：0.09
# 第17周期，第(900/938)个撮，训练误差：16.69, 校验误差：16.99, 准确率：0.09
# 第18周期，第(0/938)个撮，训练误差：16.89, 校验误差：17.00, 准确率：0.10
# 第18周期，第(100/938)个撮，训练误差：16.40, 校验误差：16.42, 准确率：0.09
# 第18周期，第(200/938)个撮，训练误差：16.40, 校验误差：16.71, 准确率：0.10
# 第18周期，第(300/938)个撮，训练误差：16.53, 校验误差：17.07, 准确率：0.09
# 第18周期，第(400/938)个撮，训练误差：16.52, 校验误差：16.82, 准确率：0.10
# 第18周期，第(500/938)个撮，训练误差：16.62, 校验误差：16.67, 准确率：0.11
# 第18周期，第(600/938)个撮，训练误差：16.68, 校验误差：16.87, 准确率：0.10
# 第18周期，第(700/938)个撮，训练误差：16.64, 校验误差：16.92, 准确率：0.10
# 第18周期，第(800/938)个撮，训练误差：16.73, 校验误差：16.74, 准确率：0.10
# 第18周期，第(900/938)个撮，训练误差：16.72, 校验误差：16.88, 准确率：0.10
# 第19周期，第(0/938)个撮，训练误差：14.19, 校验误差：16.61, 准确率：0.10
# 第19周期，第(100/938)个撮，训练误差：16.57, 校验误差：17.22, 准确率：0.10
# 第19周期，第(200/938)个撮，训练误差：16.51, 校验误差：16.99, 准确率：0.09
# 第19周期，第(300/938)个撮，训练误差：16.60, 校验误差：16.86, 准确率：0.09
# 第19周期，第(400/938)个撮，训练误差：16.67, 校验误差：16.76, 准确率：0.09
# 第19周期，第(500/938)个撮，训练误差：16.75, 校验误差：16.46, 准确率：0.11
# 第19周期，第(600/938)个撮，训练误差：16.70, 校验误差：17.09, 准确率：0.10
# 第19周期，第(700/938)个撮，训练误差：16.67, 校验误差：16.43, 准确率：0.11
# 第19周期，第(800/938)个撮，训练误差：16.70, 校验误差：16.74, 准确率：0.10
# 第19周期，第(900/938)个撮，训练误差：16.72, 校验误差：16.78, 准确率：0.09

# %%
plt.plot([1 - i[2] for i in records])
right_ratio
# Out:
# 0.102

# %% [markdown]
# ### 3.迁移，不更新权重
#
# 在这个试验中，我们首先将识别器的卷积层的权重全部迁移到了加法机的两个卷积部件中，但保持它们的权重不变，只允许后面的全链接层的权重可训练。

# %%
net = Transfer()
# 迁移网络，并设置卷积部件的权重和偏置都不计算梯度
net.set_filter_values_nograd(original_net)
if use_cuda:
    net = net.cuda()
criterion = nn.MSELoss()

# 只将可更新的权重值加载到了优化器中
new_parameters = []
for para in net.parameters():
    if para.requires_grad:
        new_parameters.append(para)
optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)

# %%
# 训练整个网络
num_epochs = 20
records = []
for epoch in range(num_epochs):
    losses = []
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        if idx >= (len(train_loader1) // fraction):
            break
        ((x1, y1), (x2, y2)) = data
        if use_cuda:
            x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
        net.train()
        optimizer.zero_grad()
        outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
        labels = y1 + y2
        labels = labels.type(dtype)
        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()
        loss = loss.cpu() if use_cuda else loss
        losses.append(loss.data.numpy())
        if idx % 100 == 0:
            val_losses = []
            rights = []
            net.eval()
            for val_data in zip(val_loader1, val_loader2):
                ((x1, y1), (x2, y2)) = val_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                labels = y1 + y2
                loss = criterion(outputs, labels.type(torch.float))
                loss = loss.cpu() if use_cuda else loss
                val_losses.append(loss.data.numpy())
                
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
rights = []
net.eval()
for test_data in zip(test_loader1, test_loader2):
    ((x1, y1), (x2, y2)) = test_data
    if use_cuda:
        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
    labels = y1 + y2
    loss = criterion(outputs, labels.type(torch.float))
    right = rightness(outputs.data, labels)
    rights.append(right)
right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
results['transfer_fixed'] = [records, right_ratio]
# Out:
# 第0周期，第(0/938)个撮，训练误差：96.60, 校验误差：97.22, 准确率：0.01
# 第0周期，第(100/938)个撮，训练误差：25.75, 校验误差：18.85, 准确率：0.09
# 第0周期，第(200/938)个撮，训练误差：21.76, 校验误差：17.54, 准确率：0.09
# 第0周期，第(300/938)个撮，训练误差：20.49, 校验误差：20.39, 准确率：0.08
# 第0周期，第(400/938)个撮，训练误差：19.93, 校验误差：17.06, 准确率：0.09
# 第0周期，第(500/938)个撮，训练误差：19.54, 校验误差：17.21, 准确率：0.10
# 第0周期，第(600/938)个撮，训练误差：19.24, 校验误差：17.24, 准确率：0.10
# 第0周期，第(700/938)个撮，训练误差：18.97, 校验误差：17.30, 准确率：0.09
# 第0周期，第(800/938)个撮，训练误差：18.86, 校验误差：17.09, 准确率：0.09
# 第0周期，第(900/938)个撮，训练误差：18.77, 校验误差：17.91, 准确率：0.09
# 第1周期，第(0/938)个撮，训练误差：20.32, 校验误差：17.94, 准确率：0.08
# 第1周期，第(100/938)个撮，训练误差：18.29, 校验误差：17.08, 准确率：0.10
# 第1周期，第(200/938)个撮，训练误差：17.69, 校验误差：17.23, 准确率：0.10
# 第1周期，第(300/938)个撮，训练误差：17.57, 校验误差：16.97, 准确率：0.10
# 第1周期，第(400/938)个撮，训练误差：17.62, 校验误差：17.55, 准确率：0.09
# 第1周期，第(500/938)个撮，训练误差：17.56, 校验误差：17.44, 准确率：0.10
# 第1周期，第(600/938)个撮，训练误差：17.56, 校验误差：17.15, 准确率：0.09
# 第1周期，第(700/938)个撮，训练误差：17.60, 校验误差：17.87, 准确率：0.09
# 第1周期，第(800/938)个撮，训练误差：17.61, 校验误差：17.18, 准确率：0.09
# 第1周期，第(900/938)个撮，训练误差：17.59, 校验误差：17.43, 准确率：0.10
# 第2周期，第(0/938)个撮，训练误差：15.36, 校验误差：16.92, 准确率：0.10
# 第2周期，第(100/938)个撮，训练误差：17.22, 校验误差：17.01, 准确率：0.10
# 第2周期，第(200/938)个撮，训练误差：17.17, 校验误差：17.07, 准确率：0.09
# 第2周期，第(300/938)个撮，训练误差：17.31, 校验误差：17.96, 准确率：0.10
# 第2周期，第(400/938)个撮，训练误差：17.46, 校验误差：17.41, 准确率：0.09
# 第2周期，第(500/938)个撮，训练误差：17.50, 校验误差：17.15, 准确率：0.10
# 第2周期，第(600/938)个撮，训练误差：17.55, 校验误差：17.14, 准确率：0.10
# 第2周期，第(700/938)个撮，训练误差：17.53, 校验误差：17.20, 准确率：0.10
# 第2周期，第(800/938)个撮，训练误差：17.57, 校验误差：17.01, 准确率：0.10
# 第2周期，第(900/938)个撮，训练误差：17.59, 校验误差：18.01, 准确率：0.09
# 第3周期，第(0/938)个撮，训练误差：17.48, 校验误差：17.38, 准确率：0.10
# 第3周期，第(100/938)个撮，训练误差：17.36, 校验误差：17.02, 准确率：0.10
# 第3周期，第(200/938)个撮，训练误差：17.46, 校验误差：17.33, 准确率：0.10
# 第3周期，第(300/938)个撮，训练误差：17.54, 校验误差：16.90, 准确率：0.10
# 第3周期，第(400/938)个撮，训练误差：17.52, 校验误差：17.29, 准确率：0.10
# 第3周期，第(500/938)个撮，训练误差：17.43, 校验误差：16.81, 准确率：0.10
# 第3周期，第(600/938)个撮，训练误差：17.43, 校验误差：17.26, 准确率：0.10
# 第3周期，第(700/938)个撮，训练误差：17.44, 校验误差：17.22, 准确率：0.09
# 第3周期，第(800/938)个撮，训练误差：17.43, 校验误差：17.62, 准确率：0.09
# 第3周期，第(900/938)个撮，训练误差：17.46, 校验误差：17.68, 准确率：0.09
# 第4周期，第(0/938)个撮，训练误差：13.78, 校验误差：17.13, 准确率：0.10
# 第4周期，第(100/938)个撮，训练误差：17.69, 校验误差：17.18, 准确率：0.10
# 第4周期，第(200/938)个撮，训练误差：17.60, 校验误差：18.87, 准确率：0.08
# 第4周期，第(300/938)个撮，训练误差：17.61, 校验误差：16.82, 准确率：0.10
# 第4周期，第(400/938)个撮，训练误差：17.51, 校验误差：17.12, 准确率：0.09
# 第4周期，第(500/938)个撮，训练误差：17.45, 校验误差：17.33, 准确率：0.09
# 第4周期，第(600/938)个撮，训练误差：17.38, 校验误差：17.03, 准确率：0.10
# 第4周期，第(700/938)个撮，训练误差：17.37, 校验误差：17.24, 准确率：0.09
# 第4周期，第(800/938)个撮，训练误差：17.40, 校验误差：17.77, 准确率：0.09
# 第4周期，第(900/938)个撮，训练误差：17.41, 校验误差：17.55, 准确率：0.10
# 第5周期，第(0/938)个撮，训练误差：16.90, 校验误差：17.33, 准确率：0.08
# 第5周期，第(100/938)个撮，训练误差：17.62, 校验误差：17.91, 准确率：0.09
# 第5周期，第(200/938)个撮，训练误差：17.63, 校验误差：19.22, 准确率：0.08
# 第5周期，第(300/938)个撮，训练误差：17.57, 校验误差：16.56, 准确率：0.10
# 第5周期，第(400/938)个撮，训练误差：17.48, 校验误差：17.47, 准确率：0.09
# 第5周期，第(500/938)个撮，训练误差：17.47, 校验误差：16.98, 准确率：0.10
# 第5周期，第(600/938)个撮，训练误差：17.37, 校验误差：17.54, 准确率：0.10
# 第5周期，第(700/938)个撮，训练误差：17.33, 校验误差：16.63, 准确率：0.10
# 第5周期，第(800/938)个撮，训练误差：17.29, 校验误差：17.28, 准确率：0.10
# 第5周期，第(900/938)个撮，训练误差：17.30, 校验误差：17.74, 准确率：0.09
# 第6周期，第(0/938)个撮，训练误差：15.37, 校验误差：16.79, 准确率：0.10
# 第6周期，第(100/938)个撮，训练误差：17.29, 校验误差：17.36, 准确率：0.09
# 第6周期，第(200/938)个撮，训练误差：17.22, 校验误差：17.08, 准确率：0.09
# 第6周期，第(300/938)个撮，训练误差：17.33, 校验误差：17.60, 准确率：0.08
# 第6周期，第(400/938)个撮，训练误差：17.27, 校验误差：17.36, 准确率：0.10
# 第6周期，第(500/938)个撮，训练误差：17.19, 校验误差：17.33, 准确率：0.10
# 第6周期，第(600/938)个撮，训练误差：17.19, 校验误差：17.36, 准确率：0.10
# 第6周期，第(700/938)个撮，训练误差：17.21, 校验误差：17.93, 准确率：0.09
# 第6周期，第(800/938)个撮，训练误差：17.25, 校验误差：17.36, 准确率：0.09
# 第6周期，第(900/938)个撮，训练误差：17.23, 校验误差：17.57, 准确率：0.09
# 第7周期，第(0/938)个撮，训练误差：14.29, 校验误差：17.22, 准确率：0.10
# 第7周期，第(100/938)个撮，训练误差：16.72, 校验误差：16.77, 准确率：0.10
# 第7周期，第(200/938)个撮，训练误差：16.85, 校验误差：16.93, 准确率：0.10
# 第7周期，第(300/938)个撮，训练误差：17.01, 校验误差：17.32, 准确率：0.09
# 第7周期，第(400/938)个撮，训练误差：17.11, 校验误差：16.76, 准确率：0.10
# 第7周期，第(500/938)个撮，训练误差：17.15, 校验误差：17.18, 准确率：0.11
# 第7周期，第(600/938)个撮，训练误差：17.11, 校验误差：17.50, 准确率：0.09
# 第7周期，第(700/938)个撮，训练误差：17.16, 校验误差：18.02, 准确率：0.09
# 第7周期，第(800/938)个撮，训练误差：17.21, 校验误差：17.23, 准确率：0.09
# 第7周期，第(900/938)个撮，训练误差：17.22, 校验误差：17.05, 准确率：0.09
# 第8周期，第(0/938)个撮，训练误差：15.30, 校验误差：16.74, 准确率：0.10
# 第8周期，第(100/938)个撮，训练误差：17.27, 校验误差：17.01, 准确率：0.09
# 第8周期，第(200/938)个撮，训练误差：17.05, 校验误差：16.93, 准确率：0.10
# 第8周期，第(300/938)个撮，训练误差：17.09, 校验误差：17.05, 准确率：0.10
# 第8周期，第(400/938)个撮，训练误差：17.06, 校验误差：16.97, 准确率：0.10
# 第8周期，第(500/938)个撮，训练误差：17.13, 校验误差：17.01, 准确率：0.11
# 第8周期，第(600/938)个撮，训练误差：17.20, 校验误差：17.66, 准确率：0.08
# 第8周期，第(700/938)个撮，训练误差：17.13, 校验误差：17.07, 准确率：0.09
# 第8周期，第(800/938)个撮，训练误差：17.11, 校验误差：16.93, 准确率：0.10
# 第8周期，第(900/938)个撮，训练误差：17.10, 校验误差：17.55, 准确率：0.09
# 第9周期，第(0/938)个撮，训练误差：15.21, 校验误差：16.92, 准确率：0.10
# 第9周期，第(100/938)个撮，训练误差：16.85, 校验误差：16.91, 准确率：0.09
# 第9周期，第(200/938)个撮，训练误差：17.05, 校验误差：16.94, 准确率：0.09
# 第9周期，第(300/938)个撮，训练误差：16.96, 校验误差：17.91, 准确率：0.09
# 第9周期，第(400/938)个撮，训练误差：16.98, 校验误差：17.04, 准确率：0.09
# 第9周期，第(500/938)个撮，训练误差：17.09, 校验误差：16.81, 准确率：0.11
# 第9周期，第(600/938)个撮，训练误差：17.12, 校验误差：16.57, 准确率：0.10
# 第9周期，第(700/938)个撮，训练误差：17.04, 校验误差：17.09, 准确率：0.09
# 第9周期，第(800/938)个撮，训练误差：17.06, 校验误差：16.42, 准确率：0.10
# 第9周期，第(900/938)个撮，训练误差：17.08, 校验误差：16.71, 准确率：0.10
# 第10周期，第(0/938)个撮，训练误差：14.26, 校验误差：17.60, 准确率：0.09
# 第10周期，第(100/938)个撮，训练误差：17.13, 校验误差：16.49, 准确率：0.10
# 第10周期，第(200/938)个撮，训练误差：17.04, 校验误差：17.40, 准确率：0.09
# 第10周期，第(300/938)个撮，训练误差：17.13, 校验误差：17.60, 准确率：0.09
# 第10周期，第(400/938)个撮，训练误差：17.16, 校验误差：17.31, 准确率：0.09
# 第10周期，第(500/938)个撮，训练误差：17.10, 校验误差：16.90, 准确率：0.09
# 第10周期，第(600/938)个撮，训练误差：17.05, 校验误差：16.69, 准确率：0.09
# 第10周期，第(700/938)个撮，训练误差：17.02, 校验误差：17.53, 准确率：0.09
# 第10周期，第(800/938)个撮，训练误差：16.99, 校验误差：16.78, 准确率：0.10
# 第10周期，第(900/938)个撮，训练误差：17.02, 校验误差：17.27, 准确率：0.10
# 第11周期，第(0/938)个撮，训练误差：12.32, 校验误差：16.59, 准确率：0.10
# 第11周期，第(100/938)个撮，训练误差：17.11, 校验误差：16.29, 准确率：0.10
# 第11周期，第(200/938)个撮，训练误差：16.84, 校验误差：16.70, 准确率：0.10
# 第11周期，第(300/938)个撮，训练误差：16.95, 校验误差：16.97, 准确率：0.10
# 第11周期，第(400/938)个撮，训练误差：16.91, 校验误差：17.20, 准确率：0.09
# 第11周期，第(500/938)个撮，训练误差：17.03, 校验误差：16.73, 准确率：0.10
# 第11周期，第(600/938)个撮，训练误差：17.00, 校验误差：17.22, 准确率：0.10
# 第11周期，第(700/938)个撮，训练误差：16.99, 校验误差：17.17, 准确率：0.10
# 第11周期，第(800/938)个撮，训练误差：17.00, 校验误差：16.36, 准确率：0.10
# 第11周期，第(900/938)个撮，训练误差：17.01, 校验误差：17.43, 准确率：0.09
# 第12周期，第(0/938)个撮，训练误差：26.81, 校验误差：16.93, 准确率：0.10
# 第12周期，第(100/938)个撮，训练误差：17.44, 校验误差：16.81, 准确率：0.10
# 第12周期，第(200/938)个撮，训练误差：17.43, 校验误差：17.28, 准确率：0.10
# 第12周期，第(300/938)个撮，训练误差：17.37, 校验误差：17.09, 准确率：0.10
# 第12周期，第(400/938)个撮，训练误差：17.23, 校验误差：17.19, 准确率：0.10
# 第12周期，第(500/938)个撮，训练误差：17.19, 校验误差：16.94, 准确率：0.09
# 第12周期，第(600/938)个撮，训练误差：17.22, 校验误差：16.89, 准确率：0.10
# 第12周期，第(700/938)个撮，训练误差：17.18, 校验误差：17.11, 准确率：0.09
# 第12周期，第(800/938)个撮，训练误差：17.24, 校验误差：17.23, 准确率：0.10
# 第12周期，第(900/938)个撮，训练误差：17.23, 校验误差：16.88, 准确率：0.09
# 第13周期，第(0/938)个撮，训练误差：17.33, 校验误差：16.70, 准确率：0.10
# 第13周期，第(100/938)个撮，训练误差：17.02, 校验误差：17.17, 准确率：0.09
# 第13周期，第(200/938)个撮，训练误差：16.95, 校验误差：17.38, 准确率：0.09
# 第13周期，第(300/938)个撮，训练误差：16.92, 校验误差：17.30, 准确率：0.08
# 第13周期，第(400/938)个撮，训练误差：16.83, 校验误差：16.69, 准确率：0.10
# 第13周期，第(500/938)个撮，训练误差：16.91, 校验误差：16.87, 准确率：0.10
# 第13周期，第(600/938)个撮，训练误差：16.92, 校验误差：16.67, 准确率：0.10
# 第13周期，第(700/938)个撮，训练误差：16.88, 校验误差：16.92, 准确率：0.09
# 第13周期，第(800/938)个撮，训练误差：16.89, 校验误差：17.02, 准确率：0.09
# 第13周期，第(900/938)个撮，训练误差：16.93, 校验误差：16.57, 准确率：0.09
# 第14周期，第(0/938)个撮，训练误差：18.55, 校验误差：17.34, 准确率：0.09
# 第14周期，第(100/938)个撮，训练误差：17.37, 校验误差：16.90, 准确率：0.09
# 第14周期，第(200/938)个撮，训练误差：17.16, 校验误差：16.93, 准确率：0.09
# 第14周期，第(300/938)个撮，训练误差：17.06, 校验误差：17.05, 准确率：0.09
# 第14周期，第(400/938)个撮，训练误差：16.90, 校验误差：16.83, 准确率：0.10
# 第14周期，第(500/938)个撮，训练误差：16.95, 校验误差：16.84, 准确率：0.10
# 第14周期，第(600/938)个撮，训练误差：16.98, 校验误差：16.83, 准确率：0.09
# 第14周期，第(700/938)个撮，训练误差：16.98, 校验误差：16.14, 准确率：0.10
# 第14周期，第(800/938)个撮，训练误差：16.96, 校验误差：17.63, 准确率：0.09
# 第14周期，第(900/938)个撮，训练误差：16.97, 校验误差：17.03, 准确率：0.10
# 第15周期，第(0/938)个撮，训练误差：22.15, 校验误差：16.80, 准确率：0.10
# 第15周期，第(100/938)个撮，训练误差：17.36, 校验误差：16.42, 准确率：0.10
# 第15周期，第(200/938)个撮，训练误差：16.92, 校验误差：16.71, 准确率：0.10
# 第15周期，第(300/938)个撮，训练误差：16.86, 校验误差：17.06, 准确率：0.10
# 第15周期，第(400/938)个撮，训练误差：16.88, 校验误差：16.59, 准确率：0.10
# 第15周期，第(500/938)个撮，训练误差：16.92, 校验误差：17.11, 准确率：0.09
# 第15周期，第(600/938)个撮，训练误差：16.94, 校验误差：17.20, 准确率：0.10
# 第15周期，第(700/938)个撮，训练误差：16.91, 校验误差：16.81, 准确率：0.10
# 第15周期，第(800/938)个撮，训练误差：16.88, 校验误差：17.15, 准确率：0.10
# 第15周期，第(900/938)个撮，训练误差：16.90, 校验误差：17.53, 准确率：0.09
# 第16周期，第(0/938)个撮，训练误差：13.30, 校验误差：16.83, 准确率：0.09
# 第16周期，第(100/938)个撮，训练误差：16.98, 校验误差：17.34, 准确率：0.09
# 第16周期，第(200/938)个撮，训练误差：16.85, 校验误差：16.60, 准确率：0.10
# 第16周期，第(300/938)个撮，训练误差：16.86, 校验误差：16.77, 准确率：0.10
# 第16周期，第(400/938)个撮，训练误差：16.89, 校验误差：17.05, 准确率：0.10
# 第16周期，第(500/938)个撮，训练误差：16.82, 校验误差：16.58, 准确率：0.10
# 第16周期，第(600/938)个撮，训练误差：16.81, 校验误差：17.05, 准确率：0.10
# 第16周期，第(700/938)个撮，训练误差：16.85, 校验误差：16.93, 准确率：0.10
# 第16周期，第(800/938)个撮，训练误差：16.86, 校验误差：17.21, 准确率：0.10
# 第16周期，第(900/938)个撮，训练误差：16.86, 校验误差：16.85, 准确率：0.09
# 第17周期，第(0/938)个撮，训练误差：16.95, 校验误差：17.09, 准确率：0.09
# 第17周期，第(100/938)个撮，训练误差：16.31, 校验误差：16.75, 准确率：0.10
# 第17周期，第(200/938)个撮，训练误差：16.73, 校验误差：16.76, 准确率：0.10
# 第17周期，第(300/938)个撮，训练误差：16.87, 校验误差：16.55, 准确率：0.10
# 第17周期，第(400/938)个撮，训练误差：16.94, 校验误差：16.65, 准确率：0.11
# 第17周期，第(500/938)个撮，训练误差：16.91, 校验误差：16.86, 准确率：0.10
# 第17周期，第(600/938)个撮，训练误差：16.85, 校验误差：16.23, 准确率：0.10
# 第17周期，第(700/938)个撮，训练误差：16.86, 校验误差：16.84, 准确率：0.10
# 第17周期，第(800/938)个撮，训练误差：16.82, 校验误差：16.65, 准确率：0.10
# 第17周期，第(900/938)个撮，训练误差：16.78, 校验误差：17.07, 准确率：0.10
# 第18周期，第(0/938)个撮，训练误差：18.54, 校验误差：17.29, 准确率：0.09
# 第18周期，第(100/938)个撮，训练误差：16.86, 校验误差：16.74, 准确率：0.10
# 第18周期，第(200/938)个撮，训练误差：16.91, 校验误差：16.89, 准确率：0.10
# 第18周期，第(300/938)个撮，训练误差：16.87, 校验误差：16.51, 准确率：0.10
# 第18周期，第(400/938)个撮，训练误差：16.79, 校验误差：16.68, 准确率：0.10
# 第18周期，第(500/938)个撮，训练误差：16.83, 校验误差：17.03, 准确率：0.10
# 第18周期，第(600/938)个撮，训练误差：16.81, 校验误差：16.63, 准确率：0.10
# 第18周期，第(700/938)个撮，训练误差：16.75, 校验误差：17.33, 准确率：0.09
# 第18周期，第(800/938)个撮，训练误差：16.73, 校验误差：16.65, 准确率：0.10
# 第18周期，第(900/938)个撮，训练误差：16.75, 校验误差：16.72, 准确率：0.10
# 第19周期，第(0/938)个撮，训练误差：15.39, 校验误差：17.04, 准确率：0.09
# 第19周期，第(100/938)个撮，训练误差：16.58, 校验误差：17.08, 准确率：0.09
# 第19周期，第(200/938)个撮，训练误差：16.72, 校验误差：16.86, 准确率：0.10
# 第19周期，第(300/938)个撮，训练误差：16.74, 校验误差：17.13, 准确率：0.10
# 第19周期，第(400/938)个撮，训练误差：16.75, 校验误差：16.57, 准确率：0.10
# 第19周期，第(500/938)个撮，训练误差：16.64, 校验误差：16.72, 准确率：0.10
# 第19周期，第(600/938)个撮，训练误差：16.61, 校验误差：16.60, 准确率：0.10
# 第19周期，第(700/938)个撮，训练误差：16.63, 校验误差：16.61, 准确率：0.10
# 第19周期，第(800/938)个撮，训练误差：16.69, 校验误差：16.92, 准确率：0.10
# 第19周期，第(900/938)个撮，训练误差：16.68, 校验误差：16.81, 准确率：0.10

# %%
plt.plot([1 - i[2] for i in records])
right_ratio
# Out:
# 0.0976

# %% [markdown]
# ### 4、结果比较
# 将三次实验的结果放到一起比较

# %%
y1, y2, y3 = results['notransfer'][0], results['transfer_pretrained'][0], results['transfer_fixed'][0]

# %%
plt.figure(figsize = (10, 7))
plt.plot([1 - i[2] for i in y1], 'o-', label = 'no transfer')
plt.plot([1 - i[2] for i in y2], 's:', label = 'transfer pretrained')
plt.plot([1 - i[2] for i in y3], '*-', label = 'transfer fixed')
plt.xlabel('Time')
plt.ylabel('Error Rate')
plt.legend()

# %%
results['notransfer'][1], results['transfer_pretrained'][1], results['transfer_fixed'][1]
# Out:
# (0.0952, 0.102, 0.0976)

# %%
experiments = {}
experiments[1] = results

# %%
experiments
# Out:
# {1: {'notransfer': [[[87.845955, 92.40984, 0.006],
#     [70.11465, 17.679903, 0.0902],
#     [44.064274, 17.056465, 0.101],
#     [35.207554, 16.766924, 0.1],
#     [30.62399, 16.996014, 0.0952],
#     [27.883127, 16.165758, 0.0996],
#     [26.048296, 16.657019, 0.1124],
#     [24.769218, 16.685783, 0.1052],
#     [23.792084, 16.831831, 0.103],
#     [23.063093, 17.202946, 0.094],
#     [18.84447, 16.779385, 0.1022],
#     [17.01462, 16.832926, 0.1106],
#     [16.991909, 16.321232, 0.101],
#     [16.903122, 16.564964, 0.095],
#     [16.952345, 16.668026, 0.0964],
#     [16.897078, 16.993149, 0.099],
#     [16.985779, 17.324814, 0.099],
#     [16.924265, 16.629667, 0.1018],
#     [16.99102, 16.903952, 0.0976],
#     [17.017265, 16.513666, 0.0962],
#     [20.279236, 16.46144, 0.0976],
#     [16.967623, 16.835665, 0.103],
#     [16.773312, 17.237848, 0.1004],
#     [16.72455, 16.789406, 0.0996],
#     [16.833706, 16.97749, 0.0986],
#     [16.860838, 16.850796, 0.0908],
#     [16.866236, 16.855797, 0.1094],
#     [16.800783, 16.42176, 0.0954],
#     [16.819197, 16.695509, 0.1002],
#     [16.82362, 16.593023, 0.1002],
#     [14.348219, 16.973734, 0.0884],
#     [16.745947, 16.464851, 0.1036],
#     [16.764265, 16.65731, 0.0968],
#     [16.814814, 16.477463, 0.104],
#     [16.780087, 16.920887, 0.1026],
#     [16.778618, 16.815613, 0.1036],
#     [16.803215, 16.928534, 0.1006],
#     [16.791779, 16.757044, 0.097],
#     [16.793331, 16.424387, 0.1006],
#     [16.795282, 16.451155, 0.0924],
#     [11.983936, 16.825253, 0.1064],
#     [17.201426, 16.820322, 0.0968],
#     [16.872286, 16.499268, 0.0972],
#     [16.793365, 16.895798, 0.0974],
#     [16.811573, 16.995829, 0.0986],
#     [16.758738, 16.594685, 0.0944],
#     [16.709974, 16.574732, 0.098],
#     [16.704765, 16.67358, 0.0922],
#     [16.723866, 16.662115, 0.0946],
#     [16.758497, 16.7154, 0.1004],
#     [21.882711, 17.022484, 0.0988],
#     [16.478935, 16.920935, 0.102],
#     [16.707687, 16.404194, 0.102],
#     [16.755411, 16.828568, 0.0902],
#     [16.8164, 16.92931, 0.0908],
#     [16.772482, 16.838314, 0.1006],
#     [16.795925, 17.041943, 0.0946],
#     [16.846254, 16.841995, 0.0976],
#     [16.837921, 16.927025, 0.0998],
#     [16.826393, 16.78644, 0.0936],
#     [16.205574, 16.900824, 0.0978],
#     [16.649818, 17.032581, 0.0892],
#     [16.770449, 16.98488, 0.1038],
#     [16.829487, 16.835802, 0.1056],
#     [16.826977, 17.064316, 0.1038],
#     [16.829918, 16.585161, 0.0928],
#     [16.865465, 16.493095, 0.1074],
#     [16.852123, 16.703058, 0.0998],
#     [16.809223, 17.091476, 0.0956],
#     [16.782955, 16.911806, 0.1016],
#     [18.49016, 16.35395, 0.1],
#     [16.708815, 16.726109, 0.1028],
#     [16.737959, 16.595274, 0.0944],
#     [16.905264, 17.04889, 0.1008],
#     [16.890394, 16.506319, 0.0946],
#     [16.857141, 16.67993, 0.0978],
#     [16.802233, 16.727339, 0.1048],
#     [16.801119, 16.515158, 0.1052],
#     [16.764315, 17.328308, 0.1002],
#     [16.728323, 16.728748, 0.0934],
#     [14.034851, 17.477413, 0.0926],
#     [16.664967, 16.637564, 0.1054],
#     [16.64729, 16.437424, 0.1056],
#     [16.62018, 16.62943, 0.1102],
#     [16.642914, 16.508505, 0.1012],
#     [16.77014, 16.588213, 0.1008],
#     [16.75454, 16.91325, 0.1046],
#     [16.757557, 16.631378, 0.1064],
#     [16.755318, 16.815844, 0.0896],
#     [16.731213, 17.029102, 0.1],
#     [16.187958, 16.666225, 0.1022],
#     [17.049242, 16.794966, 0.0986],
#     [16.825293, 17.004358, 0.1122],
#     [16.748365, 16.986128, 0.0972],
#     [16.79316, 16.695856, 0.0966],
#     [16.837345, 16.808475, 0.098],
#     [16.82698, 16.89836, 0.1022],
#     [16.883587, 16.407291, 0.0984],
#     [16.900667, 16.812992, 0.0986],
#     [16.871504, 16.814217, 0.1058],
#     [16.905346, 16.793568, 0.1024],
#     [16.695143, 16.953995, 0.1092],
#     [16.618038, 17.182697, 0.101],
#     [16.720903, 16.564915, 0.0958],
#     [16.692745, 16.920273, 0.0874],
#     [16.66568, 16.274784, 0.1004],
#     [16.652966, 17.070621, 0.096],
#     [16.672619, 16.863768, 0.0976],
#     [16.709974, 16.49173, 0.0948],
#     [16.743616, 16.50501, 0.1028],
#     [13.340836, 16.877193, 0.106],
#     [16.838562, 17.128036, 0.0978],
#     [16.7808, 16.788063, 0.1046],
#     [16.798956, 16.50758, 0.1],
#     [16.697405, 16.752806, 0.103],
#     [16.737125, 16.735035, 0.0984],
#     [16.821817, 16.307314, 0.1052],
#     [16.8124, 16.75662, 0.1044],
#     [16.70001, 16.760433, 0.1084],
#     [16.687965, 16.62443, 0.1076],
#     [18.653593, 16.76175, 0.0928],
#     [16.916443, 16.998442, 0.0966],
#     [17.040335, 16.857756, 0.1058],
#     [17.022953, 17.228367, 0.1002],
#     [17.025236, 16.887175, 0.0916],
#     [17.005955, 16.701458, 0.1012],
#     [16.969793, 16.777868, 0.0922],
#     [16.959349, 16.930204, 0.1],
#     [16.93413, 16.718899, 0.0982],
#     [16.896614, 16.958954, 0.0978],
#     [15.375618, 16.39242, 0.1078],
#     [17.058565, 16.776505, 0.1072],
#     [16.789497, 16.958153, 0.1016],
#     [16.722124, 16.70717, 0.094],
#     [16.742783, 16.934809, 0.104],
#     [16.75283, 16.815628, 0.098],
#     [16.772436, 16.62503, 0.0986],
#     [16.789705, 17.014961, 0.0902],
#     [16.78217, 16.681393, 0.1022],
#     [16.782185, 16.83038, 0.1032],
#     [14.171976, 16.698605, 0.107],
#     [16.923988, 16.958006, 0.0934],
#     [16.700136, 16.300135, 0.108],
#     [16.768925, 16.718845, 0.1066],
#     [16.710743, 17.038475, 0.0972],
#     [16.766537, 16.799166, 0.0942],
#     [16.796412, 16.327085, 0.098],
#     [16.817282, 16.392689, 0.1],
#     [16.785736, 16.813208, 0.101],
#     [16.833204, 16.853283, 0.097],
#     [21.388412, 16.43217, 0.1012],
#     [16.67624, 17.212124, 0.1026],
#     [16.276972, 17.138842, 0.0922],
#     [16.353073, 16.284843, 0.097],
#     [16.505966, 17.24485, 0.1022],
#     [16.59366, 16.756454, 0.098],
#     [16.595533, 16.556343, 0.1028],
#     [16.56057, 16.678139, 0.0928],
#     [16.659285, 16.658396, 0.0986],
#     [16.724215, 16.764727, 0.1002],
#     [16.065844, 17.315224, 0.0996],
#     [16.623188, 16.692001, 0.1034],
#     [16.646683, 16.243858, 0.1108],
#     [16.665861, 17.016115, 0.0916],
#     [16.683142, 16.636522, 0.1016],
#     [16.608875, 16.658497, 0.1022],
#     [16.664474, 16.267887, 0.1042],
#     [16.635195, 17.007547, 0.0972],
#     [16.68174, 16.653107, 0.1008],
#     [16.722273, 16.644718, 0.1014],
#     [18.678583, 16.578035, 0.1004],
#     [17.077826, 16.50786, 0.1092],
#     [17.0622, 16.712, 0.1026],
#     [16.87448, 16.765844, 0.1076],
#     [16.787209, 16.845419, 0.0958],
#     [16.753298, 16.800278, 0.094],
#     [16.711174, 16.846508, 0.0976],
#     [16.780287, 16.421, 0.0982],
#     [16.746048, 16.803404, 0.1014],
#     [16.727074, 16.38539, 0.103],
#     [17.252338, 16.619528, 0.1046],
#     [16.336805, 16.938988, 0.097],
#     [16.58489, 16.559933, 0.0984],
#     [16.715513, 16.899126, 0.0922],
#     [16.748285, 17.027685, 0.0912],
#     [16.812523, 16.892591, 0.099],
#     [16.778616, 16.523525, 0.1028],
#     [16.803886, 16.804348, 0.096],
#     [16.808296, 16.392233, 0.098],
#     [16.83087, 16.75195, 0.0944],
#     [21.889273, 16.703537, 0.0984],
#     [16.868195, 16.978935, 0.1008],
#     [16.955547, 16.552605, 0.101],
#     [16.915142, 16.75937, 0.0988],
#     [16.853342, 16.761967, 0.0994],
#     [16.842382, 16.624008, 0.0998],
#     [16.834394, 16.86658, 0.1016],
#     [16.852976, 16.397638, 0.1036],
#     [16.783176, 16.532736, 0.1],
#     [16.760109, 16.532228, 0.1022]],
#    0.0952],
#   'transfer_pretrained': [[[91.7368, 89.90783, 0.0158],
#     [24.966423, 18.296413, 0.0974],
#     [21.212288, 18.307386, 0.0876],
#     [20.117441, 17.55744, 0.0882],
#     [19.540745, 18.086748, 0.095],
#     [19.177242, 16.96434, 0.0928],
#     [18.958906, 17.326797, 0.0872],
#     [18.751703, 17.413893, 0.1014],
#     [18.590065, 17.724577, 0.091],
#     [18.505854, 17.390955, 0.0972],
#     [15.590842, 18.711884, 0.0776],
#     [17.158712, 16.824532, 0.1022],
#     [17.206715, 18.013245, 0.088],
#     [17.296654, 17.913553, 0.088],
#     [17.29197, 17.47293, 0.0908],
#     [17.222448, 17.444696, 0.088],
#     [17.29216, 17.379032, 0.1],
#     [17.34107, 16.897213, 0.0936],
#     [17.401247, 16.8852, 0.0982],
#     [17.44262, 16.993647, 0.097],
#     [23.031487, 18.133045, 0.0848],
#     [17.558096, 16.932098, 0.1004],
#     [17.618658, 17.645035, 0.1002],
#     [17.487083, 17.030333, 0.0996],
#     [17.487411, 16.733507, 0.0986],
#     [17.544498, 17.439907, 0.0974],
#     [17.482191, 17.298847, 0.0874],
#     [17.482319, 16.544716, 0.0952],
#     [17.453001, 17.275541, 0.09],
#     [17.448875, 17.157997, 0.1014],
#     [16.578995, 17.681116, 0.0924],
#     [16.955275, 17.485876, 0.091],
#     [17.155182, 17.386148, 0.0948],
#     [17.26986, 16.559458, 0.0976],
#     [17.192732, 16.892998, 0.0982],
#     [17.160212, 16.56042, 0.1008],
#     [17.24197, 17.878145, 0.0826],
#     [17.22332, 17.588076, 0.095],
#     [17.239904, 16.941183, 0.0988],
#     [17.288273, 17.06656, 0.0952],
#     [17.233727, 16.863045, 0.0954],
#     [17.38579, 17.309414, 0.0872],
#     [16.955702, 17.37932, 0.093],
#     [16.973326, 16.565723, 0.1052],
#     [16.997475, 16.808105, 0.0942],
#     [17.112133, 17.171253, 0.1048],
#     [17.121042, 16.7273, 0.0986],
#     [17.172213, 17.478527, 0.0924],
#     [17.156498, 17.448236, 0.0934],
#     [17.199715, 17.795935, 0.0854],
#     [17.333885, 16.749662, 0.0928],
#     [17.870594, 17.159487, 0.0994],
#     [17.54267, 17.265831, 0.0974],
#     [17.290848, 17.52053, 0.093],
#     [17.277166, 17.222216, 0.0954],
#     [17.380836, 16.861673, 0.102],
#     [17.289196, 16.761106, 0.0952],
#     [17.311436, 17.451921, 0.0936],
#     [17.30405, 16.771744, 0.0972],
#     [17.275425, 17.598951, 0.0888],
#     [20.444958, 16.920118, 0.1032],
#     [17.188768, 17.475338, 0.09],
#     [17.370407, 16.531538, 0.099],
#     [17.458046, 18.147573, 0.088],
#     [17.42756, 17.236324, 0.1028],
#     [17.304285, 17.056047, 0.0916],
#     [17.27478, 16.7537, 0.0976],
#     [17.255201, 16.789587, 0.097],
#     [17.222067, 17.23395, 0.0978],
#     [17.18972, 17.307472, 0.0956],
#     [14.470827, 16.807344, 0.0988],
#     [17.156805, 17.307175, 0.098],
#     [17.121618, 16.656494, 0.0986],
#     [17.08107, 16.919626, 0.1038],
#     [17.10701, 16.847923, 0.0916],
#     [17.131264, 16.809128, 0.099],
#     [17.126513, 17.201073, 0.0936],
#     [17.10686, 17.488733, 0.0892],
#     [17.089102, 18.221016, 0.0924],
#     [17.092272, 16.844725, 0.0984],
#     [15.687481, 16.725231, 0.0932],
#     [17.192055, 17.74589, 0.0898],
#     [17.098154, 16.972645, 0.1024],
#     [16.890985, 17.106642, 0.098],
#     [16.956453, 17.104425, 0.1002],
#     [16.930748, 16.664167, 0.0914],
#     [16.894794, 17.532187, 0.092],
#     [16.93913, 17.649616, 0.0826],
#     [16.974695, 17.271667, 0.0946],
#     [17.02413, 16.787289, 0.0996],
#     [20.098999, 16.868757, 0.103],
#     [17.430607, 17.049423, 0.0932],
#     [16.906038, 17.327503, 0.096],
#     [16.930952, 17.013403, 0.1008],
#     [16.998854, 17.264166, 0.0988],
#     [16.990547, 17.01975, 0.1052],
#     [17.027872, 16.838434, 0.096],
#     [17.048243, 17.060703, 0.0932],
#     [17.075691, 17.698683, 0.0904],
#     [17.10193, 17.44579, 0.1034],
#     [18.052505, 17.730793, 0.0906],
#     [16.95697, 17.390036, 0.0932],
#     [17.010233, 17.168568, 0.0922],
#     [17.054096, 16.806532, 0.097],
#     [16.914633, 16.555265, 0.1018],
#     [16.990469, 16.858664, 0.0938],
#     [16.976124, 17.03208, 0.1024],
#     [17.043688, 16.918097, 0.0908],
#     [17.011604, 16.808313, 0.0962],
#     [16.980282, 16.932629, 0.0962],
#     [16.2546, 16.787985, 0.0904],
#     [17.059053, 17.16135, 0.1046],
#     [16.898924, 17.148155, 0.0854],
#     [17.001892, 16.782703, 0.0944],
#     [17.018576, 17.31554, 0.0924],
#     [16.955889, 16.741537, 0.1064],
#     [17.021095, 16.657145, 0.084],
#     [17.050804, 16.781828, 0.0952],
#     [16.999166, 17.02809, 0.0892],
#     [17.059221, 16.640884, 0.0968],
#     [18.93357, 16.762121, 0.0982],
#     [16.590834, 17.67861, 0.0896],
#     [16.83792, 17.245361, 0.0944],
#     [16.858444, 16.74019, 0.1074],
#     [16.836285, 16.736946, 0.093],
#     [16.854643, 16.905178, 0.0982],
#     [16.851244, 17.377207, 0.0948],
#     [16.896141, 16.804277, 0.0934],
#     [16.928759, 17.217237, 0.09],
#     [16.927212, 16.746504, 0.104],
#     [16.93873, 16.855934, 0.1072],
#     [16.458582, 17.08391, 0.0956],
#     [16.741848, 16.631956, 0.1004],
#     [16.90637, 17.182768, 0.0968],
#     [16.80202, 16.647272, 0.0972],
#     [16.741049, 16.680925, 0.1002],
#     [16.753796, 16.8179, 0.0978],
#     [16.796408, 16.801397, 0.0862],
#     [16.860601, 16.861813, 0.0916],
#     [16.897242, 16.529436, 0.0994],
#     [18.669352, 16.717548, 0.1006],
#     [16.894278, 16.552593, 0.0996],
#     [16.775381, 16.533903, 0.0948],
#     [16.911188, 17.293371, 0.0962],
#     [16.931557, 16.774406, 0.099],
#     [16.932896, 16.598783, 0.1008],
#     [16.948292, 16.59112, 0.0978],
#     [17.010862, 16.651552, 0.1018],
#     [16.988235, 16.420113, 0.0972],
#     [17.004597, 16.283804, 0.1026],
#     [20.126839, 16.869465, 0.098],
#     [17.10417, 16.7142, 0.1008],
#     [16.912687, 16.706404, 0.1034],
#     [17.016478, 16.748768, 0.0968],
#     [16.97294, 16.992565, 0.0928],
#     [16.965, 16.96304, 0.0974],
#     [16.976019, 17.19715, 0.097],
#     [16.953722, 16.990084, 0.0928],
#     [16.925219, 17.331408, 0.0986],
#     [16.925806, 16.966627, 0.11],
#     [17.247116, 17.11177, 0.0928],
#     [16.720688, 17.031075, 0.0916],
#     [16.872467, 16.80202, 0.0966],
#     [16.959063, 16.684404, 0.1026],
#     [16.873028, 16.775501, 0.0872],
#     [16.918192, 17.033304, 0.0958],
#     [16.964958, 16.23721, 0.1022],
#     [16.962177, 16.856985, 0.087],
#     [16.988512, 16.710463, 0.0902],
#     [16.968697, 16.718119, 0.0986],
#     [12.330307, 16.954834, 0.0984],
#     [16.89146, 16.706766, 0.1006],
#     [16.895426, 17.20361, 0.0974],
#     [16.792671, 16.846062, 0.1082],
#     [16.750889, 16.8411, 0.0978],
#     [16.754478, 16.530853, 0.0986],
#     [16.657505, 16.624235, 0.0938],
#     [16.690165, 17.060715, 0.1024],
#     [16.718845, 16.798887, 0.0948],
#     [16.693762, 16.992949, 0.0936],
#     [16.888199, 16.996002, 0.098],
#     [16.399975, 16.417974, 0.0936],
#     [16.401344, 16.712471, 0.101],
#     [16.527588, 17.074852, 0.0894],
#     [16.51847, 16.822407, 0.0992],
#     [16.619846, 16.672562, 0.1092],
#     [16.683718, 16.865053, 0.096],
#     [16.643723, 16.918127, 0.1036],
#     [16.730328, 16.735367, 0.1024],
#     [16.724993, 16.87581, 0.0962],
#     [14.189478, 16.613173, 0.0964],
#     [16.573286, 17.216705, 0.1034],
#     [16.507273, 16.988117, 0.0934],
#     [16.598423, 16.859488, 0.0898],
#     [16.671135, 16.761118, 0.0914],
#     [16.750038, 16.455057, 0.106],
#     [16.697598, 17.086634, 0.0966],
#     [16.673443, 16.434143, 0.1056],
#     [16.695759, 16.741566, 0.0996],
#     [16.719322, 16.777445, 0.0894]],
#    0.102],
#   'transfer_fixed': [[[96.59851, 97.21636, 0.0086],
#     [25.747795, 18.848072, 0.086],
#     [21.76133, 17.54388, 0.0934],
#     [20.488163, 20.386314, 0.0786],
#     [19.927946, 17.057913, 0.0932],
#     [19.539476, 17.209341, 0.103],
#     [19.23741, 17.244944, 0.0954],
#     [18.966726, 17.3028, 0.0932],
#     [18.85581, 17.087536, 0.0944],
#     [18.772339, 17.909912, 0.0868],
#     [20.32109, 17.936739, 0.0842],
#     [18.290556, 17.078531, 0.1006],
#     [17.690983, 17.231335, 0.1026],
#     [17.571121, 16.96532, 0.102],
#     [17.621954, 17.550346, 0.0926],
#     [17.558207, 17.435484, 0.097],
#     [17.555826, 17.14797, 0.0916],
#     [17.597006, 17.870821, 0.0908],
#     [17.61203, 17.180481, 0.0922],
#     [17.589273, 17.42933, 0.0984],
#     [15.358416, 16.921595, 0.1006],
#     [17.215452, 17.006262, 0.0988],
#     [17.16993, 17.069021, 0.0936],
#     [17.313885, 17.955162, 0.096],
#     [17.457388, 17.414251, 0.0946],
#     [17.5, 17.149328, 0.0992],
#     [17.550072, 17.142664, 0.0974],
#     [17.533287, 17.198362, 0.1004],
#     [17.56654, 17.011227, 0.0988],
#     [17.590996, 18.01236, 0.0886],
#     [17.484669, 17.376995, 0.0984],
#     [17.36499, 17.016205, 0.0992],
#     [17.462551, 17.326664, 0.0958],
#     [17.541866, 16.895638, 0.0978],
#     [17.518402, 17.291435, 0.0968],
#     [17.428646, 16.810768, 0.098],
#     [17.4258, 17.259577, 0.1004],
#     [17.437113, 17.219397, 0.0942],
#     [17.432362, 17.617962, 0.0932],
#     [17.461834, 17.67811, 0.0888],
#     [13.779736, 17.131657, 0.0972],
#     [17.692524, 17.184729, 0.0958],
#     [17.598473, 18.871733, 0.0786],
#     [17.60761, 16.8248, 0.1028],
#     [17.51304, 17.11649, 0.0946],
#     [17.44865, 17.326933, 0.0886],
#     [17.379725, 17.025429, 0.0998],
#     [17.365341, 17.237785, 0.0894],
#     [17.400616, 17.774668, 0.0936],
#     [17.413193, 17.554714, 0.0992],
#     [16.8983, 17.325035, 0.084],
#     [17.622217, 17.907331, 0.0888],
#     [17.634777, 19.221367, 0.0794],
#     [17.56859, 16.561378, 0.098],
#     [17.483347, 17.472414, 0.092],
#     [17.46574, 16.975475, 0.1042],
#     [17.374208, 17.543314, 0.0968],
#     [17.329096, 16.626816, 0.1038],
#     [17.288443, 17.275005, 0.0958],
#     [17.303988, 17.743763, 0.092],
#     [15.368718, 16.787418, 0.1018],
#     [17.288265, 17.35551, 0.0932],
#     [17.22151, 17.084324, 0.0908],
#     [17.325186, 17.601627, 0.0838],
#     [17.266047, 17.358973, 0.0956],
#     [17.185472, 17.325573, 0.1006],
#     [17.190273, 17.360767, 0.0954],
#     [17.214924, 17.92907, 0.0894],
#     [17.248463, 17.361048, 0.0886],
#     [17.227827, 17.565788, 0.0886],
#     [14.292915, 17.219616, 0.0962],
#     [16.724579, 16.769089, 0.1012],
#     [16.85264, 16.925888, 0.095],
#     [17.014103, 17.318306, 0.0936],
#     [17.107841, 16.76388, 0.096],
#     [17.145155, 17.184807, 0.1052],
#     [17.113356, 17.503689, 0.0936],
#     [17.160856, 18.023735, 0.0882],
#     [17.210842, 17.2262, 0.0898],
#     [17.219046, 17.050047, 0.089],
#     [15.300308, 16.743385, 0.097],
#     [17.267889, 17.010138, 0.0938],
#     [17.05286, 16.934986, 0.1024],
#     [17.090649, 17.05231, 0.1012],
#     [17.064573, 16.969763, 0.0984],
#     [17.125986, 17.012846, 0.1062],
#     [17.199316, 17.655401, 0.0842],
#     [17.133085, 17.065104, 0.0922],
#     [17.112661, 16.930717, 0.0962],
#     [17.097675, 17.55206, 0.088],
#     [15.21058, 16.92214, 0.0998],
#     [16.848272, 16.914253, 0.0914],
#     [17.046776, 16.93648, 0.0942],
#     [16.962196, 17.907629, 0.0886],
#     [16.977411, 17.039494, 0.0926],
#     [17.092007, 16.810127, 0.1052],
#     [17.121086, 16.56713, 0.1036],
#     [17.037056, 17.094482, 0.0926],
#     [17.061527, 16.415298, 0.1014],
#     [17.083956, 16.70793, 0.0992],
#     [14.263042, 17.60237, 0.088],
#     [17.131908, 16.485216, 0.0992],
#     [17.038477, 17.403473, 0.0928],
#     [17.128878, 17.603487, 0.087],
#     [17.164257, 17.308935, 0.0942],
#     [17.096218, 16.895689, 0.0946],
#     [17.049852, 16.693727, 0.0944],
#     [17.021202, 17.529142, 0.0942],
#     [16.991335, 16.776777, 0.1018],
#     [17.021093, 17.26907, 0.0992],
#     [12.318909, 16.593363, 0.1036],
#     [17.111214, 16.286572, 0.1014],
#     [16.84087, 16.696243, 0.0982],
#     [16.950794, 16.97271, 0.098],
#     [16.913023, 17.204657, 0.0908],
#     [17.026012, 16.727102, 0.0956],
#     [17.002844, 17.224434, 0.0976],
#     [16.993855, 17.168262, 0.1014],
#     [16.998344, 16.355686, 0.0984],
#     [17.005396, 17.42756, 0.0884],
#     [26.814955, 16.927538, 0.1024],
#     [17.443533, 16.80909, 0.0974],
#     [17.428411, 17.276146, 0.097],
#     [17.37355, 17.093517, 0.102],
#     [17.225868, 17.19294, 0.0964],
#     [17.190039, 16.94488, 0.0868],
#     [17.217934, 16.890438, 0.0974],
#     [17.180964, 17.109907, 0.0916],
#     [17.23573, 17.23, 0.0988],
#     [17.230856, 16.875221, 0.0908],
#     [17.333843, 16.699928, 0.0974],
#     [17.018124, 17.17413, 0.0856],
#     [16.9465, 17.37613, 0.0882],
#     [16.921995, 17.30079, 0.084],
#     [16.827253, 16.685738, 0.096],
#     [16.912184, 16.87113, 0.1026],
#     [16.91534, 16.671204, 0.1014],
#     [16.875923, 16.915318, 0.0916],
#     [16.886505, 17.019419, 0.0866],
#     [16.925268, 16.571194, 0.0912],
#     [18.545973, 17.344057, 0.0904],
#     [17.36977, 16.901827, 0.092],
#     [17.1607, 16.932037, 0.093],
#     [17.060566, 17.053547, 0.0896],
#     [16.898209, 16.828903, 0.0974],
#     [16.952707, 16.837511, 0.0964],
#     [16.975384, 16.82991, 0.0898],
#     [16.97644, 16.142021, 0.1026],
#     [16.963661, 17.625288, 0.0922],
#     [16.971022, 17.03206, 0.102],
#     [22.153599, 16.795315, 0.0972],
#     [17.355642, 16.419117, 0.0992],
#     [16.916826, 16.713984, 0.0998],
#     [16.8569, 17.060068, 0.0984],
#     [16.87638, 16.594038, 0.0978],
#     [16.916084, 17.112265, 0.094],
#     [16.935242, 17.204794, 0.0952],
#     [16.908237, 16.814308, 0.0978],
#     [16.879328, 17.154215, 0.1008],
#     [16.904913, 17.532125, 0.0858],
#     [13.296493, 16.833393, 0.0948],
#     [16.977762, 17.344698, 0.0896],
#     [16.85489, 16.601059, 0.0968],
#     [16.85504, 16.77492, 0.1014],
#     [16.889446, 17.046661, 0.0984],
#     [16.822815, 16.582533, 0.1044],
#     [16.809904, 17.054813, 0.1022],
#     [16.852158, 16.927458, 0.0994],
#     [16.85771, 17.211893, 0.101],
#     [16.86038, 16.845413, 0.0904],
#     [16.948874, 17.094809, 0.0922],
#     [16.306086, 16.754904, 0.0998],
#     [16.72968, 16.76018, 0.0952],
#     [16.874037, 16.54926, 0.102],
#     [16.941557, 16.646122, 0.1054],
#     [16.907938, 16.85874, 0.0974],
#     [16.854324, 16.234509, 0.1038],
#     [16.86247, 16.83732, 0.1012],
#     [16.821756, 16.64575, 0.104],
#     [16.775766, 17.06855, 0.0966],
#     [18.53873, 17.285608, 0.0932],
#     [16.859125, 16.736952, 0.0988],
#     [16.9141, 16.886518, 0.0956],
#     [16.874603, 16.51298, 0.1006],
#     [16.78921, 16.684444, 0.097],
#     [16.833683, 17.028048, 0.0998],
#     [16.80555, 16.632536, 0.0962],
#     [16.750633, 17.327679, 0.0862],
#     [16.729868, 16.654202, 0.1006],
#     [16.75345, 16.719975, 0.1026],
#     [15.387312, 17.03514, 0.0942],
#     [16.581585, 17.084406, 0.0936],
#     [16.724924, 16.860342, 0.1014],
#     [16.740131, 17.133522, 0.0964],
#     [16.752413, 16.571218, 0.0972],
#     [16.635027, 16.720661, 0.1012],
#     [16.611258, 16.598406, 0.1018],
#     [16.632397, 16.613377, 0.102],
#     [16.688173, 16.920828, 0.099],
#     [16.682348, 16.814497, 0.0964]],
#    0.0976]}}

# %% [markdown]
# ## 综合试验
#
# 为了系统化的比较不同的参数对迁移学习的影响，我们做了一次大实验：
#
# 该试验包括了三重循环，分别是：
#
# 1、不同的迁移学习方法：无迁移、迁移固定权重、迁移预训练
#
# 2、每一个参数下重复实验times次
#
# 3、加载不同的数据集比例fraction

# %%
results = {} #记载实验结果
times = 10 # 每一组参数下实验都要被重复10次
fractions = [20, 10, 8, 6, 5, 4, 3, 2, 1] #所有的数据加载的比例值
for experiment in ['no transfer', 'transfer_fixed', 'transfer_pretrained']:
    for time in range(times):
        for fraction in fractions:
            
            # 分不同的迁移学习情况加载网络和优化器
            if experiment == 'no transfer':
                net = Transfer()
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
            if experiment == 'transfer_pretrained':
                net = Transfer()
                net.set_filter_values(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
            if experiment == 'transfer_fixed':
                net = Transfer()
                net.set_filter_values_nograd(original_net)
                if use_cuda:
                    net = net.cuda()
                criterion = nn.MSELoss()
                new_parameters = []
                for para in net.parameters():
                    if para.requires_grad:
                        new_parameters.append(para)
                optimizer = optim.SGD(new_parameters, lr=0.0001, momentum=0.9)
                
            #开始迁移学习训练
            num_epochs = 20
            records = []
            for epoch in range(num_epochs):
                losses = []
                for idx, data in enumerate(zip(train_loader1, train_loader2)):
                    if idx >= (len(train_loader1) // fraction):
                        break
                    ((x1, y1), (x2, y2)) = data
                    if use_cuda:
                        x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                    net.train()
                    optimizer.zero_grad()
                    outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                    labels = y1 + y2
                    loss = criterion(outputs, labels.type(dtype))
                    loss.backward()
                    optimizer.step()
                    loss = loss.cpu() if use_cuda else loss
                    losses.append(loss.data.numpy())
                    if idx % 500 == 0:
                        val_losses = []
                        rights = []
                        net.eval()
                        for val_data in zip(val_loader1, val_loader2):
                            ((x1, y1), (x2, y2)) = val_data
                            if use_cuda:
                                x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                            outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                            labels = y1 + y2
                            loss = criterion(outputs, labels.type(dtype))
                            loss = loss.cpu() if use_cuda else loss
                            val_losses.append(loss.data.numpy())
                            right = rightness(outputs.data, labels)
                            rights.append(right)
                        right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
                        print('{}网络：第{}试验，比例{}, 第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'
                              .format(experiment,time,fraction,
                            epoch, idx, len(train_loader1),
                            np.mean(losses), np.mean(val_losses), right_ratio))
                        records.append([np.mean(losses), np.mean(val_losses), right_ratio])
            rights = []
            net.eval()
            for test_data in zip(test_loader1, test_loader2):
                ((x1, y1), (x2, y2)) = test_data
                if use_cuda:
                    x1, y1, x2, y2 = x1.cuda(), y1.cuda(), x2.cuda(), y2.cuda()
                outputs = net(x1.clone().detach().requires_grad_(True), x2.clone().detach().requires_grad_(True))
                labels = y1 + y2
                loss = criterion(outputs, labels.type(dtype))
                right = rightness(outputs.data, labels)
                rights.append(right)
            right_ratio = 1.0 * np.sum([i[0].to('cpu') for i in rights]) / np.sum([i[1] for i in rights])
            print(experiment,time,fraction)
            
            #将结果记录在了results集合之中，records记载了每一个打印周期的训练集损失函数、校验集损失函数、校验集正确率，
            #right_ratio记录了每次实验测试集的准确度
            results[(experiment,time,fraction)] = [records, right_ratio]
# Out:
# no transfer网络：第0试验，比例20, 第0周期，第(0/938)个撮，训练误差：99.51, 校验误差：99.95, 准确率：0.01
# no transfer网络：第0试验，比例20, 第1周期，第(0/938)个撮，训练误差：87.51, 校验误差：85.60, 准确率：0.02
# no transfer网络：第0试验，比例20, 第2周期，第(0/938)个撮，训练误差：64.33, 校验误差：68.44, 准确率：0.03
# no transfer网络：第0试验，比例20, 第3周期，第(0/938)个撮，训练误差：21.80, 校验误差：19.70, 准确率：0.09
# no transfer网络：第0试验，比例20, 第4周期，第(0/938)个撮，训练误差：15.98, 校验误差：17.82, 准确率：0.08
# no transfer网络：第0试验，比例20, 第5周期，第(0/938)个撮，训练误差：16.53, 校验误差：16.77, 准确率：0.10
# no transfer网络：第0试验，比例20, 第6周期，第(0/938)个撮，训练误差：17.05, 校验误差：16.37, 准确率：0.11
# no transfer网络：第0试验，比例20, 第7周期，第(0/938)个撮，训练误差：21.27, 校验误差：16.72, 准确率：0.10
# no transfer网络：第0试验，比例20, 第8周期，第(0/938)个撮，训练误差：15.13, 校验误差：17.39, 准确率：0.08
# no transfer网络：第0试验，比例20, 第9周期，第(0/938)个撮，训练误差：17.19, 校验误差：17.00, 准确率：0.10
# no transfer网络：第0试验，比例20, 第10周期，第(0/938)个撮，训练误差：21.34, 校验误差：16.81, 准确率：0.10
# no transfer网络：第0试验，比例20, 第11周期，第(0/938)个撮，训练误差：16.50, 校验误差：17.59, 准确率：0.09
# no transfer网络：第0试验，比例20, 第12周期，第(0/938)个撮，训练误差：13.38, 校验误差：16.86, 准确率：0.08
# no transfer网络：第0试验，比例20, 第13周期，第(0/938)个撮，训练误差：18.18, 校验误差：16.53, 准确率：0.10
# no transfer网络：第0试验，比例20, 第14周期，第(0/938)个撮，训练误差：18.45, 校验误差：16.60, 准确率：0.11
# no transfer网络：第0试验，比例20, 第15周期，第(0/938)个撮，训练误差：18.99, 校验误差：16.96, 准确率：0.10
# no transfer网络：第0试验，比例20, 第16周期，第(0/938)个撮，训练误差：16.05, 校验误差：16.37, 准确率：0.10
# no transfer网络：第0试验，比例20, 第17周期，第(0/938)个撮，训练误差：16.94, 校验误差：16.29, 准确率：0.10
# no transfer网络：第0试验，比例20, 第18周期，第(0/938)个撮，训练误差：18.43, 校验误差：16.73, 准确率：0.11
# no transfer网络：第0试验，比例20, 第19周期，第(0/938)个撮，训练误差：19.50, 校验误差：16.96, 准确率：0.10
# no transfer 0 20
# no transfer网络：第0试验，比例10, 第0周期，第(0/938)个撮，训练误差：103.69, 校验误差：98.02, 准确率：0.01
# no transfer网络：第0试验，比例10, 第1周期，第(0/938)个撮，训练误差：65.06, 校验误差：69.40, 准确率：0.04
# no transfer网络：第0试验，比例10, 第2周期，第(0/938)个撮，训练误差：14.77, 校验误差：17.54, 准确率：0.09
# no transfer网络：第0试验，比例10, 第3周期，第(0/938)个撮，训练误差：21.26, 校验误差：16.74, 准确率：0.09
# no transfer网络：第0试验，比例10, 第4周期，第(0/938)个撮，训练误差：13.07, 校验误差：17.21, 准确率：0.11
# no transfer网络：第0试验，比例10, 第5周期，第(0/938)个撮，训练误差：15.17, 校验误差：16.90, 准确率：0.11
# no transfer网络：第0试验，比例10, 第6周期，第(0/938)个撮，训练误差：15.43, 校验误差：16.72, 准确率：0.12
# no transfer网络：第0试验，比例10, 第7周期，第(0/938)个撮，训练误差：18.53, 校验误差：17.33, 准确率：0.09
# no transfer网络：第0试验，比例10, 第8周期，第(0/938)个撮，训练误差：14.35, 校验误差：16.38, 准确率：0.10
# no transfer网络：第0试验，比例10, 第9周期，第(0/938)个撮，训练误差：18.73, 校验误差：16.96, 准确率：0.12
# no transfer网络：第0试验，比例10, 第10周期，第(0/938)个撮，训练误差：17.05, 校验误差：16.67, 准确率：0.10
# no transfer网络：第0试验，比例10, 第11周期，第(0/938)个撮，训练误差：15.87, 校验误差：16.82, 准确率：0.10
# no transfer网络：第0试验，比例10, 第12周期，第(0/938)个撮，训练误差：15.77, 校验误差：17.06, 准确率：0.10
# no transfer网络：第0试验，比例10, 第13周期，第(0/938)个撮，训练误差：18.06, 校验误差：17.12, 准确率：0.10
# no transfer网络：第0试验，比例10, 第14周期，第(0/938)个撮，训练误差：16.29, 校验误差：16.56, 准确率：0.10
# no transfer网络：第0试验，比例10, 第15周期，第(0/938)个撮，训练误差：17.59, 校验误差：16.35, 准确率：0.11
# no transfer网络：第0试验，比例10, 第16周期，第(0/938)个撮，训练误差：18.47, 校验误差：17.46, 准确率：0.08
# no transfer网络：第0试验，比例10, 第17周期，第(0/938)个撮，训练误差：18.78, 校验误差：16.74, 准确率：0.11
# no transfer网络：第0试验，比例10, 第18周期，第(0/938)个撮，训练误差：19.40, 校验误差：16.61, 准确率：0.10
# no transfer网络：第0试验，比例10, 第19周期，第(0/938)个撮，训练误差：16.23, 校验误差：16.50, 准确率：0.10
# no transfer 0 10
# no transfer网络：第0试验，比例8, 第0周期，第(0/938)个撮，训练误差：87.47, 校验误差：92.75, 准确率：0.01
# no transfer网络：第0试验，比例8, 第1周期，第(0/938)个撮，训练误差：25.59, 校验误差：19.54, 准确率：0.08
# no transfer网络：第0试验，比例8, 第2周期，第(0/938)个撮，训练误差：17.93, 校验误差：17.00, 准确率：0.10
# no transfer网络：第0试验，比例8, 第3周期，第(0/938)个撮，训练误差：15.62, 校验误差：17.30, 准确率：0.09
# no transfer网络：第0试验，比例8, 第4周期，第(0/938)个撮，训练误差：19.65, 校验误差：16.67, 准确率：0.11
# no transfer网络：第0试验，比例8, 第5周期，第(0/938)个撮，训练误差：21.37, 校验误差：16.58, 准确率：0.10
# no transfer网络：第0试验，比例8, 第6周期，第(0/938)个撮，训练误差：12.88, 校验误差：17.12, 准确率：0.09
# no transfer网络：第0试验，比例8, 第7周期，第(0/938)个撮，训练误差：14.87, 校验误差：16.26, 准确率：0.09
# no transfer网络：第0试验，比例8, 第8周期，第(0/938)个撮，训练误差：15.36, 校验误差：17.00, 准确率：0.10
# no transfer网络：第0试验，比例8, 第9周期，第(0/938)个撮，训练误差：17.47, 校验误差：16.73, 准确率：0.11
# no transfer网络：第0试验，比例8, 第10周期，第(0/938)个撮，训练误差：16.41, 校验误差：17.12, 准确率：0.11
# no transfer网络：第0试验，比例8, 第11周期，第(0/938)个撮，训练误差：13.19, 校验误差：17.46, 准确率：0.09
# no transfer网络：第0试验，比例8, 第12周期，第(0/938)个撮，训练误差：18.78, 校验误差：16.78, 准确率：0.10
# no transfer网络：第0试验，比例8, 第13周期，第(0/938)个撮，训练误差：22.69, 校验误差：16.89, 准确率：0.10
# no transfer网络：第0试验，比例8, 第14周期，第(0/938)个撮，训练误差：18.51, 校验误差：16.67, 准确率：0.10
# no transfer网络：第0试验，比例8, 第15周期，第(0/938)个撮，训练误差：17.24, 校验误差：16.45, 准确率：0.11
# no transfer网络：第0试验，比例8, 第16周期，第(0/938)个撮，训练误差：15.66, 校验误差：16.93, 准确率：0.10
# no transfer网络：第0试验，比例8, 第17周期，第(0/938)个撮，训练误差：18.04, 校验误差：16.89, 准确率：0.10
# no transfer网络：第0试验，比例8, 第18周期，第(0/938)个撮，训练误差：19.85, 校验误差：17.31, 准确率：0.09
# no transfer网络：第0试验，比例8, 第19周期，第(0/938)个撮，训练误差：15.14, 校验误差：16.68, 准确率：0.10
# no transfer 0 8
# no transfer网络：第0试验，比例6, 第0周期，第(0/938)个撮，训练误差：95.18, 校验误差：95.43, 准确率：0.01
# no transfer网络：第0试验，比例6, 第1周期，第(0/938)个撮，训练误差：16.74, 校验误差：17.06, 准确率：0.10
# no transfer网络：第0试验，比例6, 第2周期，第(0/938)个撮，训练误差：13.10, 校验误差：16.63, 准确率：0.10
# no transfer网络：第0试验，比例6, 第3周期，第(0/938)个撮，训练误差：21.10, 校验误差：17.50, 准确率：0.09
# no transfer网络：第0试验，比例6, 第4周期，第(0/938)个撮，训练误差：13.21, 校验误差：17.14, 准确率：0.10
# no transfer网络：第0试验，比例6, 第5周期，第(0/938)个撮，训练误差：18.93, 校验误差：16.75, 准确率：0.11
# no transfer网络：第0试验，比例6, 第6周期，第(0/938)个撮，训练误差：14.60, 校验误差：16.72, 准确率：0.10
# no transfer网络：第0试验，比例6, 第7周期，第(0/938)个撮，训练误差：21.12, 校验误差：16.47, 准确率：0.11
# no transfer网络：第0试验，比例6, 第8周期，第(0/938)个撮，训练误差：19.02, 校验误差：17.23, 准确率：0.10
# no transfer网络：第0试验，比例6, 第9周期，第(0/938)个撮，训练误差：19.22, 校验误差：16.45, 准确率：0.10
# no transfer网络：第0试验，比例6, 第10周期，第(0/938)个撮，训练误差：19.85, 校验误差：17.28, 准确率：0.10
# no transfer网络：第0试验，比例6, 第11周期，第(0/938)个撮，训练误差：12.85, 校验误差：17.13, 准确率：0.10
# no transfer网络：第0试验，比例6, 第12周期，第(0/938)个撮，训练误差：13.61, 校验误差：17.49, 准确率：0.10
# no transfer网络：第0试验，比例6, 第13周期，第(0/938)个撮，训练误差：15.56, 校验误差：16.58, 准确率：0.09
# no transfer网络：第0试验，比例6, 第14周期，第(0/938)个撮，训练误差：10.44, 校验误差：16.89, 准确率：0.09
# no transfer网络：第0试验，比例6, 第15周期，第(0/938)个撮，训练误差：14.73, 校验误差：16.62, 准确率：0.10
# no transfer网络：第0试验，比例6, 第16周期，第(0/938)个撮，训练误差：15.20, 校验误差：16.56, 准确率：0.11
# no transfer网络：第0试验，比例6, 第17周期，第(0/938)个撮，训练误差：15.00, 校验误差：16.09, 准确率：0.10
# no transfer网络：第0试验，比例6, 第18周期，第(0/938)个撮，训练误差：17.13, 校验误差：17.18, 准确率：0.09
# no transfer网络：第0试验，比例6, 第19周期，第(0/938)个撮，训练误差：20.14, 校验误差：16.40, 准确率：0.10
# no transfer 0 6
# no transfer网络：第0试验，比例5, 第0周期，第(0/938)个撮，训练误差：95.63, 校验误差：98.62, 准确率：0.01
# no transfer网络：第0试验，比例5, 第1周期，第(0/938)个撮，训练误差：18.87, 校验误差：16.93, 准确率：0.10
# no transfer网络：第0试验，比例5, 第2周期，第(0/938)个撮，训练误差：17.75, 校验误差：17.23, 准确率：0.09
# no transfer网络：第0试验，比例5, 第3周期，第(0/938)个撮，训练误差：14.10, 校验误差：16.77, 准确率：0.10
# no transfer网络：第0试验，比例5, 第4周期，第(0/938)个撮，训练误差：16.72, 校验误差：17.32, 准确率：0.10
# no transfer网络：第0试验，比例5, 第5周期，第(0/938)个撮，训练误差：14.82, 校验误差：16.99, 准确率：0.10
# no transfer网络：第0试验，比例5, 第6周期，第(0/938)个撮，训练误差：16.93, 校验误差：16.58, 准确率：0.10
# no transfer网络：第0试验，比例5, 第7周期，第(0/938)个撮，训练误差：18.78, 校验误差：16.68, 准确率：0.10
# no transfer网络：第0试验，比例5, 第8周期，第(0/938)个撮，训练误差：17.29, 校验误差：17.02, 准确率：0.09
# no transfer网络：第0试验，比例5, 第9周期，第(0/938)个撮，训练误差：15.97, 校验误差：16.64, 准确率：0.11
# no transfer网络：第0试验，比例5, 第10周期，第(0/938)个撮，训练误差：18.86, 校验误差：16.94, 准确率：0.10
# no transfer网络：第0试验，比例5, 第11周期，第(0/938)个撮，训练误差：17.52, 校验误差：16.93, 准确率：0.09
# no transfer网络：第0试验，比例5, 第12周期，第(0/938)个撮，训练误差：19.74, 校验误差：17.04, 准确率：0.09
# no transfer网络：第0试验，比例5, 第13周期，第(0/938)个撮，训练误差：17.71, 校验误差：16.65, 准确率：0.10
# no transfer网络：第0试验，比例5, 第14周期，第(0/938)个撮，训练误差：15.84, 校验误差：17.08, 准确率：0.10
# no transfer网络：第0试验，比例5, 第15周期，第(0/938)个撮，训练误差：17.67, 校验误差：17.03, 准确率：0.09
# no transfer网络：第0试验，比例5, 第16周期，第(0/938)个撮，训练误差：22.06, 校验误差：16.64, 准确率：0.10
# no transfer网络：第0试验，比例5, 第17周期，第(0/938)个撮，训练误差：14.84, 校验误差：16.78, 准确率：0.10
# no transfer网络：第0试验，比例5, 第18周期，第(0/938)个撮，训练误差：14.19, 校验误差：16.74, 准确率：0.10
# no transfer网络：第0试验，比例5, 第19周期，第(0/938)个撮，训练误差：21.56, 校验误差：16.89, 准确率：0.10
# no transfer 0 5
# no transfer网络：第0试验，比例4, 第0周期，第(0/938)个撮，训练误差：83.94, 校验误差：95.64, 准确率：0.01
# no transfer网络：第0试验，比例4, 第1周期，第(0/938)个撮，训练误差：13.72, 校验误差：17.16, 准确率：0.11
# no transfer网络：第0试验，比例4, 第2周期，第(0/938)个撮，训练误差：16.12, 校验误差：17.29, 准确率：0.10
# no transfer网络：第0试验，比例4, 第3周期，第(0/938)个撮，训练误差：12.19, 校验误差：16.43, 准确率：0.11
# no transfer网络：第0试验，比例4, 第4周期，第(0/938)个撮，训练误差：14.13, 校验误差：16.66, 准确率：0.10
# no transfer网络：第0试验，比例4, 第5周期，第(0/938)个撮，训练误差：22.01, 校验误差：17.05, 准确率：0.10
# no transfer网络：第0试验，比例4, 第6周期，第(0/938)个撮，训练误差：15.75, 校验误差：16.75, 准确率：0.10
# no transfer网络：第0试验，比例4, 第7周期，第(0/938)个撮，训练误差：20.28, 校验误差：16.74, 准确率：0.11
# no transfer网络：第0试验，比例4, 第8周期，第(0/938)个撮，训练误差：18.96, 校验误差：16.90, 准确率：0.11
# no transfer网络：第0试验，比例4, 第9周期，第(0/938)个撮，训练误差：16.73, 校验误差：16.84, 准确率：0.09
# no transfer网络：第0试验，比例4, 第10周期，第(0/938)个撮，训练误差：19.20, 校验误差：16.44, 准确率：0.10
# no transfer网络：第0试验，比例4, 第11周期，第(0/938)个撮，训练误差：18.97, 校验误差：16.96, 准确率：0.10
# no transfer网络：第0试验，比例4, 第12周期，第(0/938)个撮，训练误差：15.08, 校验误差：16.15, 准确率：0.11
# no transfer网络：第0试验，比例4, 第13周期，第(0/938)个撮，训练误差：16.70, 校验误差：16.89, 准确率：0.10
# no transfer网络：第0试验，比例4, 第14周期，第(0/938)个撮，训练误差：13.93, 校验误差：16.12, 准确率：0.10
# no transfer网络：第0试验，比例4, 第15周期，第(0/938)个撮，训练误差：16.77, 校验误差：16.48, 准确率：0.10
# no transfer网络：第0试验，比例4, 第16周期，第(0/938)个撮，训练误差：17.54, 校验误差：16.73, 准确率：0.10
# no transfer网络：第0试验，比例4, 第17周期，第(0/938)个撮，训练误差：15.35, 校验误差：16.96, 准确率：0.10
# no transfer网络：第0试验，比例4, 第18周期，第(0/938)个撮，训练误差：13.13, 校验误差：16.50, 准确率：0.10
# no transfer网络：第0试验，比例4, 第19周期，第(0/938)个撮，训练误差：15.95, 校验误差：16.72, 准确率：0.10
# no transfer 0 4
# no transfer网络：第0试验，比例3, 第0周期，第(0/938)个撮，训练误差：90.70, 校验误差：96.36, 准确率：0.01
# no transfer网络：第0试验，比例3, 第1周期，第(0/938)个撮，训练误差：18.13, 校验误差：16.35, 准确率：0.11
# no transfer网络：第0试验，比例3, 第2周期，第(0/938)个撮，训练误差：16.90, 校验误差：16.94, 准确率：0.09
# no transfer网络：第0试验，比例3, 第3周期，第(0/938)个撮，训练误差：21.43, 校验误差：16.53, 准确率：0.10
# no transfer网络：第0试验，比例3, 第4周期，第(0/938)个撮，训练误差：16.70, 校验误差：16.33, 准确率：0.10
# no transfer网络：第0试验，比例3, 第5周期，第(0/938)个撮，训练误差：16.83, 校验误差：16.85, 准确率：0.10
# no transfer网络：第0试验，比例3, 第6周期，第(0/938)个撮，训练误差：17.18, 校验误差：16.91, 准确率：0.11
# no transfer网络：第0试验，比例3, 第7周期，第(0/938)个撮，训练误差：19.14, 校验误差：17.29, 准确率：0.09
# no transfer网络：第0试验，比例3, 第8周期，第(0/938)个撮，训练误差：16.44, 校验误差：17.25, 准确率：0.10
# no transfer网络：第0试验，比例3, 第9周期，第(0/938)个撮，训练误差：14.42, 校验误差：16.75, 准确率：0.11
# no transfer网络：第0试验，比例3, 第10周期，第(0/938)个撮，训练误差：17.73, 校验误差：16.85, 准确率：0.10
# no transfer网络：第0试验，比例3, 第11周期，第(0/938)个撮，训练误差：16.64, 校验误差：16.95, 准确率：0.10
# no transfer网络：第0试验，比例3, 第12周期，第(0/938)个撮，训练误差：16.34, 校验误差：16.37, 准确率：0.10
# no transfer网络：第0试验，比例3, 第13周期，第(0/938)个撮，训练误差：21.73, 校验误差：16.56, 准确率：0.10
# no transfer网络：第0试验，比例3, 第14周期，第(0/938)个撮，训练误差：9.71, 校验误差：16.68, 准确率：0.11
# no transfer网络：第0试验，比例3, 第15周期，第(0/938)个撮，训练误差：17.65, 校验误差：17.84, 准确率：0.09
# no transfer网络：第0试验，比例3, 第16周期，第(0/938)个撮，训练误差：18.92, 校验误差：16.54, 准确率：0.10
# no transfer网络：第0试验，比例3, 第17周期，第(0/938)个撮，训练误差：18.33, 校验误差：16.73, 准确率：0.10
# no transfer网络：第0试验，比例3, 第18周期，第(0/938)个撮，训练误差：16.90, 校验误差：17.05, 准确率：0.09
# no transfer网络：第0试验，比例3, 第19周期，第(0/938)个撮，训练误差：14.72, 校验误差：16.70, 准确率：0.10
# no transfer 0 3
# no transfer网络：第0试验，比例2, 第0周期，第(0/938)个撮，训练误差：105.24, 校验误差：98.85, 准确率：0.01
# no transfer网络：第0试验，比例2, 第1周期，第(0/938)个撮，训练误差：14.09, 校验误差：16.91, 准确率：0.10
# no transfer网络：第0试验，比例2, 第2周期，第(0/938)个撮，训练误差：17.14, 校验误差：16.32, 准确率：0.11
# no transfer网络：第0试验，比例2, 第3周期，第(0/938)个撮，训练误差：18.87, 校验误差：16.40, 准确率：0.10
# no transfer网络：第0试验，比例2, 第4周期，第(0/938)个撮，训练误差：13.51, 校验误差：16.51, 准确率：0.10
# no transfer网络：第0试验，比例2, 第5周期，第(0/938)个撮，训练误差：17.11, 校验误差：17.08, 准确率：0.10
# no transfer网络：第0试验，比例2, 第6周期，第(0/938)个撮，训练误差：17.62, 校验误差：17.07, 准确率：0.11
# no transfer网络：第0试验，比例2, 第7周期，第(0/938)个撮，训练误差：19.57, 校验误差：16.80, 准确率：0.10
# no transfer网络：第0试验，比例2, 第8周期，第(0/938)个撮，训练误差：18.84, 校验误差：16.56, 准确率：0.10
# no transfer网络：第0试验，比例2, 第9周期，第(0/938)个撮，训练误差：16.23, 校验误差：16.46, 准确率：0.10
# no transfer网络：第0试验，比例2, 第10周期，第(0/938)个撮，训练误差：15.45, 校验误差：16.66, 准确率：0.10
# no transfer网络：第0试验，比例2, 第11周期，第(0/938)个撮，训练误差：17.67, 校验误差：17.00, 准确率：0.11
# no transfer网络：第0试验，比例2, 第12周期，第(0/938)个撮，训练误差：14.88, 校验误差：16.70, 准确率：0.10
# no transfer网络：第0试验，比例2, 第13周期，第(0/938)个撮，训练误差：19.07, 校验误差：17.02, 准确率：0.09
# no transfer网络：第0试验，比例2, 第14周期，第(0/938)个撮，训练误差：14.54, 校验误差：17.18, 准确率：0.09
# no transfer网络：第0试验，比例2, 第15周期，第(0/938)个撮，训练误差：22.51, 校验误差：16.79, 准确率：0.09
# no transfer网络：第0试验，比例2, 第16周期，第(0/938)个撮，训练误差：16.87, 校验误差：16.62, 准确率：0.09
# no transfer网络：第0试验，比例2, 第17周期，第(0/938)个撮，训练误差：20.06, 校验误差：16.76, 准确率：0.10
# no transfer网络：第0试验，比例2, 第18周期，第(0/938)个撮，训练误差：16.22, 校验误差：16.45, 准确率：0.10
# no transfer网络：第0试验，比例2, 第19周期，第(0/938)个撮，训练误差：16.63, 校验误差：16.77, 准确率：0.10
# no transfer 0 2
# no transfer网络：第0试验，比例1, 第0周期，第(0/938)个撮，训练误差：91.83, 校验误差：95.72, 准确率：0.01
# no transfer网络：第0试验，比例1, 第0周期，第(500/938)个撮，训练误差：29.78, 校验误差：16.95, 准确率：0.10
# no transfer网络：第0试验，比例1, 第1周期，第(0/938)个撮，训练误差：16.21, 校验误差：16.95, 准确率：0.10
# no transfer网络：第0试验，比例1, 第1周期，第(500/938)个撮，训练误差：17.02, 校验误差：16.72, 准确率：0.10
# no transfer网络：第0试验，比例1, 第2周期，第(0/938)个撮，训练误差：17.83, 校验误差：17.04, 准确率：0.09
# no transfer网络：第0试验，比例1, 第2周期，第(500/938)个撮，训练误差：16.77, 校验误差：16.59, 准确率：0.10
# no transfer网络：第0试验，比例1, 第3周期，第(0/938)个撮，训练误差：18.86, 校验误差：16.80, 准确率：0.10
# no transfer网络：第0试验，比例1, 第3周期，第(500/938)个撮，训练误差：16.99, 校验误差：16.87, 准确率：0.10
# no transfer网络：第0试验，比例1, 第4周期，第(0/938)个撮，训练误差：18.48, 校验误差：17.07, 准确率：0.08
# no transfer网络：第0试验，比例1, 第4周期，第(500/938)个撮，训练误差：16.90, 校验误差：16.76, 准确率：0.10
# no transfer网络：第0试验，比例1, 第5周期，第(0/938)个撮，训练误差：14.87, 校验误差：17.08, 准确率：0.10
# no transfer网络：第0试验，比例1, 第5周期，第(500/938)个撮，训练误差：16.82, 校验误差：17.08, 准确率：0.10
# no transfer网络：第0试验，比例1, 第6周期，第(0/938)个撮，训练误差：13.19, 校验误差：16.82, 准确率：0.10
# no transfer网络：第0试验，比例1, 第6周期，第(500/938)个撮，训练误差：16.79, 校验误差：16.71, 准确率：0.10
# no transfer网络：第0试验，比例1, 第7周期，第(0/938)个撮，训练误差：22.42, 校验误差：16.69, 准确率：0.11
# no transfer网络：第0试验，比例1, 第7周期，第(500/938)个撮，训练误差：16.73, 校验误差：16.67, 准确率：0.11
# no transfer网络：第0试验，比例1, 第8周期，第(0/938)个撮，训练误差：15.05, 校验误差：16.84, 准确率：0.09
# no transfer网络：第0试验，比例1, 第8周期，第(500/938)个撮，训练误差：16.88, 校验误差：17.13, 准确率：0.10
# no transfer网络：第0试验，比例1, 第9周期，第(0/938)个撮，训练误差：16.95, 校验误差：16.64, 准确率：0.11
# no transfer网络：第0试验，比例1, 第9周期，第(500/938)个撮，训练误差：16.92, 校验误差：16.61, 准确率：0.10
# no transfer网络：第0试验，比例1, 第10周期，第(0/938)个撮，训练误差：22.42, 校验误差：16.97, 准确率：0.10
# no transfer网络：第0试验，比例1, 第10周期，第(500/938)个撮，训练误差：16.81, 校验误差：16.71, 准确率：0.10
# no transfer网络：第0试验，比例1, 第11周期，第(0/938)个撮，训练误差：17.01, 校验误差：16.63, 准确率：0.10
# no transfer网络：第0试验，比例1, 第11周期，第(500/938)个撮，训练误差：16.96, 校验误差：16.99, 准确率：0.10
# no transfer网络：第0试验，比例1, 第12周期，第(0/938)个撮，训练误差：17.58, 校验误差：16.97, 准确率：0.09
# no transfer网络：第0试验，比例1, 第12周期，第(500/938)个撮，训练误差：16.80, 校验误差：16.39, 准确率：0.10
# no transfer网络：第0试验，比例1, 第13周期，第(0/938)个撮，训练误差：13.34, 校验误差：16.94, 准确率：0.10
# no transfer网络：第0试验，比例1, 第13周期，第(500/938)个撮，训练误差：16.70, 校验误差：17.34, 准确率：0.09
# no transfer网络：第0试验，比例1, 第14周期，第(0/938)个撮，训练误差：12.46, 校验误差：16.54, 准确率：0.10
# no transfer网络：第0试验，比例1, 第14周期，第(500/938)个撮，训练误差：16.87, 校验误差：16.71, 准确率：0.11
# no transfer网络：第0试验，比例1, 第15周期，第(0/938)个撮，训练误差：19.93, 校验误差：16.89, 准确率：0.09
# no transfer网络：第0试验，比例1, 第15周期，第(500/938)个撮，训练误差：16.80, 校验误差：16.54, 准确率：0.10
# no transfer网络：第0试验，比例1, 第16周期，第(0/938)个撮，训练误差：18.72, 校验误差：16.38, 准确率：0.10
# no transfer网络：第0试验，比例1, 第16周期，第(500/938)个撮，训练误差：16.75, 校验误差：17.08, 准确率：0.09
# no transfer网络：第0试验，比例1, 第17周期，第(0/938)个撮，训练误差：15.58, 校验误差：16.94, 准确率：0.10
# no transfer网络：第0试验，比例1, 第17周期，第(500/938)个撮，训练误差：16.90, 校验误差：16.90, 准确率：0.10
# no transfer网络：第0试验，比例1, 第18周期，第(0/938)个撮，训练误差：17.20, 校验误差：16.41, 准确率：0.10
# no transfer网络：第0试验，比例1, 第18周期，第(500/938)个撮，训练误差：16.68, 校验误差：16.96, 准确率：0.10
# no transfer网络：第0试验，比例1, 第19周期，第(0/938)个撮，训练误差：14.62, 校验误差：17.02, 准确率：0.10
# no transfer网络：第0试验，比例1, 第19周期，第(500/938)个撮，训练误差：16.82, 校验误差：16.74, 准确率：0.09
# no transfer 0 1
# no transfer网络：第1试验，比例20, 第0周期，第(0/938)个撮，训练误差：100.34, 校验误差：99.74, 准确率：0.01
# no transfer网络：第1试验，比例20, 第1周期，第(0/938)个撮，训练误差：65.75, 校验误差：80.83, 准确率：0.02
# no transfer网络：第1试验，比例20, 第2周期，第(0/938)个撮，训练误差：23.62, 校验误差：21.85, 准确率：0.08
# no transfer网络：第1试验，比例20, 第3周期，第(0/938)个撮，训练误差：17.08, 校验误差：17.50, 准确率：0.10
# no transfer网络：第1试验，比例20, 第4周期，第(0/938)个撮，训练误差：18.40, 校验误差：17.41, 准确率：0.10
# no transfer网络：第1试验，比例20, 第5周期，第(0/938)个撮，训练误差：16.43, 校验误差：17.24, 准确率：0.11
# no transfer网络：第1试验，比例20, 第6周期，第(0/938)个撮，训练误差：16.86, 校验误差：16.79, 准确率：0.11
# no transfer网络：第1试验，比例20, 第7周期，第(0/938)个撮，训练误差：18.82, 校验误差：17.20, 准确率：0.09
# no transfer网络：第1试验，比例20, 第8周期，第(0/938)个撮，训练误差：15.85, 校验误差：17.83, 准确率：0.09
# no transfer网络：第1试验，比例20, 第9周期，第(0/938)个撮，训练误差：19.91, 校验误差：17.13, 准确率：0.11
# no transfer网络：第1试验，比例20, 第10周期，第(0/938)个撮，训练误差：21.69, 校验误差：17.01, 准确率：0.11
# no transfer网络：第1试验，比例20, 第11周期，第(0/938)个撮，训练误差：14.24, 校验误差：17.38, 准确率：0.08
# no transfer网络：第1试验，比例20, 第12周期，第(0/938)个撮，训练误差：16.83, 校验误差：16.92, 准确率：0.10
# no transfer网络：第1试验，比例20, 第13周期，第(0/938)个撮，训练误差：18.92, 校验误差：16.58, 准确率：0.10
# no transfer网络：第1试验，比例20, 第14周期，第(0/938)个撮，训练误差：13.83, 校验误差：16.92, 准确率：0.10
# no transfer网络：第1试验，比例20, 第15周期，第(0/938)个撮，训练误差：13.07, 校验误差：17.26, 准确率：0.09
# no transfer网络：第1试验，比例20, 第16周期，第(0/938)个撮，训练误差：16.82, 校验误差：16.92, 准确率：0.10
# no transfer网络：第1试验，比例20, 第17周期，第(0/938)个撮，训练误差：15.88, 校验误差：16.64, 准确率：0.11
# no transfer网络：第1试验，比例20, 第18周期，第(0/938)个撮，训练误差：15.81, 校验误差：16.46, 准确率：0.11
# no transfer网络：第1试验，比例20, 第19周期，第(0/938)个撮，训练误差：17.48, 校验误差：16.43, 准确率：0.11
# no transfer 1 20
# no transfer网络：第1试验，比例10, 第0周期，第(0/938)个撮，训练误差：102.23, 校验误差：96.32, 准确率：0.01
# no transfer网络：第1试验，比例10, 第1周期，第(0/938)个撮，训练误差：54.39, 校验误差：48.28, 准确率：0.04
# no transfer网络：第1试验，比例10, 第2周期，第(0/938)个撮，训练误差：20.13, 校验误差：17.49, 准确率：0.09
# no transfer网络：第1试验，比例10, 第3周期，第(0/938)个撮，训练误差：17.59, 校验误差：17.24, 准确率：0.11
# no transfer网络：第1试验，比例10, 第4周期，第(0/938)个撮，训练误差：15.44, 校验误差：16.93, 准确率：0.10
# no transfer网络：第1试验，比例10, 第5周期，第(0/938)个撮，训练误差：12.95, 校验误差：16.94, 准确率：0.11
# no transfer网络：第1试验，比例10, 第6周期，第(0/938)个撮，训练误差：19.43, 校验误差：16.61, 准确率：0.11
# no transfer网络：第1试验，比例10, 第7周期，第(0/938)个撮，训练误差：14.29, 校验误差：17.02, 准确率：0.11
# no transfer网络：第1试验，比例10, 第8周期，第(0/938)个撮，训练误差：13.32, 校验误差：16.78, 准确率：0.10
# no transfer网络：第1试验，比例10, 第9周期，第(0/938)个撮，训练误差：15.40, 校验误差：17.05, 准确率：0.09
# no transfer网络：第1试验，比例10, 第10周期，第(0/938)个撮，训练误差：18.88, 校验误差：16.55, 准确率：0.11
# no transfer网络：第1试验，比例10, 第11周期，第(0/938)个撮，训练误差：15.06, 校验误差：16.75, 准确率：0.11
# no transfer网络：第1试验，比例10, 第12周期，第(0/938)个撮，训练误差：16.42, 校验误差：17.16, 准确率：0.10
# no transfer网络：第1试验，比例10, 第13周期，第(0/938)个撮，训练误差：16.49, 校验误差：16.95, 准确率：0.11
# no transfer网络：第1试验，比例10, 第14周期，第(0/938)个撮，训练误差：16.09, 校验误差：17.32, 准确率：0.09
# no transfer网络：第1试验，比例10, 第15周期，第(0/938)个撮，训练误差：13.82, 校验误差：16.12, 准确率：0.10
# no transfer网络：第1试验，比例10, 第16周期，第(0/938)个撮，训练误差：16.93, 校验误差：17.00, 准确率：0.10
# no transfer网络：第1试验，比例10, 第17周期，第(0/938)个撮，训练误差：17.53, 校验误差：16.18, 准确率：0.11
# no transfer网络：第1试验，比例10, 第18周期，第(0/938)个撮，训练误差：17.99, 校验误差：16.78, 准确率：0.09
# no transfer网络：第1试验，比例10, 第19周期，第(0/938)个撮，训练误差：18.31, 校验误差：16.41, 准确率：0.11
# no transfer 1 10
# no transfer网络：第1试验，比例8, 第0周期，第(0/938)个撮，训练误差：83.32, 校验误差：93.19, 准确率：0.01
# no transfer网络：第1试验，比例8, 第1周期，第(0/938)个撮，训练误差：14.71, 校验误差：17.53, 准确率：0.08
# no transfer网络：第1试验，比例8, 第2周期，第(0/938)个撮，训练误差：19.66, 校验误差：17.31, 准确率：0.09
# no transfer网络：第1试验，比例8, 第3周期，第(0/938)个撮，训练误差：19.99, 校验误差：17.13, 准确率：0.10
# no transfer网络：第1试验，比例8, 第4周期，第(0/938)个撮，训练误差：17.35, 校验误差：17.08, 准确率：0.09
# no transfer网络：第1试验，比例8, 第5周期，第(0/938)个撮，训练误差：17.64, 校验误差：16.74, 准确率：0.10
# no transfer网络：第1试验，比例8, 第6周期，第(0/938)个撮，训练误差：18.09, 校验误差：16.66, 准确率：0.10
# no transfer网络：第1试验，比例8, 第7周期，第(0/938)个撮，训练误差：13.40, 校验误差：16.67, 准确率：0.10
# no transfer网络：第1试验，比例8, 第8周期，第(0/938)个撮，训练误差：13.78, 校验误差：17.08, 准确率：0.10
# no transfer网络：第1试验，比例8, 第9周期，第(0/938)个撮，训练误差：16.16, 校验误差：16.82, 准确率：0.10
# no transfer网络：第1试验，比例8, 第10周期，第(0/938)个撮，训练误差：18.34, 校验误差：16.71, 准确率：0.11
# no transfer网络：第1试验，比例8, 第11周期，第(0/938)个撮，训练误差：14.12, 校验误差：17.20, 准确率：0.09
# no transfer网络：第1试验，比例8, 第12周期，第(0/938)个撮，训练误差：14.56, 校验误差：16.62, 准确率：0.11
# no transfer网络：第1试验，比例8, 第13周期，第(0/938)个撮，训练误差：18.75, 校验误差：16.41, 准确率：0.11
# no transfer网络：第1试验，比例8, 第14周期，第(0/938)个撮，训练误差：19.85, 校验误差：17.00, 准确率：0.10
# no transfer网络：第1试验，比例8, 第15周期，第(0/938)个撮，训练误差：19.59, 校验误差：16.73, 准确率：0.11
# no transfer网络：第1试验，比例8, 第16周期，第(0/938)个撮，训练误差：16.90, 校验误差：16.67, 准确率：0.11
# no transfer网络：第1试验，比例8, 第17周期，第(0/938)个撮，训练误差：12.55, 校验误差：16.07, 准确率：0.10
# no transfer网络：第1试验，比例8, 第18周期，第(0/938)个撮，训练误差：15.27, 校验误差：16.68, 准确率：0.10
# no transfer网络：第1试验，比例8, 第19周期，第(0/938)个撮，训练误差：22.21, 校验误差：16.79, 准确率：0.10
# no transfer 1 8
# no transfer网络：第1试验，比例6, 第0周期，第(0/938)个撮，训练误差：109.86, 校验误差：98.09, 准确率：0.01
# no transfer网络：第1试验，比例6, 第1周期，第(0/938)个撮，训练误差：14.22, 校验误差：17.34, 准确率：0.09
# no transfer网络：第1试验，比例6, 第2周期，第(0/938)个撮，训练误差：20.03, 校验误差：16.68, 准确率：0.10
# no transfer网络：第1试验，比例6, 第3周期，第(0/938)个撮，训练误差：18.95, 校验误差：16.85, 准确率：0.11
# no transfer网络：第1试验，比例6, 第4周期，第(0/938)个撮，训练误差：15.51, 校验误差：16.81, 准确率：0.10
# no transfer网络：第1试验，比例6, 第5周期，第(0/938)个撮，训练误差：17.72, 校验误差：16.85, 准确率：0.10
# no transfer网络：第1试验，比例6, 第6周期，第(0/938)个撮，训练误差：18.91, 校验误差：16.83, 准确率：0.10
# no transfer网络：第1试验，比例6, 第7周期，第(0/938)个撮，训练误差：20.55, 校验误差：16.69, 准确率：0.11
# no transfer网络：第1试验，比例6, 第8周期，第(0/938)个撮，训练误差：17.13, 校验误差：16.91, 准确率：0.09
# no transfer网络：第1试验，比例6, 第9周期，第(0/938)个撮，训练误差：13.52, 校验误差：17.11, 准确率：0.10
# no transfer网络：第1试验，比例6, 第10周期，第(0/938)个撮，训练误差：19.01, 校验误差：16.35, 准确率：0.11
# no transfer网络：第1试验，比例6, 第11周期，第(0/938)个撮，训练误差：17.81, 校验误差：16.85, 准确率：0.09
# no transfer网络：第1试验，比例6, 第12周期，第(0/938)个撮，训练误差：15.03, 校验误差：16.60, 准确率：0.10
# no transfer网络：第1试验，比例6, 第13周期，第(0/938)个撮，训练误差：15.85, 校验误差：16.74, 准确率：0.09
# no transfer网络：第1试验，比例6, 第14周期，第(0/938)个撮，训练误差：17.42, 校验误差：16.95, 准确率：0.10
# no transfer网络：第1试验，比例6, 第15周期，第(0/938)个撮，训练误差：18.25, 校验误差：16.51, 准确率：0.10
# no transfer网络：第1试验，比例6, 第16周期，第(0/938)个撮，训练误差：13.62, 校验误差：16.47, 准确率：0.10
# no transfer网络：第1试验，比例6, 第17周期，第(0/938)个撮，训练误差：19.35, 校验误差：16.55, 准确率：0.10
# no transfer网络：第1试验，比例6, 第18周期，第(0/938)个撮，训练误差：15.62, 校验误差：16.54, 准确率：0.10
# no transfer网络：第1试验，比例6, 第19周期，第(0/938)个撮，训练误差：15.33, 校验误差：16.45, 准确率：0.10
# no transfer 1 6
# no transfer网络：第1试验，比例5, 第0周期，第(0/938)个撮，训练误差：82.28, 校验误差：96.45, 准确率：0.01
# no transfer网络：第1试验，比例5, 第1周期，第(0/938)个撮，训练误差：18.60, 校验误差：17.46, 准确率：0.10
# no transfer网络：第1试验，比例5, 第2周期，第(0/938)个撮，训练误差：18.70, 校验误差：16.98, 准确率：0.09
# no transfer网络：第1试验，比例5, 第3周期，第(0/938)个撮，训练误差：18.25, 校验误差：16.98, 准确率：0.10
# no transfer网络：第1试验，比例5, 第4周期，第(0/938)个撮，训练误差：15.85, 校验误差：16.54, 准确率：0.10
# no transfer网络：第1试验，比例5, 第5周期，第(0/938)个撮，训练误差：17.91, 校验误差：16.34, 准确率：0.10
# no transfer网络：第1试验，比例5, 第6周期，第(0/938)个撮，训练误差：21.94, 校验误差：16.82, 准确率：0.10
# no transfer网络：第1试验，比例5, 第7周期，第(0/938)个撮，训练误差：16.08, 校验误差：16.89, 准确率：0.10
# no transfer网络：第1试验，比例5, 第8周期，第(0/938)个撮，训练误差：18.06, 校验误差：17.06, 准确率：0.10
# no transfer网络：第1试验，比例5, 第9周期，第(0/938)个撮，训练误差：16.20, 校验误差：16.79, 准确率：0.09
# no transfer网络：第1试验，比例5, 第10周期，第(0/938)个撮，训练误差：16.18, 校验误差：16.99, 准确率：0.10
# no transfer网络：第1试验，比例5, 第11周期，第(0/938)个撮，训练误差：16.04, 校验误差：16.99, 准确率：0.09
# no transfer网络：第1试验，比例5, 第12周期，第(0/938)个撮，训练误差：15.42, 校验误差：17.06, 准确率：0.10
# no transfer网络：第1试验，比例5, 第13周期，第(0/938)个撮，训练误差：14.08, 校验误差：16.46, 准确率：0.10
# no transfer网络：第1试验，比例5, 第14周期，第(0/938)个撮，训练误差：22.15, 校验误差：16.69, 准确率：0.10
# no transfer网络：第1试验，比例5, 第15周期，第(0/938)个撮，训练误差：14.06, 校验误差：16.99, 准确率：0.10
# no transfer网络：第1试验，比例5, 第16周期，第(0/938)个撮，训练误差：18.98, 校验误差：16.88, 准确率：0.10
# no transfer网络：第1试验，比例5, 第17周期，第(0/938)个撮，训练误差：13.08, 校验误差：16.73, 准确率：0.10
# no transfer网络：第1试验，比例5, 第18周期，第(0/938)个撮，训练误差：18.20, 校验误差：16.97, 准确率：0.10
# no transfer网络：第1试验，比例5, 第19周期，第(0/938)个撮，训练误差：17.14, 校验误差：16.60, 准确率：0.10
# no transfer 1 5
# no transfer网络：第1试验，比例4, 第0周期，第(0/938)个撮，训练误差：123.27, 校验误差：102.44, 准确率：0.01
# no transfer网络：第1试验，比例4, 第1周期，第(0/938)个撮，训练误差：18.26, 校验误差：17.38, 准确率：0.08
# no transfer网络：第1试验，比例4, 第2周期，第(0/938)个撮，训练误差：23.07, 校验误差：16.72, 准确率：0.11
# no transfer网络：第1试验，比例4, 第3周期，第(0/938)个撮，训练误差：17.36, 校验误差：17.25, 准确率：0.09
# no transfer网络：第1试验，比例4, 第4周期，第(0/938)个撮，训练误差：14.40, 校验误差：16.27, 准确率：0.10
# no transfer网络：第1试验，比例4, 第5周期，第(0/938)个撮，训练误差：16.07, 校验误差：16.65, 准确率：0.10
# no transfer网络：第1试验，比例4, 第6周期，第(0/938)个撮，训练误差：18.86, 校验误差：16.73, 准确率：0.10
# no transfer网络：第1试验，比例4, 第7周期，第(0/938)个撮，训练误差：16.51, 校验误差：16.94, 准确率：0.10
# no transfer网络：第1试验，比例4, 第8周期，第(0/938)个撮，训练误差：16.85, 校验误差：16.99, 准确率：0.10
# no transfer网络：第1试验，比例4, 第9周期，第(0/938)个撮，训练误差：18.25, 校验误差：17.16, 准确率：0.10
# no transfer网络：第1试验，比例4, 第10周期，第(0/938)个撮，训练误差：14.57, 校验误差：16.88, 准确率：0.10
# no transfer网络：第1试验，比例4, 第11周期，第(0/938)个撮，训练误差：14.98, 校验误差：16.52, 准确率：0.10
# no transfer网络：第1试验，比例4, 第12周期，第(0/938)个撮，训练误差：18.61, 校验误差：17.50, 准确率：0.10
# no transfer网络：第1试验，比例4, 第13周期，第(0/938)个撮，训练误差：16.65, 校验误差：16.84, 准确率：0.10
# no transfer网络：第1试验，比例4, 第14周期，第(0/938)个撮，训练误差：14.44, 校验误差：16.92, 准确率：0.09
# no transfer网络：第1试验，比例4, 第15周期，第(0/938)个撮，训练误差：16.23, 校验误差：16.86, 准确率：0.10
# no transfer网络：第1试验，比例4, 第16周期，第(0/938)个撮，训练误差：14.42, 校验误差：16.64, 准确率：0.10
# no transfer网络：第1试验，比例4, 第17周期，第(0/938)个撮，训练误差：17.12, 校验误差：16.81, 准确率：0.10
# no transfer网络：第1试验，比例4, 第18周期，第(0/938)个撮，训练误差：18.86, 校验误差：16.75, 准确率：0.09
# no transfer网络：第1试验，比例4, 第19周期，第(0/938)个撮，训练误差：16.92, 校验误差：17.07, 准确率：0.09
# no transfer 1 4
# no transfer网络：第1试验，比例3, 第0周期，第(0/938)个撮，训练误差：104.13, 校验误差：93.85, 准确率：0.01
# no transfer网络：第1试验，比例3, 第1周期，第(0/938)个撮，训练误差：14.96, 校验误差：17.05, 准确率：0.10
# no transfer网络：第1试验，比例3, 第2周期，第(0/938)个撮，训练误差：18.55, 校验误差：16.20, 准确率：0.10
# no transfer网络：第1试验，比例3, 第3周期，第(0/938)个撮，训练误差：15.59, 校验误差：16.95, 准确率：0.10
# no transfer网络：第1试验，比例3, 第4周期，第(0/938)个撮，训练误差：17.34, 校验误差：16.59, 准确率：0.11
# no transfer网络：第1试验，比例3, 第5周期，第(0/938)个撮，训练误差：17.80, 校验误差：16.69, 准确率：0.10
# no transfer网络：第1试验，比例3, 第6周期，第(0/938)个撮，训练误差：19.79, 校验误差：16.41, 准确率：0.09
# no transfer网络：第1试验，比例3, 第7周期，第(0/938)个撮，训练误差：17.72, 校验误差：16.49, 准确率：0.09
# no transfer网络：第1试验，比例3, 第8周期，第(0/938)个撮，训练误差：17.02, 校验误差：16.75, 准确率：0.10
# no transfer网络：第1试验，比例3, 第9周期，第(0/938)个撮，训练误差：16.37, 校验误差：17.14, 准确率：0.10
# no transfer网络：第1试验，比例3, 第10周期，第(0/938)个撮，训练误差：16.05, 校验误差：16.91, 准确率：0.11
# no transfer网络：第1试验，比例3, 第11周期，第(0/938)个撮，训练误差：12.65, 校验误差：18.25, 准确率：0.09
# no transfer网络：第1试验，比例3, 第12周期，第(0/938)个撮，训练误差：18.23, 校验误差：16.58, 准确率：0.10
# no transfer网络：第1试验，比例3, 第13周期，第(0/938)个撮，训练误差：23.52, 校验误差：17.40, 准确率：0.10
# no transfer网络：第1试验，比例3, 第14周期，第(0/938)个撮，训练误差：21.24, 校验误差：16.64, 准确率：0.10
# no transfer网络：第1试验，比例3, 第15周期，第(0/938)个撮，训练误差：14.10, 校验误差：17.11, 准确率：0.10
# no transfer网络：第1试验，比例3, 第16周期，第(0/938)个撮，训练误差：16.07, 校验误差：16.74, 准确率：0.10
# no transfer网络：第1试验，比例3, 第17周期，第(0/938)个撮，训练误差：15.46, 校验误差：16.90, 准确率：0.10
# no transfer网络：第1试验，比例3, 第18周期，第(0/938)个撮，训练误差：15.31, 校验误差：16.73, 准确率：0.10
# no transfer网络：第1试验，比例3, 第19周期，第(0/938)个撮，训练误差：21.11, 校验误差：17.27, 准确率：0.10
# no transfer 1 3
# no transfer网络：第1试验，比例2, 第0周期，第(0/938)个撮，训练误差：97.60, 校验误差：93.96, 准确率：0.01
# no transfer网络：第1试验，比例2, 第1周期，第(0/938)个撮，训练误差：16.14, 校验误差：16.57, 准确率：0.10
# no transfer网络：第1试验，比例2, 第2周期，第(0/938)个撮，训练误差：15.30, 校验误差：16.56, 准确率：0.11
# no transfer网络：第1试验，比例2, 第3周期，第(0/938)个撮，训练误差：16.81, 校验误差：16.85, 准确率：0.10
# no transfer网络：第1试验，比例2, 第4周期，第(0/938)个撮，训练误差：16.89, 校验误差：16.53, 准确率：0.08
# no transfer网络：第1试验，比例2, 第5周期，第(0/938)个撮，训练误差：14.14, 校验误差：17.14, 准确率：0.10
# no transfer网络：第1试验，比例2, 第6周期，第(0/938)个撮，训练误差：18.14, 校验误差：16.96, 准确率：0.10
# no transfer网络：第1试验，比例2, 第7周期，第(0/938)个撮，训练误差：19.70, 校验误差：16.96, 准确率：0.10
# no transfer网络：第1试验，比例2, 第8周期，第(0/938)个撮，训练误差：22.88, 校验误差：17.68, 准确率：0.09
# no transfer网络：第1试验，比例2, 第9周期，第(0/938)个撮，训练误差：18.28, 校验误差：17.20, 准确率：0.10
# no transfer网络：第1试验，比例2, 第10周期，第(0/938)个撮，训练误差：13.48, 校验误差：16.86, 准确率：0.10
# no transfer网络：第1试验，比例2, 第11周期，第(0/938)个撮，训练误差：15.61, 校验误差：16.44, 准确率：0.11
# no transfer网络：第1试验，比例2, 第12周期，第(0/938)个撮，训练误差：18.37, 校验误差：16.53, 准确率：0.10
# no transfer网络：第1试验，比例2, 第13周期，第(0/938)个撮，训练误差：18.11, 校验误差：16.85, 准确率：0.10
# no transfer网络：第1试验，比例2, 第14周期，第(0/938)个撮，训练误差：13.78, 校验误差：16.76, 准确率：0.10
# no transfer网络：第1试验，比例2, 第15周期，第(0/938)个撮，训练误差：16.82, 校验误差：16.69, 准确率：0.10
# no transfer网络：第1试验，比例2, 第16周期，第(0/938)个撮，训练误差：19.22, 校验误差：16.95, 准确率：0.10
# no transfer网络：第1试验，比例2, 第17周期，第(0/938)个撮，训练误差：16.17, 校验误差：16.31, 准确率：0.10
# no transfer网络：第1试验，比例2, 第18周期，第(0/938)个撮，训练误差：16.76, 校验误差：16.62, 准确率：0.10
# no transfer网络：第1试验，比例2, 第19周期，第(0/938)个撮，训练误差：15.50, 校验误差：16.88, 准确率：0.10
# no transfer 1 2
# no transfer网络：第1试验，比例1, 第0周期，第(0/938)个撮，训练误差：90.35, 校验误差：91.92, 准确率：0.01
# no transfer网络：第1试验，比例1, 第0周期，第(500/938)个撮，训练误差：31.57, 校验误差：16.03, 准确率：0.11
# no transfer网络：第1试验，比例1, 第1周期，第(0/938)个撮，训练误差：18.83, 校验误差：17.20, 准确率：0.10
# no transfer网络：第1试验，比例1, 第1周期，第(500/938)个撮，训练误差：16.93, 校验误差：17.12, 准确率：0.10
# no transfer网络：第1试验，比例1, 第2周期，第(0/938)个撮，训练误差：17.34, 校验误差：17.21, 准确率：0.09
# no transfer网络：第1试验，比例1, 第2周期，第(500/938)个撮，训练误差：16.91, 校验误差：16.70, 准确率：0.10
# no transfer网络：第1试验，比例1, 第3周期，第(0/938)个撮，训练误差：22.14, 校验误差：16.83, 准确率：0.10
# no transfer网络：第1试验，比例1, 第3周期，第(500/938)个撮，训练误差：16.89, 校验误差：16.73, 准确率：0.10
# no transfer网络：第1试验，比例1, 第4周期，第(0/938)个撮，训练误差：16.25, 校验误差：16.87, 准确率：0.11
# no transfer网络：第1试验，比例1, 第4周期，第(500/938)个撮，训练误差：16.83, 校验误差：16.94, 准确率：0.09
# no transfer网络：第1试验，比例1, 第5周期，第(0/938)个撮，训练误差：18.53, 校验误差：16.62, 准确率：0.10
# no transfer网络：第1试验，比例1, 第5周期，第(500/938)个撮，训练误差：16.71, 校验误差：16.61, 准确率：0.10
# no transfer网络：第1试验，比例1, 第6周期，第(0/938)个撮，训练误差：21.21, 校验误差：16.67, 准确率：0.10
# no transfer网络：第1试验，比例1, 第6周期，第(500/938)个撮，训练误差：16.84, 校验误差：17.16, 准确率：0.09
# no transfer网络：第1试验，比例1, 第7周期，第(0/938)个撮，训练误差：16.58, 校验误差：17.02, 准确率：0.10
# no transfer网络：第1试验，比例1, 第7周期，第(500/938)个撮，训练误差：16.74, 校验误差：16.84, 准确率：0.10
# no transfer网络：第1试验，比例1, 第8周期，第(0/938)个撮，训练误差：17.77, 校验误差：16.64, 准确率：0.10
# no transfer网络：第1试验，比例1, 第8周期，第(500/938)个撮，训练误差：16.80, 校验误差：16.59, 准确率：0.10
# no transfer网络：第1试验，比例1, 第9周期，第(0/938)个撮，训练误差：15.62, 校验误差：16.57, 准确率：0.09
# no transfer网络：第1试验，比例1, 第9周期，第(500/938)个撮，训练误差：16.77, 校验误差：16.89, 准确率：0.10
# no transfer网络：第1试验，比例1, 第10周期，第(0/938)个撮，训练误差：15.83, 校验误差：16.52, 准确率：0.10
# no transfer网络：第1试验，比例1, 第10周期，第(500/938)个撮，训练误差：16.80, 校验误差：16.56, 准确率：0.10
# no transfer网络：第1试验，比例1, 第11周期，第(0/938)个撮，训练误差：14.68, 校验误差：16.80, 准确率：0.10
# no transfer网络：第1试验，比例1, 第11周期，第(500/938)个撮，训练误差：16.75, 校验误差：16.23, 准确率：0.10
# no transfer网络：第1试验，比例1, 第12周期，第(0/938)个撮，训练误差：17.10, 校验误差：16.90, 准确率：0.10
# no transfer网络：第1试验，比例1, 第12周期，第(500/938)个撮，训练误差：16.73, 校验误差：16.72, 准确率：0.10
# no transfer网络：第1试验，比例1, 第13周期，第(0/938)个撮，训练误差：20.92, 校验误差：16.94, 准确率：0.09
# no transfer网络：第1试验，比例1, 第13周期，第(500/938)个撮，训练误差：16.70, 校验误差：16.94, 准确率：0.09
# no transfer网络：第1试验，比例1, 第14周期，第(0/938)个撮，训练误差：14.16, 校验误差：16.92, 准确率：0.10
# no transfer网络：第1试验，比例1, 第14周期，第(500/938)个撮，训练误差：16.75, 校验误差：16.78, 准确率：0.11
# no transfer网络：第1试验，比例1, 第15周期，第(0/938)个撮，训练误差：13.51, 校验误差：16.56, 准确率：0.10
# no transfer网络：第1试验，比例1, 第15周期，第(500/938)个撮，训练误差：16.74, 校验误差：16.55, 准确率：0.10
# no transfer网络：第1试验，比例1, 第16周期，第(0/938)个撮，训练误差：15.26, 校验误差：17.20, 准确率：0.10
# no transfer网络：第1试验，比例1, 第16周期，第(500/938)个撮，训练误差：16.80, 校验误差：16.66, 准确率：0.10
# no transfer网络：第1试验，比例1, 第17周期，第(0/938)个撮，训练误差：17.37, 校验误差：16.27, 准确率：0.11
# no transfer网络：第1试验，比例1, 第17周期，第(500/938)个撮，训练误差：16.77, 校验误差：16.38, 准确率：0.10
# no transfer网络：第1试验，比例1, 第18周期，第(0/938)个撮，训练误差：13.90, 校验误差：16.98, 准确率：0.10
# no transfer网络：第1试验，比例1, 第18周期，第(500/938)个撮，训练误差：16.61, 校验误差：16.66, 准确率：0.10
# no transfer网络：第1试验，比例1, 第19周期，第(0/938)个撮，训练误差：17.22, 校验误差：16.71, 准确率：0.10
# no transfer网络：第1试验，比例1, 第19周期，第(500/938)个撮，训练误差：16.54, 校验误差：16.65, 准确率：0.11
# no transfer 1 1
# no transfer网络：第2试验，比例20, 第0周期，第(0/938)个撮，训练误差：88.77, 校验误差：93.07, 准确率：0.01
# no transfer网络：第2试验，比例20, 第1周期，第(0/938)个撮，训练误差：66.59, 校验误差：77.88, 准确率：0.02
# no transfer网络：第2试验，比例20, 第2周期，第(0/938)个撮，训练误差：61.55, 校验误差：59.08, 准确率：0.03
# no transfer网络：第2试验，比例20, 第3周期，第(0/938)个撮，训练误差：23.16, 校验误差：20.69, 准确率：0.09
# no transfer网络：第2试验，比例20, 第4周期，第(0/938)个撮，训练误差：14.16, 校验误差：17.18, 准确率：0.09
# no transfer网络：第2试验，比例20, 第5周期，第(0/938)个撮，训练误差：13.97, 校验误差：16.91, 准确率：0.10
# no transfer网络：第2试验，比例20, 第6周期，第(0/938)个撮，训练误差：18.52, 校验误差：17.18, 准确率：0.10
# no transfer网络：第2试验，比例20, 第7周期，第(0/938)个撮，训练误差：15.96, 校验误差：16.59, 准确率：0.10
# no transfer网络：第2试验，比例20, 第8周期，第(0/938)个撮，训练误差：12.71, 校验误差：17.17, 准确率：0.10
# no transfer网络：第2试验，比例20, 第9周期，第(0/938)个撮，训练误差：18.62, 校验误差：16.70, 准确率：0.10
# no transfer网络：第2试验，比例20, 第10周期，第(0/938)个撮，训练误差：14.14, 校验误差：16.82, 准确率：0.10
# no transfer网络：第2试验，比例20, 第11周期，第(0/938)个撮，训练误差：15.54, 校验误差：16.80, 准确率：0.10
# no transfer网络：第2试验，比例20, 第12周期，第(0/938)个撮，训练误差：19.11, 校验误差：16.62, 准确率：0.10
# no transfer网络：第2试验，比例20, 第13周期，第(0/938)个撮，训练误差：16.26, 校验误差：17.16, 准确率：0.10
# no transfer网络：第2试验，比例20, 第14周期，第(0/938)个撮，训练误差：14.78, 校验误差：17.06, 准确率：0.10
# no transfer网络：第2试验，比例20, 第15周期，第(0/938)个撮，训练误差：19.86, 校验误差：16.62, 准确率：0.10
# no transfer网络：第2试验，比例20, 第16周期，第(0/938)个撮，训练误差：17.59, 校验误差：16.76, 准确率：0.10
# no transfer网络：第2试验，比例20, 第17周期，第(0/938)个撮，训练误差：15.29, 校验误差：16.79, 准确率：0.11
# no transfer网络：第2试验，比例20, 第18周期，第(0/938)个撮，训练误差：17.07, 校验误差：17.04, 准确率：0.10
# no transfer网络：第2试验，比例20, 第19周期，第(0/938)个撮，训练误差：18.66, 校验误差：16.72, 准确率：0.10
# no transfer 2 20
# no transfer网络：第2试验，比例10, 第0周期，第(0/938)个撮，训练误差：104.55, 校验误差：92.07, 准确率：0.01
# no transfer网络：第2试验，比例10, 第1周期，第(0/938)个撮，训练误差：19.02, 校验误差：17.70, 准确率：0.09
# no transfer网络：第2试验，比例10, 第2周期，第(0/938)个撮，训练误差：14.55, 校验误差：16.76, 准确率：0.11
# no transfer网络：第2试验，比例10, 第3周期，第(0/938)个撮，训练误差：17.87, 校验误差：17.25, 准确率：0.11
# no transfer网络：第2试验，比例10, 第4周期，第(0/938)个撮，训练误差：15.55, 校验误差：16.86, 准确率：0.11
# no transfer网络：第2试验，比例10, 第5周期，第(0/938)个撮，训练误差：16.31, 校验误差：16.82, 准确率：0.10
# no transfer网络：第2试验，比例10, 第6周期，第(0/938)个撮，训练误差：16.54, 校验误差：17.16, 准确率：0.09
# no transfer网络：第2试验，比例10, 第7周期，第(0/938)个撮，训练误差：14.79, 校验误差：16.80, 准确率：0.10
# no transfer网络：第2试验，比例10, 第8周期，第(0/938)个撮，训练误差：11.18, 校验误差：17.14, 准确率：0.09
# no transfer网络：第2试验，比例10, 第9周期，第(0/938)个撮，训练误差：16.25, 校验误差：16.87, 准确率：0.10
# no transfer网络：第2试验，比例10, 第10周期，第(0/938)个撮，训练误差：22.35, 校验误差：16.56, 准确率：0.11
# no transfer网络：第2试验，比例10, 第11周期，第(0/938)个撮，训练误差：21.60, 校验误差：16.83, 准确率：0.09
# no transfer网络：第2试验，比例10, 第12周期，第(0/938)个撮，训练误差：12.28, 校验误差：17.58, 准确率：0.08
# no transfer网络：第2试验，比例10, 第13周期，第(0/938)个撮，训练误差：20.53, 校验误差：16.48, 准确率：0.08
# no transfer网络：第2试验，比例10, 第14周期，第(0/938)个撮，训练误差：21.07, 校验误差：16.72, 准确率：0.10
# no transfer网络：第2试验，比例10, 第15周期，第(0/938)个撮，训练误差：19.21, 校验误差：16.93, 准确率：0.09
# no transfer网络：第2试验，比例10, 第16周期，第(0/938)个撮，训练误差：16.36, 校验误差：17.39, 准确率：0.08
# no transfer网络：第2试验，比例10, 第17周期，第(0/938)个撮，训练误差：15.73, 校验误差：16.79, 准确率：0.10
# no transfer网络：第2试验，比例10, 第18周期，第(0/938)个撮，训练误差：16.76, 校验误差：16.51, 准确率：0.10
# no transfer网络：第2试验，比例10, 第19周期，第(0/938)个撮，训练误差：13.57, 校验误差：16.67, 准确率：0.09
# no transfer 2 10
# no transfer网络：第2试验，比例8, 第0周期，第(0/938)个撮，训练误差：104.71, 校验误差：98.18, 准确率：0.01
# no transfer网络：第2试验，比例8, 第1周期，第(0/938)个撮，训练误差：14.81, 校验误差：17.40, 准确率：0.09
# no transfer网络：第2试验，比例8, 第2周期，第(0/938)个撮，训练误差：12.67, 校验误差：16.81, 准确率：0.10
# no transfer网络：第2试验，比例8, 第3周期，第(0/938)个撮，训练误差：18.98, 校验误差：17.30, 准确率：0.09
# no transfer网络：第2试验，比例8, 第4周期，第(0/938)个撮，训练误差：15.37, 校验误差：16.52, 准确率：0.10
# no transfer网络：第2试验，比例8, 第5周期，第(0/938)个撮，训练误差：17.93, 校验误差：16.93, 准确率：0.10
# no transfer网络：第2试验，比例8, 第6周期，第(0/938)个撮，训练误差：13.50, 校验误差：16.56, 准确率：0.10
# no transfer网络：第2试验，比例8, 第7周期，第(0/938)个撮，训练误差：25.62, 校验误差：16.88, 准确率：0.09
# no transfer网络：第2试验，比例8, 第8周期，第(0/938)个撮，训练误差：15.52, 校验误差：16.50, 准确率：0.10
# no transfer网络：第2试验，比例8, 第9周期，第(0/938)个撮，训练误差：16.40, 校验误差：16.59, 准确率：0.10
# no transfer网络：第2试验，比例8, 第10周期，第(0/938)个撮，训练误差：15.86, 校验误差：16.68, 准确率：0.09
# no transfer网络：第2试验，比例8, 第11周期，第(0/938)个撮，训练误差：12.32, 校验误差：17.31, 准确率：0.09
# no transfer网络：第2试验，比例8, 第12周期，第(0/938)个撮，训练误差：17.07, 校验误差：16.58, 准确率：0.11
# no transfer网络：第2试验，比例8, 第13周期，第(0/938)个撮，训练误差：16.00, 校验误差：16.89, 准确率：0.10
# no transfer网络：第2试验，比例8, 第14周期，第(0/938)个撮，训练误差：13.25, 校验误差：16.56, 准确率：0.10
# no transfer网络：第2试验，比例8, 第15周期，第(0/938)个撮，训练误差：14.73, 校验误差：16.61, 准确率：0.10
# no transfer网络：第2试验，比例8, 第16周期，第(0/938)个撮，训练误差：17.29, 校验误差：16.24, 准确率：0.11
# no transfer网络：第2试验，比例8, 第17周期，第(0/938)个撮，训练误差：16.44, 校验误差：16.37, 准确率：0.10
# no transfer网络：第2试验，比例8, 第18周期，第(0/938)个撮，训练误差：16.48, 校验误差：16.48, 准确率：0.10
# no transfer网络：第2试验，比例8, 第19周期，第(0/938)个撮，训练误差：12.88, 校验误差：16.86, 准确率：0.10
# no transfer 2 8
# no transfer网络：第2试验，比例6, 第0周期，第(0/938)个撮，训练误差：107.79, 校验误差：94.36, 准确率：0.01
# no transfer网络：第2试验，比例6, 第1周期，第(0/938)个撮，训练误差：18.87, 校验误差：16.90, 准确率：0.09
# no transfer网络：第2试验，比例6, 第2周期，第(0/938)个撮，训练误差：15.12, 校验误差：16.93, 准确率：0.11
# no transfer网络：第2试验，比例6, 第3周期，第(0/938)个撮，训练误差：12.76, 校验误差：16.66, 准确率：0.10
# no transfer网络：第2试验，比例6, 第4周期，第(0/938)个撮，训练误差：15.11, 校验误差：17.57, 准确率：0.09
# no transfer网络：第2试验，比例6, 第5周期，第(0/938)个撮，训练误差：17.99, 校验误差：16.45, 准确率：0.10
# no transfer网络：第2试验，比例6, 第6周期，第(0/938)个撮，训练误差：13.64, 校验误差：16.73, 准确率：0.11
# no transfer网络：第2试验，比例6, 第7周期，第(0/938)个撮，训练误差：19.77, 校验误差：16.47, 准确率：0.11
# no transfer网络：第2试验，比例6, 第8周期，第(0/938)个撮，训练误差：15.95, 校验误差：16.58, 准确率：0.11
# no transfer网络：第2试验，比例6, 第9周期，第(0/938)个撮，训练误差：20.73, 校验误差：16.53, 准确率：0.10
# no transfer网络：第2试验，比例6, 第10周期，第(0/938)个撮，训练误差：15.03, 校验误差：17.05, 准确率：0.10
# no transfer网络：第2试验，比例6, 第11周期，第(0/938)个撮，训练误差：15.58, 校验误差：17.46, 准确率：0.10
# no transfer网络：第2试验，比例6, 第12周期，第(0/938)个撮，训练误差：14.25, 校验误差：17.01, 准确率：0.10
# no transfer网络：第2试验，比例6, 第13周期，第(0/938)个撮，训练误差：13.34, 校验误差：16.91, 准确率：0.10
# no transfer网络：第2试验，比例6, 第14周期，第(0/938)个撮，训练误差：20.11, 校验误差：17.32, 准确率：0.09
# no transfer网络：第2试验，比例6, 第15周期，第(0/938)个撮，训练误差：16.59, 校验误差：16.86, 准确率：0.10
# no transfer网络：第2试验，比例6, 第16周期，第(0/938)个撮，训练误差：15.27, 校验误差：16.62, 准确率：0.10
# no transfer网络：第2试验，比例6, 第17周期，第(0/938)个撮，训练误差：19.66, 校验误差：16.84, 准确率：0.11
# no transfer网络：第2试验，比例6, 第18周期，第(0/938)个撮，训练误差：20.33, 校验误差：16.75, 准确率：0.10
# no transfer网络：第2试验，比例6, 第19周期，第(0/938)个撮，训练误差：15.48, 校验误差：17.02, 准确率：0.10
# no transfer 2 6
# no transfer网络：第2试验，比例5, 第0周期，第(0/938)个撮，训练误差：100.48, 校验误差：101.16, 准确率：0.01
# no transfer网络：第2试验，比例5, 第1周期，第(0/938)个撮，训练误差：15.15, 校验误差：16.98, 准确率：0.10
# no transfer网络：第2试验，比例5, 第2周期，第(0/938)个撮，训练误差：23.12, 校验误差：17.67, 准确率：0.09
# no transfer网络：第2试验，比例5, 第3周期，第(0/938)个撮，训练误差：16.78, 校验误差：16.74, 准确率：0.11
# no transfer网络：第2试验，比例5, 第4周期，第(0/938)个撮，训练误差：13.51, 校验误差：16.47, 准确率：0.10
# no transfer网络：第2试验，比例5, 第5周期，第(0/938)个撮，训练误差：21.24, 校验误差：17.31, 准确率：0.10
# no transfer网络：第2试验，比例5, 第6周期，第(0/938)个撮，训练误差：16.92, 校验误差：16.55, 准确率：0.10
# no transfer网络：第2试验，比例5, 第7周期，第(0/938)个撮，训练误差：17.49, 校验误差：16.97, 准确率：0.10
# no transfer网络：第2试验，比例5, 第8周期，第(0/938)个撮，训练误差：15.87, 校验误差：16.85, 准确率：0.10
# no transfer网络：第2试验，比例5, 第9周期，第(0/938)个撮，训练误差：18.20, 校验误差：16.59, 准确率：0.10
# no transfer网络：第2试验，比例5, 第10周期，第(0/938)个撮，训练误差：15.45, 校验误差：16.49, 准确率：0.10
# no transfer网络：第2试验，比例5, 第11周期，第(0/938)个撮，训练误差：17.08, 校验误差：16.43, 准确率：0.10
# no transfer网络：第2试验，比例5, 第12周期，第(0/938)个撮，训练误差：18.81, 校验误差：17.04, 准确率：0.09
# no transfer网络：第2试验，比例5, 第13周期，第(0/938)个撮，训练误差：19.72, 校验误差：16.84, 准确率：0.11
# no transfer网络：第2试验，比例5, 第14周期，第(0/938)个撮，训练误差：18.16, 校验误差：16.87, 准确率：0.10
# no transfer网络：第2试验，比例5, 第15周期，第(0/938)个撮，训练误差：17.22, 校验误差：16.76, 准确率：0.10
# no transfer网络：第2试验，比例5, 第16周期，第(0/938)个撮，训练误差：16.88, 校验误差：16.46, 准确率：0.10
# no transfer网络：第2试验，比例5, 第17周期，第(0/938)个撮，训练误差：14.76, 校验误差：17.13, 准确率：0.09
# no transfer网络：第2试验，比例5, 第18周期，第(0/938)个撮，训练误差：14.58, 校验误差：16.68, 准确率：0.10
# no transfer网络：第2试验，比例5, 第19周期，第(0/938)个撮，训练误差：15.94, 校验误差：16.55, 准确率：0.10
# no transfer 2 5
# no transfer网络：第2试验，比例4, 第0周期，第(0/938)个撮，训练误差：98.86, 校验误差：96.99, 准确率：0.01
# no transfer网络：第2试验，比例4, 第1周期，第(0/938)个撮，训练误差：17.17, 校验误差：16.93, 准确率：0.11
# no transfer网络：第2试验，比例4, 第2周期，第(0/938)个撮，训练误差：19.37, 校验误差：17.45, 准确率：0.09
# no transfer网络：第2试验，比例4, 第3周期，第(0/938)个撮，训练误差：15.54, 校验误差：16.78, 准确率：0.10
# no transfer网络：第2试验，比例4, 第4周期，第(0/938)个撮，训练误差：17.23, 校验误差：17.27, 准确率：0.10
# no transfer网络：第2试验，比例4, 第5周期，第(0/938)个撮，训练误差：17.84, 校验误差：16.83, 准确率：0.10
# no transfer网络：第2试验，比例4, 第6周期，第(0/938)个撮，训练误差：18.35, 校验误差：16.59, 准确率：0.10
# no transfer网络：第2试验，比例4, 第7周期，第(0/938)个撮，训练误差：17.39, 校验误差：16.77, 准确率：0.10
# no transfer网络：第2试验，比例4, 第8周期，第(0/938)个撮，训练误差：16.05, 校验误差：16.66, 准确率：0.11
# no transfer网络：第2试验，比例4, 第9周期，第(0/938)个撮，训练误差：19.38, 校验误差：16.77, 准确率：0.10
# no transfer网络：第2试验，比例4, 第10周期，第(0/938)个撮，训练误差：19.73, 校验误差：16.72, 准确率：0.10
# no transfer网络：第2试验，比例4, 第11周期，第(0/938)个撮，训练误差：16.80, 校验误差：17.30, 准确率：0.09
# no transfer网络：第2试验，比例4, 第12周期，第(0/938)个撮，训练误差：17.96, 校验误差：16.74, 准确率：0.10
# no transfer网络：第2试验，比例4, 第13周期，第(0/938)个撮，训练误差：11.28, 校验误差：16.63, 准确率：0.10
# no transfer网络：第2试验，比例4, 第14周期，第(0/938)个撮，训练误差：16.40, 校验误差：17.27, 准确率：0.09
# no transfer网络：第2试验，比例4, 第15周期，第(0/938)个撮，训练误差：13.72, 校验误差：16.73, 准确率：0.10
# no transfer网络：第2试验，比例4, 第16周期，第(0/938)个撮，训练误差：16.92, 校验误差：16.39, 准确率：0.10
# no transfer网络：第2试验，比例4, 第17周期，第(0/938)个撮，训练误差：18.88, 校验误差：16.30, 准确率：0.10
# no transfer网络：第2试验，比例4, 第18周期，第(0/938)个撮，训练误差：17.01, 校验误差：17.16, 准确率：0.10
# no transfer网络：第2试验，比例4, 第19周期，第(0/938)个撮，训练误差：18.48, 校验误差：16.67, 准确率：0.10
# no transfer 2 4
# no transfer网络：第2试验，比例3, 第0周期，第(0/938)个撮，训练误差：100.31, 校验误差：92.32, 准确率：0.01
# no transfer网络：第2试验，比例3, 第1周期，第(0/938)个撮，训练误差：17.05, 校验误差：16.57, 准确率：0.11
# no transfer网络：第2试验，比例3, 第2周期，第(0/938)个撮，训练误差：15.77, 校验误差：17.05, 准确率：0.10
# no transfer网络：第2试验，比例3, 第3周期，第(0/938)个撮，训练误差：19.44, 校验误差：16.90, 准确率：0.09
# no transfer网络：第2试验，比例3, 第4周期，第(0/938)个撮，训练误差：16.27, 校验误差：17.23, 准确率：0.09
# no transfer网络：第2试验，比例3, 第5周期，第(0/938)个撮，训练误差：18.79, 校验误差：16.60, 准确率：0.10
# no transfer网络：第2试验，比例3, 第6周期，第(0/938)个撮，训练误差：15.67, 校验误差：16.96, 准确率：0.09
# no transfer网络：第2试验，比例3, 第7周期，第(0/938)个撮，训练误差：14.02, 校验误差：16.56, 准确率：0.10
# no transfer网络：第2试验，比例3, 第8周期，第(0/938)个撮，训练误差：13.22, 校验误差：16.52, 准确率：0.10
# no transfer网络：第2试验，比例3, 第9周期，第(0/938)个撮，训练误差：14.00, 校验误差：16.83, 准确率：0.10
# no transfer网络：第2试验，比例3, 第10周期，第(0/938)个撮，训练误差：13.78, 校验误差：16.33, 准确率：0.10
# no transfer网络：第2试验，比例3, 第11周期，第(0/938)个撮，训练误差：21.24, 校验误差：17.24, 准确率：0.10
# no transfer网络：第2试验，比例3, 第12周期，第(0/938)个撮，训练误差：15.02, 校验误差：16.82, 准确率：0.11
# no transfer网络：第2试验，比例3, 第13周期，第(0/938)个撮，训练误差：13.69, 校验误差：16.32, 准确率：0.10
# no transfer网络：第2试验，比例3, 第14周期，第(0/938)个撮，训练误差：17.51, 校验误差：17.04, 准确率：0.09
# no transfer网络：第2试验，比例3, 第15周期，第(0/938)个撮，训练误差：13.20, 校验误差：17.29, 准确率：0.10
# no transfer网络：第2试验，比例3, 第16周期，第(0/938)个撮，训练误差：14.82, 校验误差：17.21, 准确率：0.10
# no transfer网络：第2试验，比例3, 第17周期，第(0/938)个撮，训练误差：16.04, 校验误差：16.46, 准确率：0.10
# no transfer网络：第2试验，比例3, 第18周期，第(0/938)个撮，训练误差：16.14, 校验误差：16.90, 准确率：0.10
# no transfer网络：第2试验，比例3, 第19周期，第(0/938)个撮，训练误差：17.91, 校验误差：16.62, 准确率：0.11
# no transfer 2 3
# no transfer网络：第2试验，比例2, 第0周期，第(0/938)个撮，训练误差：103.88, 校验误差：96.20, 准确率：0.01
# no transfer网络：第2试验，比例2, 第1周期，第(0/938)个撮，训练误差：18.06, 校验误差：16.90, 准确率：0.10
# no transfer网络：第2试验，比例2, 第2周期，第(0/938)个撮，训练误差：20.16, 校验误差：16.95, 准确率：0.10
# no transfer网络：第2试验，比例2, 第3周期，第(0/938)个撮，训练误差：18.92, 校验误差：17.15, 准确率：0.10
# no transfer网络：第2试验，比例2, 第4周期，第(0/938)个撮，训练误差：24.22, 校验误差：17.17, 准确率：0.10
# no transfer网络：第2试验，比例2, 第5周期，第(0/938)个撮，训练误差：15.24, 校验误差：16.52, 准确率：0.10
# no transfer网络：第2试验，比例2, 第6周期，第(0/938)个撮，训练误差：18.73, 校验误差：16.87, 准确率：0.10
# no transfer网络：第2试验，比例2, 第7周期，第(0/938)个撮，训练误差：16.93, 校验误差：16.77, 准确率：0.11
# no transfer网络：第2试验，比例2, 第8周期，第(0/938)个撮，训练误差：15.81, 校验误差：17.32, 准确率：0.09
# no transfer网络：第2试验，比例2, 第9周期，第(0/938)个撮，训练误差：14.77, 校验误差：17.14, 准确率：0.10
# no transfer网络：第2试验，比例2, 第10周期，第(0/938)个撮，训练误差：16.61, 校验误差：16.79, 准确率：0.10
# no transfer网络：第2试验，比例2, 第11周期，第(0/938)个撮，训练误差：15.42, 校验误差：16.33, 准确率：0.10
# no transfer网络：第2试验，比例2, 第12周期，第(0/938)个撮，训练误差：19.54, 校验误差：16.84, 准确率：0.10
# no transfer网络：第2试验，比例2, 第13周期，第(0/938)个撮，训练误差：16.72, 校验误差：17.03, 准确率：0.11
# no transfer网络：第2试验，比例2, 第14周期，第(0/938)个撮，训练误差：16.85, 校验误差：16.75, 准确率：0.10
# no transfer网络：第2试验，比例2, 第15周期，第(0/938)个撮，训练误差：18.24, 校验误差：16.66, 准确率：0.10
# no transfer网络：第2试验，比例2, 第16周期，第(0/938)个撮，训练误差：17.72, 校验误差：16.66, 准确率：0.10
# no transfer网络：第2试验，比例2, 第17周期，第(0/938)个撮，训练误差：19.49, 校验误差：16.77, 准确率：0.10
# no transfer网络：第2试验，比例2, 第18周期，第(0/938)个撮，训练误差：16.22, 校验误差：16.33, 准确率：0.10
# no transfer网络：第2试验，比例2, 第19周期，第(0/938)个撮，训练误差：15.52, 校验误差：17.04, 准确率：0.10
# no transfer 2 2
# no transfer网络：第2试验，比例1, 第0周期，第(0/938)个撮，训练误差：96.71, 校验误差：102.26, 准确率：0.01
# no transfer网络：第2试验，比例1, 第0周期，第(500/938)个撮，训练误差：37.16, 校验误差：17.57, 准确率：0.09
# no transfer网络：第2试验，比例1, 第1周期，第(0/938)个撮，训练误差：16.39, 校验误差：16.89, 准确率：0.10
# no transfer网络：第2试验，比例1, 第1周期，第(500/938)个撮，训练误差：16.81, 校验误差：16.68, 准确率：0.10
# no transfer网络：第2试验，比例1, 第2周期，第(0/938)个撮，训练误差：19.45, 校验误差：17.21, 准确率：0.10
# no transfer网络：第2试验，比例1, 第2周期，第(500/938)个撮，训练误差：16.68, 校验误差：16.29, 准确率：0.11
# no transfer网络：第2试验，比例1, 第3周期，第(0/938)个撮，训练误差：16.88, 校验误差：16.69, 准确率：0.10
# no transfer网络：第2试验，比例1, 第3周期，第(500/938)个撮，训练误差：16.93, 校验误差：17.48, 准确率：0.10
# no transfer网络：第2试验，比例1, 第4周期，第(0/938)个撮，训练误差：15.04, 校验误差：16.74, 准确率：0.09
# no transfer网络：第2试验，比例1, 第4周期，第(500/938)个撮，训练误差：16.84, 校验误差：16.85, 准确率：0.10
# no transfer网络：第2试验，比例1, 第5周期，第(0/938)个撮，训练误差：17.11, 校验误差：16.73, 准确率：0.10
# no transfer网络：第2试验，比例1, 第5周期，第(500/938)个撮，训练误差：16.77, 校验误差：16.53, 准确率：0.10
# no transfer网络：第2试验，比例1, 第6周期，第(0/938)个撮，训练误差：16.21, 校验误差：16.67, 准确率：0.10
# no transfer网络：第2试验，比例1, 第6周期，第(500/938)个撮，训练误差：16.88, 校验误差：16.63, 准确率：0.10
# no transfer网络：第2试验，比例1, 第7周期，第(0/938)个撮，训练误差：18.53, 校验误差：16.98, 准确率：0.10
# no transfer网络：第2试验，比例1, 第7周期，第(500/938)个撮，训练误差：16.51, 校验误差：16.64, 准确率：0.10
# no transfer网络：第2试验，比例1, 第8周期，第(0/938)个撮，训练误差：15.20, 校验误差：16.51, 准确率：0.10
# no transfer网络：第2试验，比例1, 第8周期，第(500/938)个撮，训练误差：16.79, 校验误差：16.81, 准确率：0.10
# no transfer网络：第2试验，比例1, 第9周期，第(0/938)个撮，训练误差：20.26, 校验误差：16.82, 准确率：0.10
# no transfer网络：第2试验，比例1, 第9周期，第(500/938)个撮，训练误差：16.79, 校验误差：16.28, 准确率：0.11
# no transfer网络：第2试验，比例1, 第10周期，第(0/938)个撮，训练误差：13.91, 校验误差：16.56, 准确率：0.11
# no transfer网络：第2试验，比例1, 第10周期，第(500/938)个撮，训练误差：16.74, 校验误差：16.82, 准确率：0.10
# no transfer网络：第2试验，比例1, 第11周期，第(0/938)个撮，训练误差：17.54, 校验误差：16.61, 准确率：0.10
# no transfer网络：第2试验，比例1, 第11周期，第(500/938)个撮，训练误差：16.59, 校验误差：16.34, 准确率：0.11
# no transfer网络：第2试验，比例1, 第12周期，第(0/938)个撮，训练误差：12.95, 校验误差：16.70, 准确率：0.09
# no transfer网络：第2试验，比例1, 第12周期，第(500/938)个撮，训练误差：16.67, 校验误差：16.79, 准确率：0.10
# no transfer网络：第2试验，比例1, 第13周期，第(0/938)个撮，训练误差：18.21, 校验误差：16.81, 准确率：0.10
# no transfer网络：第2试验，比例1, 第13周期，第(500/938)个撮，训练误差：16.73, 校验误差：16.10, 准确率：0.10
# no transfer网络：第2试验，比例1, 第14周期，第(0/938)个撮，训练误差：15.92, 校验误差：16.97, 准确率：0.10
# no transfer网络：第2试验，比例1, 第14周期，第(500/938)个撮，训练误差：16.72, 校验误差：16.38, 准确率：0.10
# no transfer网络：第2试验，比例1, 第15周期，第(0/938)个撮，训练误差：14.38, 校验误差：17.01, 准确率：0.10
# no transfer网络：第2试验，比例1, 第15周期，第(500/938)个撮，训练误差：16.62, 校验误差：16.70, 准确率：0.10
# no transfer网络：第2试验，比例1, 第16周期，第(0/938)个撮，训练误差：18.52, 校验误差：17.25, 准确率：0.09
# no transfer网络：第2试验，比例1, 第16周期，第(500/938)个撮，训练误差：16.78, 校验误差：16.36, 准确率：0.09
# no transfer网络：第2试验，比例1, 第17周期，第(0/938)个撮，训练误差：19.47, 校验误差：16.41, 准确率：0.09
# no transfer网络：第2试验，比例1, 第17周期，第(500/938)个撮，训练误差：16.68, 校验误差：16.84, 准确率：0.10
# no transfer网络：第2试验，比例1, 第18周期，第(0/938)个撮，训练误差：19.97, 校验误差：16.77, 准确率：0.10
# no transfer网络：第2试验，比例1, 第18周期，第(500/938)个撮，训练误差：16.68, 校验误差：17.03, 准确率：0.10
# no transfer网络：第2试验，比例1, 第19周期，第(0/938)个撮，训练误差：14.56, 校验误差：16.90, 准确率：0.10
# no transfer网络：第2试验，比例1, 第19周期，第(500/938)个撮，训练误差：16.63, 校验误差：16.51, 准确率：0.10
# no transfer 2 1
# no transfer网络：第3试验，比例20, 第0周期，第(0/938)个撮，训练误差：80.95, 校验误差：93.22, 准确率：0.01
# no transfer网络：第3试验，比例20, 第1周期，第(0/938)个撮，训练误差：66.91, 校验误差：78.71, 准确率：0.02
# no transfer网络：第3试验，比例20, 第2周期，第(0/938)个撮，训练误差：26.76, 校验误差：23.58, 准确率：0.08
# no transfer网络：第3试验，比例20, 第3周期，第(0/938)个撮，训练误差：19.37, 校验误差：17.08, 准确率：0.11
# no transfer网络：第3试验，比例20, 第4周期，第(0/938)个撮，训练误差：16.67, 校验误差：16.59, 准确率：0.11
# no transfer网络：第3试验，比例20, 第5周期，第(0/938)个撮，训练误差：16.10, 校验误差：16.80, 准确率：0.10
# no transfer网络：第3试验，比例20, 第6周期，第(0/938)个撮，训练误差：15.95, 校验误差：17.68, 准确率：0.09
# no transfer网络：第3试验，比例20, 第7周期，第(0/938)个撮，训练误差：15.79, 校验误差：16.78, 准确率：0.10
# no transfer网络：第3试验，比例20, 第8周期，第(0/938)个撮，训练误差：11.16, 校验误差：17.09, 准确率：0.10
# no transfer网络：第3试验，比例20, 第9周期，第(0/938)个撮，训练误差：18.62, 校验误差：16.69, 准确率：0.12
# no transfer网络：第3试验，比例20, 第10周期，第(0/938)个撮，训练误差：16.54, 校验误差：16.77, 准确率：0.10
# no transfer网络：第3试验，比例20, 第11周期，第(0/938)个撮，训练误差：16.05, 校验误差：16.91, 准确率：0.09
# no transfer网络：第3试验，比例20, 第12周期，第(0/938)个撮，训练误差：15.54, 校验误差：16.55, 准确率：0.11
# no transfer网络：第3试验，比例20, 第13周期，第(0/938)个撮，训练误差：15.21, 校验误差：17.15, 准确率：0.10
# no transfer网络：第3试验，比例20, 第14周期，第(0/938)个撮，训练误差：18.51, 校验误差：16.65, 准确率：0.10
# no transfer网络：第3试验，比例20, 第15周期，第(0/938)个撮，训练误差：15.28, 校验误差：16.87, 准确率：0.10
# no transfer网络：第3试验，比例20, 第16周期，第(0/938)个撮，训练误差：18.97, 校验误差：16.54, 准确率：0.11
# no transfer网络：第3试验，比例20, 第17周期，第(0/938)个撮，训练误差：19.36, 校验误差：16.82, 准确率：0.10
# no transfer网络：第3试验，比例20, 第18周期，第(0/938)个撮，训练误差：17.61, 校验误差：16.82, 准确率：0.10
# no transfer网络：第3试验，比例20, 第19周期，第(0/938)个撮，训练误差：18.28, 校验误差：16.55, 准确率：0.11
# no transfer 3 20
# no transfer网络：第3试验，比例10, 第0周期，第(0/938)个撮，训练误差：108.81, 校验误差：99.74, 准确率：0.01
# no transfer网络：第3试验，比例10, 第1周期，第(0/938)个撮，训练误差：36.74, 校验误差：42.46, 准确率：0.05
# no transfer网络：第3试验，比例10, 第2周期，第(0/938)个撮，训练误差：14.35, 校验误差：16.54, 准确率：0.10
# no transfer网络：第3试验，比例10, 第3周期，第(0/938)个撮，训练误差：21.43, 校验误差：17.18, 准确率：0.09
# no transfer网络：第3试验，比例10, 第4周期，第(0/938)个撮，训练误差：18.01, 校验误差：16.60, 准确率：0.10
# no transfer网络：第3试验，比例10, 第5周期，第(0/938)个撮，训练误差：15.03, 校验误差：16.36, 准确率：0.10
# no transfer网络：第3试验，比例10, 第6周期，第(0/938)个撮，训练误差：14.89, 校验误差：16.90, 准确率：0.10
# no transfer网络：第3试验，比例10, 第7周期，第(0/938)个撮，训练误差：16.09, 校验误差：16.98, 准确率：0.09
# no transfer网络：第3试验，比例10, 第8周期，第(0/938)个撮，训练误差：16.66, 校验误差：17.08, 准确率：0.10
# no transfer网络：第3试验，比例10, 第9周期，第(0/938)个撮，训练误差：16.85, 校验误差：16.63, 准确率：0.10
# no transfer网络：第3试验，比例10, 第10周期，第(0/938)个撮，训练误差：19.40, 校验误差：16.48, 准确率：0.10
# no transfer网络：第3试验，比例10, 第11周期，第(0/938)个撮，训练误差：15.01, 校验误差：16.78, 准确率：0.09
# no transfer网络：第3试验，比例10, 第12周期，第(0/938)个撮，训练误差：14.20, 校验误差：16.49, 准确率：0.10
# no transfer网络：第3试验，比例10, 第13周期，第(0/938)个撮，训练误差：13.50, 校验误差：16.89, 准确率：0.10
# no transfer网络：第3试验，比例10, 第14周期，第(0/938)个撮，训练误差：21.63, 校验误差：16.78, 准确率：0.10
# no transfer网络：第3试验，比例10, 第15周期，第(0/938)个撮，训练误差：14.80, 校验误差：16.64, 准确率：0.10
# no transfer网络：第3试验，比例10, 第16周期，第(0/938)个撮，训练误差：22.90, 校验误差：16.55, 准确率：0.10
# no transfer网络：第3试验，比例10, 第17周期，第(0/938)个撮，训练误差：14.57, 校验误差：16.97, 准确率：0.10
# no transfer网络：第3试验，比例10, 第18周期，第(0/938)个撮，训练误差：19.30, 校验误差：16.56, 准确率：0.10
# no transfer网络：第3试验，比例10, 第19周期，第(0/938)个撮，训练误差：17.10, 校验误差：16.69, 准确率：0.10
# no transfer 3 10
# no transfer网络：第3试验，比例8, 第0周期，第(0/938)个撮，训练误差：100.31, 校验误差：96.84, 准确率：0.01
# no transfer网络：第3试验，比例8, 第1周期，第(0/938)个撮，训练误差：18.09, 校验误差：16.83, 准确率：0.11
# ...
# no transfer网络：第3试验，比例2, 第2周期，第(0/938)个撮，训练误差：21.94, 校验误差：17.29, 准确率：0.09
# no transfer网络：第3试验，比例2, 第3周期，第(0/938)个撮，训练误差：16.66, 校验误差：17.08, 准确率：0.10
# no transfer网络：第3试验，比例2, 第4周期，第(0/938)个撮，训练误差：18.14, 校验误差：16.61, 准确率：0.10
# no transfer网络：第3试验，比例2, 第5周期，第(0/938)个撮，训练误差：16.29, 校验误差：16.65, 准确率：0.11
# no transfer网络：第3试验，比例2, 第6周期，第(0/938)个撮，训练误差：19.55, 校验误差：16.76, 准确率：0.09
# no transfer网络：第3试验，比例2, 第7周期，第(0/938)个撮，训练误差：16.87, 校验误差：16.42, 准确率：0.10
# no transfer网络：第3试验，比例2, 第8周期，第(0/938)个撮，训练误差：13.33, 校验误差：17.06, 准确率：0.10
# no transfer网络：第3试验，比例2, 第9周期，第(0/938)个撮，训练误差：21.92, 校验误差：16.94, 准确率：0.10
# no transfer网络：第3试验，比例2, 第10周期，第(0/938)个撮，训练误差：18.82, 校验误差：16.80, 准确率：0.09
# no transfer网络：第3试验，比例2, 第11周期，第(0/938)个撮，训练误差：18.05, 校验误差：16.34, 准确率：0.11
# no transfer网络：第3试验，比例2, 第12周期，第(0/938)个撮，训练误差：16.27, 校验误差：16.87, 准确率：0.10
# no transfer网络：第3试验，比例2, 第13周期，第(0/938)个撮，训练误差：13.79, 校验误差：16.66, 准确率：0.10
# no transfer网络：第3试验，比例2, 第14周期，第(0/938)个撮，训练误差：17.47, 校验误差：16.59, 准确率：0.11
# no transfer网络：第3试验，比例2, 第15周期，第(0/938)个撮，训练误差：17.59, 校验误差：16.70, 准确率：0.10
# no transfer网络：第3试验，比例2, 第16周期，第(0/938)个撮，训练误差：14.44, 校验误差：17.16, 准确率：0.10
# no transfer网络：第3试验，比例2, 第17周期，第(0/938)个撮，训练误差：15.79, 校验误差：16.54, 准确率：0.11
# no transfer网络：第3试验，比例2, 第18周期，第(0/938)个撮，训练误差：17.54, 校验误差：16.67, 准确率：0.10
# no transfer网络：第3试验，比例2, 第19周期，第(0/938)个撮，训练误差：16.60, 校验误差：17.12, 准确率：0.10
# no transfer 3 2
# no transfer网络：第3试验，比例1, 第0周期，第(0/938)个撮，训练误差：96.04, 校验误差：93.86, 准确率：0.01
# no transfer网络：第3试验，比例1, 第0周期，第(500/938)个撮，训练误差：29.99, 校验误差：16.43, 准确率：0.10
# no transfer网络：第3试验，比例1, 第1周期，第(0/938)个撮，训练误差：16.12, 校验误差：17.08, 准确率：0.10
# no transfer网络：第3试验，比例1, 第1周期，第(500/938)个撮，训练误差：16.87, 校验误差：16.46, 准确率：0.11
# no transfer网络：第3试验，比例1, 第2周期，第(0/938)个撮，训练误差：17.65, 校验误差：16.47, 准确率：0.10
# no transfer网络：第3试验，比例1, 第2周期，第(500/938)个撮，训练误差：16.53, 校验误差：16.69, 准确率：0.11
# no transfer网络：第3试验，比例1, 第3周期，第(0/938)个撮，训练误差：15.90, 校验误差：16.96, 准确率：0.10
# no transfer网络：第3试验，比例1, 第3周期，第(500/938)个撮，训练误差：16.91, 校验误差：16.59, 准确率：0.10
# no transfer网络：第3试验，比例1, 第4周期，第(0/938)个撮，训练误差：14.01, 校验误差：16.83, 准确率：0.10
# no transfer网络：第3试验，比例1, 第4周期，第(500/938)个撮，训练误差：16.78, 校验误差：16.77, 准确率：0.10
# no transfer网络：第3试验，比例1, 第5周期，第(0/938)个撮，训练误差：17.51, 校验误差：16.96, 准确率：0.10
# no transfer网络：第3试验，比例1, 第5周期，第(500/938)个撮，训练误差：16.81, 校验误差：16.66, 准确率：0.10
# no transfer网络：第3试验，比例1, 第6周期，第(0/938)个撮，训练误差：15.98, 校验误差：16.60, 准确率：0.10
# no transfer网络：第3试验，比例1, 第6周期，第(500/938)个撮，训练误差：16.82, 校验误差：16.81, 准确率：0.10
# no transfer网络：第3试验，比例1, 第7周期，第(0/938)个撮，训练误差：16.44, 校验误差：17.14, 准确率：0.09
# no transfer网络：第3试验，比例1, 第7周期，第(500/938)个撮，训练误差：16.88, 校验误差：16.47, 准确率：0.10
# no transfer网络：第3试验，比例1, 第8周期，第(0/938)个撮，训练误差：18.96, 校验误差：16.38, 准确率：0.10
# no transfer网络：第3试验，比例1, 第8周期，第(500/938)个撮，训练误差：16.89, 校验误差：16.82, 准确率：0.10
# no transfer网络：第3试验，比例1, 第9周期，第(0/938)个撮，训练误差：12.02, 校验误差：15.82, 准确率：0.11
# no transfer网络：第3试验，比例1, 第9周期，第(500/938)个撮，训练误差：16.72, 校验误差：16.69, 准确率：0.11
# no transfer网络：第3试验，比例1, 第10周期，第(0/938)个撮，训练误差：18.61, 校验误差：16.75, 准确率：0.10
# no transfer网络：第3试验，比例1, 第10周期，第(500/938)个撮，训练误差：16.83, 校验误差：16.78, 准确率：0.10
# no transfer网络：第3试验，比例1, 第11周期，第(0/938)个撮，训练误差：17.85, 校验误差：16.89, 准确率：0.09
# no transfer网络：第3试验，比例1, 第11周期，第(500/938)个撮，训练误差：16.92, 校验误差：16.96, 准确率：0.10
# no transfer网络：第3试验，比例1, 第12周期，第(0/938)个撮，训练误差：13.78, 校验误差：17.13, 准确率：0.10
# no transfer网络：第3试验，比例1, 第12周期，第(500/938)个撮，训练误差：16.57, 校验误差：16.78, 准确率：0.09
# no transfer网络：第3试验，比例1, 第13周期，第(0/938)个撮，训练误差：15.59, 校验误差：16.89, 准确率：0.10
# no transfer网络：第3试验，比例1, 第13周期，第(500/938)个撮，训练误差：16.65, 校验误差：16.46, 准确率：0.10
# no transfer网络：第3试验，比例1, 第14周期，第(0/938)个撮，训练误差：15.12, 校验误差：16.82, 准确率：0.10
# no transfer网络：第3试验，比例1, 第14周期，第(500/938)个撮，训练误差：16.76, 校验误差：16.44, 准确率：0.10
# no transfer网络：第3试验，比例1, 第15周期，第(0/938)个撮，训练误差：12.99, 校验误差：16.88, 准确率：0.10
# no transfer网络：第3试验，比例1, 第15周期，第(500/938)个撮，训练误差：16.85, 校验误差：16.54, 准确率：0.10
# no transfer网络：第3试验，比例1, 第16周期，第(0/938)个撮，训练误差：18.66, 校验误差：16.33, 准确率：0.10
# no transfer网络：第3试验，比例1, 第16周期，第(500/938)个撮，训练误差：16.73, 校验误差：16.81, 准确率：0.10
# no transfer网络：第3试验，比例1, 第17周期，第(0/938)个撮，训练误差：16.86, 校验误差：16.75, 准确率：0.10
# no transfer网络：第3试验，比例1, 第17周期，第(500/938)个撮，训练误差：16.74, 校验误差：16.79, 准确率：0.10
# no transfer网络：第3试验，比例1, 第18周期，第(0/938)个撮，训练误差：17.40, 校验误差：16.39, 准确率：0.10
# no transfer网络：第3试验，比例1, 第18周期，第(500/938)个撮，训练误差：16.76, 校验误差：16.94, 准确率：0.10
# no transfer网络：第3试验，比例1, 第19周期，第(0/938)个撮，训练误差：16.28, 校验误差：16.85, 准确率：0.10
# no transfer网络：第3试验，比例1, 第19周期，第(500/938)个撮，训练误差：16.67, 校验误差：16.70, 准确率：0.10
# no transfer 3 1
# no transfer网络：第4试验，比例20, 第0周期，第(0/938)个撮，训练误差：88.93, 校验误差：101.37, 准确率：0.01
# no transfer网络：第4试验，比例20, 第1周期，第(0/938)个撮，训练误差：79.13, 校验误差：79.60, 准确率：0.02
# no transfer网络：第4试验，比例20, 第2周期，第(0/938)个撮，训练误差：27.12, 校验误差：17.11, 准确率：0.10
# no transfer网络：第4试验，比例20, 第3周期，第(0/938)个撮，训练误差：14.97, 校验误差：17.03, 准确率：0.09
# no transfer网络：第4试验，比例20, 第4周期，第(0/938)个撮，训练误差：16.69, 校验误差：17.46, 准确率：0.09
# no transfer网络：第4试验，比例20, 第5周期，第(0/938)个撮，训练误差：17.15, 校验误差：16.38, 准确率：0.11
# no transfer网络：第4试验，比例20, 第6周期，第(0/938)个撮，训练误差：15.37, 校验误差：16.46, 准确率：0.11
# no transfer网络：第4试验，比例20, 第7周期，第(0/938)个撮，训练误差：16.28, 校验误差：17.14, 准确率：0.08
# no transfer网络：第4试验，比例20, 第8周期，第(0/938)个撮，训练误差：16.86, 校验误差：17.01, 准确率：0.11
# no transfer网络：第4试验，比例20, 第9周期，第(0/938)个撮，训练误差：18.38, 校验误差：16.85, 准确率：0.10
# no transfer网络：第4试验，比例20, 第10周期，第(0/938)个撮，训练误差：15.26, 校验误差：16.92, 准确率：0.08
# no transfer网络：第4试验，比例20, 第11周期，第(0/938)个撮，训练误差：14.77, 校验误差：16.63, 准确率：0.10
# no transfer网络：第4试验，比例20, 第12周期，第(0/938)个撮，训练误差：11.32, 校验误差：17.01, 准确率：0.10
# no transfer网络：第4试验，比例20, 第13周期，第(0/938)个撮，训练误差：16.71, 校验误差：16.45, 准确率：0.10
# no transfer网络：第4试验，比例20, 第14周期，第(0/938)个撮，训练误差：16.80, 校验误差：16.66, 准确率：0.11
# no transfer网络：第4试验，比例20, 第15周期，第(0/938)个撮，训练误差：17.24, 校验误差：16.77, 准确率：0.09
# no transfer网络：第4试验，比例20, 第16周期，第(0/938)个撮，训练误差：18.28, 校验误差：16.63, 准确率：0.09
# no transfer网络：第4试验，比例20, 第17周期，第(0/938)个撮，训练误差：15.08, 校验误差：16.78, 准确率：0.10
# no transfer网络：第4试验，比例20, 第18周期，第(0/938)个撮，训练误差：13.31, 校验误差：17.13, 准确率：0.10
# no transfer网络：第4试验，比例20, 第19周期，第(0/938)个撮，训练误差：20.73, 校验误差：16.68, 准确率：0.09
# no transfer 4 20
# no transfer网络：第4试验，比例10, 第0周期，第(0/938)个撮，训练误差：78.11, 校验误差：95.86, 准确率：0.01
# no transfer网络：第4试验，比例10, 第1周期，第(0/938)个撮，训练误差：69.09, 校验误差：71.03, 准确率：0.03
# no transfer网络：第4试验，比例10, 第2周期，第(0/938)个撮，训练误差：22.73, 校验误差：19.57, 准确率：0.09
# no transfer网络：第4试验，比例10, 第3周期，第(0/938)个撮，训练误差：12.89, 校验误差：16.71, 准确率：0.11
# no transfer网络：第4试验，比例10, 第4周期，第(0/938)个撮，训练误差：14.86, 校验误差：16.90, 准确率：0.09
# no transfer网络：第4试验，比例10, 第5周期，第(0/938)个撮，训练误差：17.70, 校验误差：16.56, 准确率：0.11
# no transfer网络：第4试验，比例10, 第6周期，第(0/938)个撮，训练误差：14.16, 校验误差：16.90, 准确率：0.10
# no transfer网络：第4试验，比例10, 第7周期，第(0/938)个撮，训练误差：18.38, 校验误差：16.75, 准确率：0.10
# no transfer网络：第4试验，比例10, 第8周期，第(0/938)个撮，训练误差：16.12, 校验误差：17.16, 准确率：0.10
# no transfer网络：第4试验，比例10, 第9周期，第(0/938)个撮，训练误差：15.93, 校验误差：16.52, 准确率：0.10
# no transfer网络：第4试验，比例10, 第10周期，第(0/938)个撮，训练误差：18.38, 校验误差：16.51, 准确率：0.10
# no transfer网络：第4试验，比例10, 第11周期，第(0/938)个撮，训练误差：12.90, 校验误差：16.45, 准确率：0.10
# no transfer网络：第4试验，比例10, 第12周期，第(0/938)个撮，训练误差：16.61, 校验误差：17.01, 准确率：0.10
# no transfer网络：第4试验，比例10, 第13周期，第(0/938)个撮，训练误差：14.22, 校验误差：16.61, 准确率：0.10
# no transfer网络：第4试验，比例10, 第14周期，第(0/938)个撮，训练误差：20.63, 校验误差：16.43, 准确率：0.09
# no transfer网络：第4试验，比例10, 第15周期，第(0/938)个撮，训练误差：16.32, 校验误差：16.90, 准确率：0.09
# no transfer网络：第4试验，比例10, 第16周期，第(0/938)个撮，训练误差：20.74, 校验误差：16.70, 准确率：0.10
# no transfer网络：第4试验，比例10, 第17周期，第(0/938)个撮，训练误差：13.19, 校验误差：16.95, 准确率：0.10
# no transfer网络：第4试验，比例10, 第18周期，第(0/938)个撮，训练误差：18.82, 校验误差：16.60, 准确率：0.11
# no transfer网络：第4试验，比例10, 第19周期，第(0/938)个撮，训练误差：17.94, 校验误差：16.84, 准确率：0.10
# no transfer 4 10
# no transfer网络：第4试验，比例8, 第0周期，第(0/938)个撮，训练误差：103.30, 校验误差：98.54, 准确率：0.01
# no transfer网络：第4试验，比例8, 第1周期，第(0/938)个撮，训练误差：22.67, 校验误差：17.37, 准确率：0.08
# no transfer网络：第4试验，比例8, 第2周期，第(0/938)个撮，训练误差：22.42, 校验误差：17.27, 准确率：0.08
# no transfer网络：第4试验，比例8, 第3周期，第(0/938)个撮，训练误差：17.61, 校验误差：16.89, 准确率：0.11
# no transfer网络：第4试验，比例8, 第4周期，第(0/938)个撮，训练误差：14.91, 校验误差：17.01, 准确率：0.11
# no transfer网络：第4试验，比例8, 第5周期，第(0/938)个撮，训练误差：18.98, 校验误差：17.22, 准确率：0.09
# no transfer网络：第4试验，比例8, 第6周期，第(0/938)个撮，训练误差：15.51, 校验误差：16.88, 准确率：0.09
# no transfer网络：第4试验，比例8, 第7周期，第(0/938)个撮，训练误差：17.91, 校验误差：17.11, 准确率：0.10
# no transfer网络：第4试验，比例8, 第8周期，第(0/938)个撮，训练误差：16.39, 校验误差：16.45, 准确率：0.10
# no transfer网络：第4试验，比例8, 第9周期，第(0/938)个撮，训练误差：17.51, 校验误差：16.88, 准确率：0.10
# no transfer网络：第4试验，比例8, 第10周期，第(0/938)个撮，训练误差：16.60, 校验误差：16.44, 准确率：0.09
# no transfer网络：第4试验，比例8, 第11周期，第(0/938)个撮，训练误差：15.99, 校验误差：16.48, 准确率：0.10
# no transfer网络：第4试验，比例8, 第12周期，第(0/938)个撮，训练误差：18.85, 校验误差：17.85, 准确率：0.09
# no transfer网络：第4试验，比例8, 第13周期，第(0/938)个撮，训练误差：19.15, 校验误差：17.14, 准确率：0.10
# no transfer网络：第4试验，比例8, 第14周期，第(0/938)个撮，训练误差：20.35, 校验误差：16.80, 准确率：0.10
# no transfer网络：第4试验，比例8, 第15周期，第(0/938)个撮，训练误差：21.17, 校验误差：16.71, 准确率：0.11
# no transfer网络：第4试验，比例8, 第16周期，第(0/938)个撮，训练误差：17.42, 校验误差：16.97, 准确率：0.10
# no transfer网络：第4试验，比例8, 第17周期，第(0/938)个撮，训练误差：15.01, 校验误差：16.74, 准确率：0.09
# no transfer网络：第4试验，比例8, 第18周期，第(0/938)个撮，训练误差：22.23, 校验误差：17.15, 准确率：0.09
# no transfer网络：第4试验，比例8, 第19周期，第(0/938)个撮，训练误差：18.54, 校验误差：16.44, 准确率：0.10
# no transfer 4 8
# no transfer网络：第4试验，比例6, 第0周期，第(0/938)个撮，训练误差：83.78, 校验误差：97.44, 准确率：0.01
# no transfer网络：第4试验，比例6, 第1周期，第(0/938)个撮，训练误差：15.06, 校验误差：16.82, 准确率：0.09
# no transfer网络：第4试验，比例6, 第2周期，第(0/938)个撮，训练误差：15.87, 校验误差：17.25, 准确率：0.10
# no transfer网络：第4试验，比例6, 第3周期，第(0/938)个撮，训练误差：18.38, 校验误差：17.11, 准确率：0.10
# no transfer网络：第4试验，比例6, 第4周期，第(0/938)个撮，训练误差：16.26, 校验误差：17.41, 准确率：0.09
# no transfer网络：第4试验，比例6, 第5周期，第(0/938)个撮，训练误差：13.13, 校验误差：16.98, 准确率：0.08
# no transfer网络：第4试验，比例6, 第6周期，第(0/938)个撮，训练误差：20.86, 校验误差：16.54, 准确率：0.11
# no transfer网络：第4试验，比例6, 第7周期，第(0/938)个撮，训练误差：16.33, 校验误差：17.22, 准确率：0.10
# no transfer网络：第4试验，比例6, 第8周期，第(0/938)个撮，训练误差：14.08, 校验误差：16.55, 准确率：0.11
# no transfer网络：第4试验，比例6, 第9周期，第(0/938)个撮，训练误差：16.20, 校验误差：16.83, 准确率：0.10
# no transfer网络：第4试验，比例6, 第10周期，第(0/938)个撮，训练误差：19.49, 校验误差：16.27, 准确率：0.09
# no transfer网络：第4试验，比例6, 第11周期，第(0/938)个撮，训练误差：15.90, 校验误差：16.36, 准确率：0.10
# no transfer网络：第4试验，比例6, 第12周期，第(0/938)个撮，训练误差：18.83, 校验误差：16.54, 准确率：0.10
# no transfer网络：第4试验，比例6, 第13周期，第(0/938)个撮，训练误差：13.58, 校验误差：16.87, 准确率：0.10
# no transfer网络：第4试验，比例6, 第14周期，第(0/938)个撮，训练误差：16.44, 校验误差：17.22, 准确率：0.10
# no transfer网络：第4试验，比例6, 第15周期，第(0/938)个撮，训练误差：18.19, 校验误差：17.14, 准确率：0.10
# no transfer网络：第4试验，比例6, 第16周期，第(0/938)个撮，训练误差：15.53, 校验误差：16.79, 准确率：0.11
# no transfer网络：第4试验，比例6, 第17周期，第(0/938)个撮，训练误差：14.86, 校验误差：16.95, 准确率：0.09
# no transfer网络：第4试验，比例6, 第18周期，第(0/938)个撮，训练误差：19.04, 校验误差：16.80, 准确率：0.09
# no transfer网络：第4试验，比例6, 第19周期，第(0/938)个撮，训练误差：15.12, 校验误差：16.73, 准确率：0.10
# no transfer 4 6
# no transfer网络：第4试验，比例5, 第0周期，第(0/938)个撮，训练误差：97.25, 校验误差：93.88, 准确率：0.01
# no transfer网络：第4试验，比例5, 第1周期，第(0/938)个撮，训练误差：16.85, 校验误差：17.38, 准确率：0.10
# no transfer网络：第4试验，比例5, 第2周期，第(0/938)个撮，训练误差：19.44, 校验误差：16.79, 准确率：0.10
# no transfer网络：第4试验，比例5, 第3周期，第(0/938)个撮，训练误差：14.50, 校验误差：17.00, 准确率：0.10
# no transfer网络：第4试验，比例5, 第4周期，第(0/938)个撮，训练误差：15.11, 校验误差：16.83, 准确率：0.11
# no transfer网络：第4试验，比例5, 第5周期，第(0/938)个撮，训练误差：20.91, 校验误差：16.77, 准确率：0.11
# no transfer网络：第4试验，比例5, 第6周期，第(0/938)个撮，训练误差：19.98, 校验误差：17.04, 准确率：0.09
# no transfer网络：第4试验，比例5, 第7周期，第(0/938)个撮，训练误差：17.09, 校验误差：17.08, 准确率：0.09
# no transfer网络：第4试验，比例5, 第8周期，第(0/938)个撮，训练误差：18.42, 校验误差：16.81, 准确率：0.10
# no transfer网络：第4试验，比例5, 第9周期，第(0/938)个撮，训练误差：20.00, 校验误差：16.52, 准确率：0.11
# no transfer网络：第4试验，比例5, 第10周期，第(0/938)个撮，训练误差：20.45, 校验误差：16.66, 准确率：0.10
# no transfer网络：第4试验，比例5, 第11周期，第(0/938)个撮，训练误差：18.54, 校验误差：16.68, 准确率：0.10
# no transfer网络：第4试验，比例5, 第12周期，第(0/938)个撮，训练误差：18.20, 校验误差：16.98, 准确率：0.10
# no transfer网络：第4试验，比例5, 第13周期，第(0/938)个撮，训练误差：14.14, 校验误差：17.26, 准确率：0.10
# no transfer网络：第4试验，比例5, 第14周期，第(0/938)个撮，训练误差：14.14, 校验误差：16.64, 准确率：0.11
# no transfer网络：第4试验，比例5, 第15周期，第(0/938)个撮，训练误差：16.28, 校验误差：17.11, 准确率：0.10
# no transfer网络：第4试验，比例5, 第16周期，第(0/938)个撮，训练误差：14.43, 校验误差：16.42, 准确率：0.10
# no transfer网络：第4试验，比例5, 第17周期，第(0/938)个撮，训练误差：18.54, 校验误差：16.62, 准确率：0.10
# no transfer网络：第4试验，比例5, 第18周期，第(0/938)个撮，训练误差：19.42, 校验误差：16.36, 准确率：0.11
# no transfer网络：第4试验，比例5, 第19周期，第(0/938)个撮，训练误差：18.23, 校验误差：17.01, 准确率：0.11
# no transfer 4 5
# no transfer网络：第4试验，比例4, 第0周期，第(0/938)个撮，训练误差：82.82, 校验误差：101.54, 准确率：0.01
# no transfer网络：第4试验，比例4, 第1周期，第(0/938)个撮，训练误差：22.26, 校验误差：16.54, 准确率：0.11
# no transfer网络：第4试验，比例4, 第2周期，第(0/938)个撮，训练误差：19.18, 校验误差：16.51, 准确率：0.10
# no transfer网络：第4试验，比例4, 第3周期，第(0/938)个撮，训练误差：17.21, 校验误差：16.63, 准确率：0.11
# no transfer网络：第4试验，比例4, 第4周期，第(0/938)个撮，训练误差：16.52, 校验误差：17.59, 准确率：0.09
# no transfer网络：第4试验，比例4, 第5周期，第(0/938)个撮，训练误差：15.09, 校验误差：16.65, 准确率：0.10
# no transfer网络：第4试验，比例4, 第6周期，第(0/938)个撮，训练误差：18.43, 校验误差：16.83, 准确率：0.11
# no transfer网络：第4试验，比例4, 第7周期，第(0/938)个撮，训练误差：18.12, 校验误差：16.49, 准确率：0.09
# no transfer网络：第4试验，比例4, 第8周期，第(0/938)个撮，训练误差：15.33, 校验误差：17.03, 准确率：0.10
# no transfer网络：第4试验，比例4, 第9周期，第(0/938)个撮，训练误差：16.92, 校验误差：16.50, 准确率：0.10
# no transfer网络：第4试验，比例4, 第10周期，第(0/938)个撮，训练误差：17.65, 校验误差：16.55, 准确率：0.10
# no transfer网络：第4试验，比例4, 第11周期，第(0/938)个撮，训练误差：17.21, 校验误差：16.78, 准确率：0.10
# no transfer网络：第4试验，比例4, 第12周期，第(0/938)个撮，训练误差：16.53, 校验误差：17.01, 准确率：0.08
# no transfer网络：第4试验，比例4, 第13周期，第(0/938)个撮，训练误差：15.81, 校验误差：16.62, 准确率：0.11
# no transfer网络：第4试验，比例4, 第14周期，第(0/938)个撮，训练误差：16.17, 校验误差：17.23, 准确率：0.10
# no transfer网络：第4试验，比例4, 第15周期，第(0/938)个撮，训练误差：14.57, 校验误差：16.69, 准确率：0.10
# no transfer网络：第4试验，比例4, 第16周期，第(0/938)个撮，训练误差：16.85, 校验误差：16.61, 准确率：0.10
# no transfer网络：第4试验，比例4, 第17周期，第(0/938)个撮，训练误差：18.96, 校验误差：17.08, 准确率：0.10
# no transfer网络：第4试验，比例4, 第18周期，第(0/938)个撮，训练误差：16.62, 校验误差：16.67, 准确率：0.10
# no transfer网络：第4试验，比例4, 第19周期，第(0/938)个撮，训练误差：19.65, 校验误差：16.59, 准确率：0.11
# no transfer 4 4
# no transfer网络：第4试验，比例3, 第0周期，第(0/938)个撮，训练误差：102.87, 校验误差：101.46, 准确率：0.01
# no transfer网络：第4试验，比例3, 第1周期，第(0/938)个撮，训练误差：21.47, 校验误差：17.12, 准确率：0.11
# no transfer网络：第4试验，比例3, 第2周期，第(0/938)个撮，训练误差：15.96, 校验误差：16.89, 准确率：0.10
# no transfer网络：第4试验，比例3, 第3周期，第(0/938)个撮，训练误差：12.37, 校验误差：16.63, 准确率：0.10
# no transfer网络：第4试验，比例3, 第4周期，第(0/938)个撮，训练误差：18.68, 校验误差：16.96, 准确率：0.08
# no transfer网络：第4试验，比例3, 第5周期，第(0/938)个撮，训练误差：13.85, 校验误差：16.60, 准确率：0.10
# no transfer网络：第4试验，比例3, 第6周期，第(0/938)个撮，训练误差：14.42, 校验误差：16.82, 准确率：0.10
# no transfer网络：第4试验，比例3, 第7周期，第(0/938)个撮，训练误差：16.79, 校验误差：16.83, 准确率：0.10
# no transfer网络：第4试验，比例3, 第8周期，第(0/938)个撮，训练误差：18.23, 校验误差：17.16, 准确率：0.10
# no transfer网络：第4试验，比例3, 第9周期，第(0/938)个撮，训练误差：20.33, 校验误差：16.81, 准确率：0.10
# no transfer网络：第4试验，比例3, 第10周期，第(0/938)个撮，训练误差：16.92, 校验误差：16.92, 准确率：0.10
# no transfer网络：第4试验，比例3, 第11周期，第(0/938)个撮，训练误差：18.35, 校验误差：16.98, 准确率：0.10
# no transfer网络：第4试验，比例3, 第12周期，第(0/938)个撮，训练误差：15.10, 校验误差：16.42, 准确率：0.10
# no transfer网络：第4试验，比例3, 第13周期，第(0/938)个撮，训练误差：19.76, 校验误差：17.15, 准确率：0.10
# no transfer网络：第4试验，比例3, 第14周期，第(0/938)个撮，训练误差：16.59, 校验误差：16.44, 准确率：0.10
# no transfer网络：第4试验，比例3, 第15周期，第(0/938)个撮，训练误差：15.31, 校验误差：16.88, 准确率：0.11
# no transfer网络：第4试验，比例3, 第16周期，第(0/938)个撮，训练误差：20.92, 校验误差：16.95, 准确率：0.10
# no transfer网络：第4试验，比例3, 第17周期，第(0/938)个撮，训练误差：12.20, 校验误差：16.78, 准确率：0.09
# no transfer网络：第4试验，比例3, 第18周期，第(0/938)个撮，训练误差：21.28, 校验误差：16.73, 准确率：0.10
# no transfer网络：第4试验，比例3, 第19周期，第(0/938)个撮，训练误差：17.03, 校验误差：16.81, 准确率：0.10
# no transfer 4 3
# no transfer网络：第4试验，比例2, 第0周期，第(0/938)个撮，训练误差：117.97, 校验误差：100.56, 准确率：0.01
# no transfer网络：第4试验，比例2, 第1周期，第(0/938)个撮，训练误差：22.04, 校验误差：17.19, 准确率：0.10
# no transfer网络：第4试验，比例2, 第2周期，第(0/938)个撮，训练误差：18.01, 校验误差：17.20, 准确率：0.09
# no transfer网络：第4试验，比例2, 第3周期，第(0/938)个撮，训练误差：19.63, 校验误差：16.81, 准确率：0.10
# no transfer网络：第4试验，比例2, 第4周期，第(0/938)个撮，训练误差：18.13, 校验误差：16.85, 准确率：0.10
# no transfer网络：第4试验，比例2, 第5周期，第(0/938)个撮，训练误差：14.51, 校验误差：16.36, 准确率：0.09
# no transfer网络：第4试验，比例2, 第6周期，第(0/938)个撮，训练误差：16.01, 校验误差：16.29, 准确率：0.10
# no transfer网络：第4试验，比例2, 第7周期，第(0/938)个撮，训练误差：15.79, 校验误差：16.34, 准确率：0.10
# no transfer网络：第4试验，比例2, 第8周期，第(0/938)个撮，训练误差：22.05, 校验误差：16.45, 准确率：0.10
# no transfer网络：第4试验，比例2, 第9周期，第(0/938)个撮，训练误差：13.26, 校验误差：16.84, 准确率：0.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b21df9878ced> in <module>
#      54                     loss.backward()
#      55                     optimizer.step()
# ---> 56                     loss = loss.cpu() if use_cuda else loss
#      57                     losses.append(loss.data.numpy())
#      58                     if idx % 500 == 0:
#
# KeyboardInterrupt:

# %%
# 处理实验数据
# 首先对于同一组参数下的数据求多次试验的平均值

one_curve = {}
tests = {}
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    for fraction in fractions:
        one_experiment = []
        test_value = []
        for time in range(times):
            rr = results[(experiment, time, fraction)]
            one_experiment.append([ii[2] for ii in rr[0]])
            test_value.append(rr[1])
        aa = np.array(one_experiment)
        #print(aa.shape)
        one_curve[(experiment, fraction)] = np.mean(aa, 0)
        tests[(experiment, fraction)] = np.mean(test_value)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-c9d407e099c6> in <module>
#       9         test_value = []
#      10         for time in range(times):
# ---> 11             rr = results[(experiment, time, fraction)]
#      12             one_experiment.append([ii[2] for ii in rr[0]])
#      13             test_value.append(rr[1])
#
# KeyError: ('no transfer', 5, 20)

# %%
# 然后再绘制它们的误差曲线
for fraction in fractions:
    plt.figure(figsize = (10, 7))
    plt.title('{:.2f} % of the data'.format(100.0 / fraction))
    plt.plot(1 - one_curve[('no transfer', fraction)], label = 'no transfer')
    plt.plot(1 - one_curve[('transfer_pretrained', fraction)], label = 'transfer pretrained')
    plt.plot(1 - one_curve[('transfer_fixed', fraction)] , label = 'transfer fixed')
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('Error')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-590f289dd540> in <module>
#       3     plt.figure(figsize = (10, 7))
#       4     plt.title('{:.2f} % of the data'.format(100.0 / fraction))
# ----> 5     plt.plot(1 - one_curve[('no transfer', fraction)], label = 'no transfer')
#       6     plt.plot(1 - one_curve[('transfer_pretrained', fraction)], label = 'transfer pretrained')
#       7     plt.plot(1 - one_curve[('transfer_fixed', fraction)] , label = 'transfer fixed')
#
# KeyError: ('no transfer', 20)

# %%
# 绘制测试准确度随着fraction变化的曲线
plt.figure(figsize = (10, 7))
for experiment in ['no transfer', 'transfer_pretrained', 'transfer_fixed']:
    testss = []
    for fraction in fractions:
        test = 1 - tests[(experiment, fraction)]
        testss.append(test)
    plt.plot(fractions, testss, 'o-', label = experiment)
plt.legend()
plt.xlabel('Fractions')
plt.ylabel('Error Rate')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-f72948c1d545> in <module>
#       4     testss = []
#       5     for fraction in fractions:
# ----> 6         test = 1 - tests[(experiment, fraction)]
#       7         testss.append(test)
#       8     plt.plot(fractions, testss, 'o-', label = experiment)
#
# KeyError: ('no transfer', 20)
